# %% [markdown]
# **1. Import Modules**

# %%
'''
  Import all necessary modules
'''

import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input , Dense, Dropout, SimpleRNN
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.losses import MeanSquaredError, MeanAbsoluteError
from tensorflow.keras.metrics import RootMeanSquaredError, MeanAbsoluteError
from tensorflow.keras.optimizers import Adam, Adadelta
from numpy.random import seed
from tensorflow.keras.utils import set_random_seed
from sklearn import preprocessing
import seaborn as sns

# %%
#mount the drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd /content/gdrive/MyDrive/TRM/ENAAM
# Out:
# /content/gdrive/MyDrive/TRM/ENAAM

# %% [markdown]
# **2. Dataset Preparation**

# %%
# Import dataset
df = pd.read_csv('/content/gdrive/MyDrive/TRM/ENAAM/AllRanking/ground_truth-shuffled.csv')
df
# Out:
#       Response Time  Availability  Throughput  Reliability  Latency  Rank
# 0            182.25            67         9.7           67    46.50   1672
# 1            175.50            90         7.6           80    39.00   1585
# 2            500.71            92         2.2           67   233.85   2432
# 3            175.00            86         9.4           73     3.00    435
# 4            996.00            83        14.0           83    59.00   2088
# ...             ...           ...         ...          ...      ...    ...
# 2502         432.00            86         8.8           80     1.29    577
# 2503         249.00            56         8.1           73     2.25    554
# 2504         219.20            94         1.1           73     8.40   1256
# 2505         171.00            83        18.6           80     5.00    474
# 2506         227.00            88        21.2           73    23.00   1321
#
# [2507 rows x 6 columns]

# %%
df.hist(figsize = (12,10))
plt.show()

# %%
f, ax = plt.subplots(figsize=(10, 8))
corr = df.corr()
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool),
            cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, ax=ax)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Correlation between different variables
#
corr = df.corr()
#
# Set up the matplotlib plot configuration
#
f, ax = plt.subplots(figsize=(12, 10))
#
# Generate a mask for upper traingle
#
mask = np.triu(np.ones_like(corr, dtype=bool))
#
# Configure a custom diverging colormap
#
cmap = sns.diverging_palette(230, 20, as_cmap=True)
#
# Draw the heatmap
#
sns.heatmap(corr, annot=True, mask = mask, cmap=cmap)

# %%
# Create python dataframe
decisions = pd.DataFrame()
decisions['Response Time'] = df['Response Time']
decisions['Availability'] = df['Availability']
decisions['Throughput'] = df['Throughput']
decisions['Reliability'] = df['Reliability']
decisions['Latency'] = df['Latency']
decisions['Rank'] = df['Rank ']
decisions
# Out:
#       Response Time  Availability  Throughput  Reliability  Latency  Rank
# 0            182.25            67         9.7           67    46.50  1672
# 1            175.50            90         7.6           80    39.00  1585
# 2            500.71            92         2.2           67   233.85  2432
# 3            175.00            86         9.4           73     3.00   435
# 4            996.00            83        14.0           83    59.00  2088
# ...             ...           ...         ...          ...      ...   ...
# 2502         432.00            86         8.8           80     1.29   577
# 2503         249.00            56         8.1           73     2.25   554
# 2504         219.20            94         1.1           73     8.40  1256
# 2505         171.00            83        18.6           80     5.00   474
# 2506         227.00            88        21.2           73    23.00  1321
#
# [2507 rows x 6 columns]

# %%
'''
 Split dataset to train (70%), test (15%) and validation(15%) sets. 
 The top 30 values were removed from the dataset to be split. 
      * Reason for removal - We have to check the MAE of the top 30. The data should be unknown to the model to get
        accurate figures. 
'''
training_data = decisions[0:1785]#361

test_data = decisions[1855:2146]

validation_data = decisions[2146:2507]

# %%
# Split into input and output values

tmp_train = np.array(training_data)
X_train = tmp_train[:, :-1]
y_train = tmp_train[:, -1]

tmp_test = np.array(test_data)
X_test = tmp_test[:, :-1]
y_test = tmp_test[:, -1]

tmp_val = np.array(validation_data)
X_validation = tmp_val[:, :-1]
y_validation = tmp_val[:, -1]

# %% [markdown]
# **3. Model Preparation**

# %%
seed(0)
set_random_seed(0)

# %%
'''
 This function is used to display the training history of the dataset.
'''
def show_train_history(train_history,train,validation):
    plt.plot(train_history.history[train])
    plt.plot(train_history.history[validation])
    plt.title('Train History')
    plt.ylabel(train)
    plt.xlabel('Epoch')
    plt.legend(['train', 'validation'], loc='best')
    plt.show()

# %%
# 4 hidden layers neural network
 
model = Sequential()

n_cols = training_data.shape[1]

model.add(Dense(256, kernel_initializer='normal', activation='relu', input_shape=(5,)))
# The Hidden Layers :
model.add(Dense(128, kernel_initializer='normal',activation='relu'))
model.add(Dense(96, kernel_initializer='normal',activation='relu'))
model.add(Dense(72, kernel_initializer='normal',activation='relu'))
model.add(Dense(64, kernel_initializer='normal',activation='relu'))
#model.add(Dropout(0.5))
model.add(Dense(1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9a2899646275> in <module>
#       1 # 4 hidden layers neural network
#       2
# ----> 3 model = Sequential()
#       4
#       5 n_cols = training_data.shape[1]
#
# NameError: name 'Sequential' is not defined

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 256)               1536
#
#  dense_13 (Dense)            (None, 128)               32896
#
#  dense_14 (Dense)            (None, 96)                12384
#
#  dense_15 (Dense)            (None, 72)                6984
#
#  dense_16 (Dense)            (None, 64)                4672
#
#  dense_17 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 58,537
# Trainable params: 58,537
# Non-trainable params: 0
# _________________________________________________________________

# %%
'''
Checkpoints are used to save the model at some interval, so the model can be loaded from the saved state to continue training
'''
cp = ModelCheckpoint('model_ann_all/', save_best_only=True)

# Compile model
model.compile(loss='mean_absolute_error',
                optimizer=tf.keras.optimizers.Adam(0.0001), metrics='mean_absolute_error')

# %%
#train model
#change ebochs----Enaam

train_history = model.fit(X_train, y_train, epochs=700, validation_data=(X_validation, y_validation), callbacks=[cp])
# Out:
# Epoch 1/700
# 56/56 [==============================] - 2s 26ms/step - loss: 1247.0912 - mean_absolute_error: 1247.0912 - val_loss: 1230.2021 - val_mean_absolute_error: 1230.2021
# Epoch 2/700
# 56/56 [==============================] - 1s 22ms/step - loss: 1135.0017 - mean_absolute_error: 1135.0017 - val_loss: 931.6815 - val_mean_absolute_error: 931.6815
# Epoch 3/700
# 56/56 [==============================] - 1s 23ms/step - loss: 804.9108 - mean_absolute_error: 804.9108 - val_loss: 770.2875 - val_mean_absolute_error: 770.2875
# Epoch 4/700
# 56/56 [==============================] - 1s 22ms/step - loss: 720.8885 - mean_absolute_error: 720.8885 - val_loss: 741.9166 - val_mean_absolute_error: 741.9166
# Epoch 5/700
# 56/56 [==============================] - 1s 22ms/step - loss: 686.5105 - mean_absolute_error: 686.5105 - val_loss: 712.5447 - val_mean_absolute_error: 712.5447
# Epoch 6/700
# 56/56 [==============================] - 2s 27ms/step - loss: 656.1216 - mean_absolute_error: 656.1216 - val_loss: 660.8432 - val_mean_absolute_error: 660.8432
# Epoch 7/700
# 56/56 [==============================] - 1s 23ms/step - loss: 622.3033 - mean_absolute_error: 622.3033 - val_loss: 632.7328 - val_mean_absolute_error: 632.7328
# Epoch 8/700
# 56/56 [==============================] - 1s 22ms/step - loss: 589.3129 - mean_absolute_error: 589.3129 - val_loss: 597.8464 - val_mean_absolute_error: 597.8464
# Epoch 9/700
# 56/56 [==============================] - 1s 22ms/step - loss: 556.6877 - mean_absolute_error: 556.6877 - val_loss: 570.8615 - val_mean_absolute_error: 570.8615
# Epoch 10/700
# 56/56 [==============================] - 1s 22ms/step - loss: 518.6843 - mean_absolute_error: 518.6843 - val_loss: 543.5714 - val_mean_absolute_error: 543.5714
# Epoch 11/700
# 56/56 [==============================] - 1s 22ms/step - loss: 483.0758 - mean_absolute_error: 483.0758 - val_loss: 503.1043 - val_mean_absolute_error: 503.1043
# Epoch 12/700
# 56/56 [==============================] - 1s 22ms/step - loss: 439.9551 - mean_absolute_error: 439.9551 - val_loss: 463.7145 - val_mean_absolute_error: 463.7145
# Epoch 13/700
# 56/56 [==============================] - 2s 27ms/step - loss: 393.2397 - mean_absolute_error: 393.2397 - val_loss: 411.0861 - val_mean_absolute_error: 411.0861
# Epoch 14/700
# 56/56 [==============================] - 1s 22ms/step - loss: 335.1566 - mean_absolute_error: 335.1566 - val_loss: 358.3691 - val_mean_absolute_error: 358.3691
# Epoch 15/700
# 56/56 [==============================] - 1s 22ms/step - loss: 280.1227 - mean_absolute_error: 280.1227 - val_loss: 277.8891 - val_mean_absolute_error: 277.8891
# Epoch 16/700
# 56/56 [==============================] - 1s 23ms/step - loss: 239.4228 - mean_absolute_error: 239.4228 - val_loss: 238.0589 - val_mean_absolute_error: 238.0589
# Epoch 17/700
# 56/56 [==============================] - 1s 22ms/step - loss: 220.9122 - mean_absolute_error: 220.9122 - val_loss: 226.9823 - val_mean_absolute_error: 226.9823
# Epoch 18/700
# 56/56 [==============================] - 1s 23ms/step - loss: 212.4404 - mean_absolute_error: 212.4404 - val_loss: 209.3540 - val_mean_absolute_error: 209.3540
# Epoch 19/700
# 56/56 [==============================] - 2s 27ms/step - loss: 205.5147 - mean_absolute_error: 205.5147 - val_loss: 205.7476 - val_mean_absolute_error: 205.7476
# Epoch 20/700
# 56/56 [==============================] - 0s 4ms/step - loss: 199.8415 - mean_absolute_error: 199.8415 - val_loss: 211.1626 - val_mean_absolute_error: 211.1626
# Epoch 21/700
# 56/56 [==============================] - 1s 22ms/step - loss: 194.1178 - mean_absolute_error: 194.1178 - val_loss: 195.0360 - val_mean_absolute_error: 195.0360
# Epoch 22/700
# 56/56 [==============================] - 1s 23ms/step - loss: 192.5306 - mean_absolute_error: 192.5306 - val_loss: 192.8588 - val_mean_absolute_error: 192.8588
# Epoch 23/700
# 56/56 [==============================] - 2s 42ms/step - loss: 186.4918 - mean_absolute_error: 186.4918 - val_loss: 189.2943 - val_mean_absolute_error: 189.2943
# Epoch 24/700
# 56/56 [==============================] - 2s 40ms/step - loss: 185.3654 - mean_absolute_error: 185.3654 - val_loss: 185.3332 - val_mean_absolute_error: 185.3332
# Epoch 25/700
# 56/56 [==============================] - 1s 22ms/step - loss: 179.1125 - mean_absolute_error: 179.1125 - val_loss: 182.1410 - val_mean_absolute_error: 182.1410
# Epoch 26/700
# 56/56 [==============================] - 1s 23ms/step - loss: 175.9538 - mean_absolute_error: 175.9538 - val_loss: 177.5558 - val_mean_absolute_error: 177.5558
# Epoch 27/700
# 56/56 [==============================] - 2s 27ms/step - loss: 171.4039 - mean_absolute_error: 171.4039 - val_loss: 172.7645 - val_mean_absolute_error: 172.7645
# Epoch 28/700
# 56/56 [==============================] - 1s 23ms/step - loss: 170.4389 - mean_absolute_error: 170.4389 - val_loss: 169.5935 - val_mean_absolute_error: 169.5935
# Epoch 29/700
# 56/56 [==============================] - 0s 4ms/step - loss: 165.6006 - mean_absolute_error: 165.6006 - val_loss: 174.3112 - val_mean_absolute_error: 174.3112
# Epoch 30/700
# 56/56 [==============================] - 1s 22ms/step - loss: 163.4487 - mean_absolute_error: 163.4487 - val_loss: 164.9245 - val_mean_absolute_error: 164.9245
# Epoch 31/700
# 56/56 [==============================] - 2s 37ms/step - loss: 162.0556 - mean_absolute_error: 162.0556 - val_loss: 160.9368 - val_mean_absolute_error: 160.9368
# Epoch 32/700
# 56/56 [==============================] - 0s 4ms/step - loss: 157.6198 - mean_absolute_error: 157.6198 - val_loss: 165.2648 - val_mean_absolute_error: 165.2648
# Epoch 33/700
# 56/56 [==============================] - 1s 22ms/step - loss: 153.5642 - mean_absolute_error: 153.5642 - val_loss: 155.0735 - val_mean_absolute_error: 155.0735
# Epoch 34/700
# 56/56 [==============================] - 1s 23ms/step - loss: 149.7200 - mean_absolute_error: 149.7200 - val_loss: 152.7590 - val_mean_absolute_error: 152.7590
# Epoch 35/700
# 56/56 [==============================] - 2s 28ms/step - loss: 147.3989 - mean_absolute_error: 147.3989 - val_loss: 147.6898 - val_mean_absolute_error: 147.6898
# Epoch 36/700
# 56/56 [==============================] - 0s 4ms/step - loss: 144.8328 - mean_absolute_error: 144.8328 - val_loss: 154.7192 - val_mean_absolute_error: 154.7192
# Epoch 37/700
# 56/56 [==============================] - 0s 4ms/step - loss: 141.1875 - mean_absolute_error: 141.1875 - val_loss: 149.8002 - val_mean_absolute_error: 149.8002
# Epoch 38/700
# 56/56 [==============================] - 1s 23ms/step - loss: 139.1503 - mean_absolute_error: 139.1503 - val_loss: 139.0304 - val_mean_absolute_error: 139.0304
# Epoch 39/700
# 56/56 [==============================] - 0s 4ms/step - loss: 136.2647 - mean_absolute_error: 136.2647 - val_loss: 139.4675 - val_mean_absolute_error: 139.4675
# Epoch 40/700
# 56/56 [==============================] - 1s 24ms/step - loss: 131.9437 - mean_absolute_error: 131.9437 - val_loss: 137.8721 - val_mean_absolute_error: 137.8721
# Epoch 41/700
# 56/56 [==============================] - 1s 22ms/step - loss: 130.5645 - mean_absolute_error: 130.5645 - val_loss: 134.9513 - val_mean_absolute_error: 134.9513
# Epoch 42/700
# 56/56 [==============================] - 1s 23ms/step - loss: 128.2948 - mean_absolute_error: 128.2948 - val_loss: 130.2583 - val_mean_absolute_error: 130.2583
# Epoch 43/700
# 56/56 [==============================] - 0s 4ms/step - loss: 128.4971 - mean_absolute_error: 128.4971 - val_loss: 138.1625 - val_mean_absolute_error: 138.1625
# Epoch 44/700
# 56/56 [==============================] - 1s 23ms/step - loss: 122.9134 - mean_absolute_error: 122.9134 - val_loss: 126.0406 - val_mean_absolute_error: 126.0406
# Epoch 45/700
# 56/56 [==============================] - 0s 4ms/step - loss: 122.7735 - mean_absolute_error: 122.7735 - val_loss: 126.7106 - val_mean_absolute_error: 126.7106
# Epoch 46/700
# 56/56 [==============================] - 1s 22ms/step - loss: 118.2228 - mean_absolute_error: 118.2228 - val_loss: 122.5585 - val_mean_absolute_error: 122.5585
# Epoch 47/700
# 56/56 [==============================] - 0s 4ms/step - loss: 116.5626 - mean_absolute_error: 116.5626 - val_loss: 137.8138 - val_mean_absolute_error: 137.8138
# Epoch 48/700
# 56/56 [==============================] - 2s 28ms/step - loss: 114.7301 - mean_absolute_error: 114.7301 - val_loss: 120.6050 - val_mean_absolute_error: 120.6050
# Epoch 49/700
# 56/56 [==============================] - 0s 4ms/step - loss: 112.4290 - mean_absolute_error: 112.4290 - val_loss: 127.5522 - val_mean_absolute_error: 127.5522
# Epoch 50/700
# 56/56 [==============================] - 1s 23ms/step - loss: 111.3090 - mean_absolute_error: 111.3090 - val_loss: 114.1150 - val_mean_absolute_error: 114.1150
# Epoch 51/700
# 56/56 [==============================] - 1s 23ms/step - loss: 110.3912 - mean_absolute_error: 110.3912 - val_loss: 113.9198 - val_mean_absolute_error: 113.9198
# Epoch 52/700
# 56/56 [==============================] - 0s 4ms/step - loss: 110.0444 - mean_absolute_error: 110.0444 - val_loss: 116.5058 - val_mean_absolute_error: 116.5058
# Epoch 53/700
# 56/56 [==============================] - 0s 4ms/step - loss: 105.7483 - mean_absolute_error: 105.7483 - val_loss: 116.5161 - val_mean_absolute_error: 116.5161
# Epoch 54/700
# 56/56 [==============================] - 0s 4ms/step - loss: 104.6594 - mean_absolute_error: 104.6594 - val_loss: 114.1785 - val_mean_absolute_error: 114.1785
# Epoch 55/700
# 56/56 [==============================] - 0s 4ms/step - loss: 103.7539 - mean_absolute_error: 103.7539 - val_loss: 114.1343 - val_mean_absolute_error: 114.1343
# Epoch 56/700
# 56/56 [==============================] - 1s 23ms/step - loss: 102.8505 - mean_absolute_error: 102.8505 - val_loss: 106.5237 - val_mean_absolute_error: 106.5237
# Epoch 57/700
# 56/56 [==============================] - 0s 4ms/step - loss: 104.8730 - mean_absolute_error: 104.8730 - val_loss: 108.9683 - val_mean_absolute_error: 108.9683
# Epoch 58/700
# 56/56 [==============================] - 0s 3ms/step - loss: 101.5083 - mean_absolute_error: 101.5083 - val_loss: 107.0215 - val_mean_absolute_error: 107.0215
# Epoch 59/700
# 56/56 [==============================] - 1s 23ms/step - loss: 99.6184 - mean_absolute_error: 99.6184 - val_loss: 103.0460 - val_mean_absolute_error: 103.0460
# Epoch 60/700
# 56/56 [==============================] - 0s 4ms/step - loss: 99.5288 - mean_absolute_error: 99.5288 - val_loss: 104.5767 - val_mean_absolute_error: 104.5767
# Epoch 61/700
# 56/56 [==============================] - 1s 23ms/step - loss: 96.6603 - mean_absolute_error: 96.6603 - val_loss: 102.5184 - val_mean_absolute_error: 102.5184
# Epoch 62/700
# 56/56 [==============================] - 0s 4ms/step - loss: 97.1839 - mean_absolute_error: 97.1839 - val_loss: 105.4234 - val_mean_absolute_error: 105.4234
# Epoch 63/700
# 56/56 [==============================] - 0s 4ms/step - loss: 97.4414 - mean_absolute_error: 97.4414 - val_loss: 102.8295 - val_mean_absolute_error: 102.8295
# Epoch 64/700
# 56/56 [==============================] - 2s 30ms/step - loss: 96.5302 - mean_absolute_error: 96.5302 - val_loss: 99.6837 - val_mean_absolute_error: 99.6837
# Epoch 65/700
# 56/56 [==============================] - 0s 4ms/step - loss: 95.7262 - mean_absolute_error: 95.7262 - val_loss: 101.8049 - val_mean_absolute_error: 101.8049
# Epoch 66/700
# 56/56 [==============================] - 0s 4ms/step - loss: 94.4080 - mean_absolute_error: 94.4080 - val_loss: 102.9333 - val_mean_absolute_error: 102.9333
# Epoch 67/700
# 56/56 [==============================] - 1s 23ms/step - loss: 93.3202 - mean_absolute_error: 93.3202 - val_loss: 96.9664 - val_mean_absolute_error: 96.9664
# Epoch 68/700
# 56/56 [==============================] - 0s 4ms/step - loss: 93.2875 - mean_absolute_error: 93.2875 - val_loss: 98.2031 - val_mean_absolute_error: 98.2031
# Epoch 69/700
# 56/56 [==============================] - 1s 23ms/step - loss: 91.3265 - mean_absolute_error: 91.3265 - val_loss: 96.4343 - val_mean_absolute_error: 96.4343
# Epoch 70/700
# 56/56 [==============================] - 0s 4ms/step - loss: 93.9062 - mean_absolute_error: 93.9062 - val_loss: 104.7327 - val_mean_absolute_error: 104.7327
# Epoch 71/700
# 56/56 [==============================] - 0s 4ms/step - loss: 91.2202 - mean_absolute_error: 91.2202 - val_loss: 101.2572 - val_mean_absolute_error: 101.2572
# Epoch 72/700
# 56/56 [==============================] - 1s 23ms/step - loss: 91.6981 - mean_absolute_error: 91.6981 - val_loss: 95.2900 - val_mean_absolute_error: 95.2900
# Epoch 73/700
# 56/56 [==============================] - 0s 4ms/step - loss: 94.8589 - mean_absolute_error: 94.8589 - val_loss: 106.8554 - val_mean_absolute_error: 106.8554
# Epoch 74/700
# 56/56 [==============================] - 0s 4ms/step - loss: 89.7747 - mean_absolute_error: 89.7747 - val_loss: 98.3274 - val_mean_absolute_error: 98.3274
# Epoch 75/700
# 56/56 [==============================] - 0s 4ms/step - loss: 89.1298 - mean_absolute_error: 89.1298 - val_loss: 96.5100 - val_mean_absolute_error: 96.5100
# Epoch 76/700
# 56/56 [==============================] - 1s 22ms/step - loss: 90.2215 - mean_absolute_error: 90.2215 - val_loss: 92.7297 - val_mean_absolute_error: 92.7297
# Epoch 77/700
# 56/56 [==============================] - 0s 4ms/step - loss: 88.7600 - mean_absolute_error: 88.7600 - val_loss: 98.2820 - val_mean_absolute_error: 98.2820
# Epoch 78/700
# 56/56 [==============================] - 0s 4ms/step - loss: 91.0087 - mean_absolute_error: 91.0087 - val_loss: 97.6455 - val_mean_absolute_error: 97.6455
# Epoch 79/700
# 56/56 [==============================] - 0s 4ms/step - loss: 88.0861 - mean_absolute_error: 88.0861 - val_loss: 94.0281 - val_mean_absolute_error: 94.0281
# Epoch 80/700
# 56/56 [==============================] - 0s 4ms/step - loss: 91.0108 - mean_absolute_error: 91.0108 - val_loss: 97.1626 - val_mean_absolute_error: 97.1626
# Epoch 81/700
# 56/56 [==============================] - 1s 22ms/step - loss: 87.9977 - mean_absolute_error: 87.9977 - val_loss: 90.3377 - val_mean_absolute_error: 90.3377
# Epoch 82/700
# 56/56 [==============================] - 0s 4ms/step - loss: 87.2967 - mean_absolute_error: 87.2967 - val_loss: 93.5667 - val_mean_absolute_error: 93.5667
# Epoch 83/700
# 56/56 [==============================] - 0s 4ms/step - loss: 90.1882 - mean_absolute_error: 90.1882 - val_loss: 90.6841 - val_mean_absolute_error: 90.6841
# Epoch 84/700
# 56/56 [==============================] - 0s 4ms/step - loss: 86.6164 - mean_absolute_error: 86.6164 - val_loss: 97.8576 - val_mean_absolute_error: 97.8576
# Epoch 85/700
# 56/56 [==============================] - 1s 23ms/step - loss: 87.5055 - mean_absolute_error: 87.5055 - val_loss: 88.0836 - val_mean_absolute_error: 88.0836
# Epoch 86/700
# 56/56 [==============================] - 0s 4ms/step - loss: 88.0872 - mean_absolute_error: 88.0872 - val_loss: 95.0077 - val_mean_absolute_error: 95.0077
# Epoch 87/700
# 56/56 [==============================] - 0s 4ms/step - loss: 87.3392 - mean_absolute_error: 87.3392 - val_loss: 96.2540 - val_mean_absolute_error: 96.2540
# Epoch 88/700
# 56/56 [==============================] - 2s 29ms/step - loss: 87.8730 - mean_absolute_error: 87.8730 - val_loss: 87.8606 - val_mean_absolute_error: 87.8606
# Epoch 89/700
# 56/56 [==============================] - 0s 4ms/step - loss: 84.4708 - mean_absolute_error: 84.4708 - val_loss: 90.6406 - val_mean_absolute_error: 90.6406
# Epoch 90/700
# 56/56 [==============================] - 0s 4ms/step - loss: 85.7144 - mean_absolute_error: 85.7144 - val_loss: 90.6203 - val_mean_absolute_error: 90.6203
# Epoch 91/700
# 56/56 [==============================] - 0s 4ms/step - loss: 85.5294 - mean_absolute_error: 85.5294 - val_loss: 93.4629 - val_mean_absolute_error: 93.4629
# Epoch 92/700
# 56/56 [==============================] - 0s 4ms/step - loss: 86.3095 - mean_absolute_error: 86.3095 - val_loss: 87.9758 - val_mean_absolute_error: 87.9758
# Epoch 93/700
# 56/56 [==============================] - 0s 4ms/step - loss: 85.6942 - mean_absolute_error: 85.6942 - val_loss: 89.4866 - val_mean_absolute_error: 89.4866
# Epoch 94/700
# 56/56 [==============================] - 0s 4ms/step - loss: 84.9798 - mean_absolute_error: 84.9798 - val_loss: 100.0222 - val_mean_absolute_error: 100.0222
# Epoch 95/700
# 56/56 [==============================] - 0s 3ms/step - loss: 85.9630 - mean_absolute_error: 85.9630 - val_loss: 94.4500 - val_mean_absolute_error: 94.4500
# Epoch 96/700
# 56/56 [==============================] - 0s 4ms/step - loss: 84.9805 - mean_absolute_error: 84.9805 - val_loss: 88.9416 - val_mean_absolute_error: 88.9416
# Epoch 97/700
# 56/56 [==============================] - 1s 23ms/step - loss: 84.8701 - mean_absolute_error: 84.8701 - val_loss: 86.8240 - val_mean_absolute_error: 86.8240
# Epoch 98/700
# 56/56 [==============================] - 0s 4ms/step - loss: 84.2236 - mean_absolute_error: 84.2236 - val_loss: 90.0048 - val_mean_absolute_error: 90.0048
# Epoch 99/700
# 56/56 [==============================] - 0s 4ms/step - loss: 85.7514 - mean_absolute_error: 85.7514 - val_loss: 99.8439 - val_mean_absolute_error: 99.8439
# Epoch 100/700
# 56/56 [==============================] - 0s 4ms/step - loss: 84.2191 - mean_absolute_error: 84.2191 - val_loss: 88.6647 - val_mean_absolute_error: 88.6647
# Epoch 101/700
# 56/56 [==============================] - 0s 4ms/step - loss: 86.3237 - mean_absolute_error: 86.3237 - val_loss: 88.6645 - val_mean_absolute_error: 88.6645
# Epoch 102/700
# 56/56 [==============================] - 0s 4ms/step - loss: 86.4678 - mean_absolute_error: 86.4678 - val_loss: 103.0571 - val_mean_absolute_error: 103.0571
# Epoch 103/700
# 56/56 [==============================] - 0s 4ms/step - loss: 82.8479 - mean_absolute_error: 82.8479 - val_loss: 86.9697 - val_mean_absolute_error: 86.9697
# Epoch 104/700
# 56/56 [==============================] - 0s 4ms/step - loss: 85.1012 - mean_absolute_error: 85.1012 - val_loss: 90.2325 - val_mean_absolute_error: 90.2325
# Epoch 105/700
# 56/56 [==============================] - 0s 4ms/step - loss: 83.8067 - mean_absolute_error: 83.8067 - val_loss: 92.9530 - val_mean_absolute_error: 92.9530
# Epoch 106/700
# 56/56 [==============================] - 0s 4ms/step - loss: 81.5483 - mean_absolute_error: 81.5483 - val_loss: 90.6096 - val_mean_absolute_error: 90.6096
# Epoch 107/700
# 56/56 [==============================] - 1s 22ms/step - loss: 80.3928 - mean_absolute_error: 80.3928 - val_loss: 85.3714 - val_mean_absolute_error: 85.3714
# Epoch 108/700
# 56/56 [==============================] - 1s 22ms/step - loss: 81.1673 - mean_absolute_error: 81.1673 - val_loss: 84.3950 - val_mean_absolute_error: 84.3950
# Epoch 109/700
# 56/56 [==============================] - 0s 4ms/step - loss: 81.7781 - mean_absolute_error: 81.7781 - val_loss: 92.2968 - val_mean_absolute_error: 92.2968
# Epoch 110/700
# 56/56 [==============================] - 0s 4ms/step - loss: 81.4032 - mean_absolute_error: 81.4032 - val_loss: 85.4604 - val_mean_absolute_error: 85.4604
# Epoch 111/700
# 56/56 [==============================] - 0s 3ms/step - loss: 81.4002 - mean_absolute_error: 81.4002 - val_loss: 91.7516 - val_mean_absolute_error: 91.7516
# Epoch 112/700
# 56/56 [==============================] - 0s 4ms/step - loss: 81.1286 - mean_absolute_error: 81.1286 - val_loss: 102.0263 - val_mean_absolute_error: 102.0263
# Epoch 113/700
# 56/56 [==============================] - 1s 23ms/step - loss: 83.3984 - mean_absolute_error: 83.3984 - val_loss: 83.7939 - val_mean_absolute_error: 83.7939
# Epoch 114/700
# 56/56 [==============================] - 0s 4ms/step - loss: 83.2370 - mean_absolute_error: 83.2370 - val_loss: 98.5162 - val_mean_absolute_error: 98.5162
# Epoch 115/700
# 56/56 [==============================] - 1s 23ms/step - loss: 82.0074 - mean_absolute_error: 82.0074 - val_loss: 81.4768 - val_mean_absolute_error: 81.4768
# Epoch 116/700
# 56/56 [==============================] - 0s 4ms/step - loss: 80.3686 - mean_absolute_error: 80.3686 - val_loss: 86.8405 - val_mean_absolute_error: 86.8405
# Epoch 117/700
# 56/56 [==============================] - 0s 4ms/step - loss: 81.1142 - mean_absolute_error: 81.1142 - val_loss: 86.2464 - val_mean_absolute_error: 86.2464
# Epoch 118/700
# 56/56 [==============================] - 0s 4ms/step - loss: 81.9200 - mean_absolute_error: 81.9200 - val_loss: 83.2524 - val_mean_absolute_error: 83.2524
# Epoch 119/700
# 56/56 [==============================] - 0s 4ms/step - loss: 80.8799 - mean_absolute_error: 80.8799 - val_loss: 81.7367 - val_mean_absolute_error: 81.7367
# Epoch 120/700
# 56/56 [==============================] - 0s 4ms/step - loss: 77.5834 - mean_absolute_error: 77.5834 - val_loss: 85.9539 - val_mean_absolute_error: 85.9539
# Epoch 121/700
# 56/56 [==============================] - 1s 23ms/step - loss: 79.1270 - mean_absolute_error: 79.1270 - val_loss: 80.1980 - val_mean_absolute_error: 80.1980
# Epoch 122/700
# 56/56 [==============================] - 0s 4ms/step - loss: 77.7515 - mean_absolute_error: 77.7515 - val_loss: 86.9063 - val_mean_absolute_error: 86.9063
# Epoch 123/700
# 56/56 [==============================] - 0s 4ms/step - loss: 77.8898 - mean_absolute_error: 77.8898 - val_loss: 82.0063 - val_mean_absolute_error: 82.0063
# Epoch 124/700
# 56/56 [==============================] - 0s 4ms/step - loss: 77.6637 - mean_absolute_error: 77.6637 - val_loss: 87.9929 - val_mean_absolute_error: 87.9929
# Epoch 125/700
# 56/56 [==============================] - 0s 4ms/step - loss: 78.3567 - mean_absolute_error: 78.3567 - val_loss: 87.0420 - val_mean_absolute_error: 87.0420
# Epoch 126/700
# 56/56 [==============================] - 2s 29ms/step - loss: 78.0517 - mean_absolute_error: 78.0517 - val_loss: 78.0890 - val_mean_absolute_error: 78.0890
# Epoch 127/700
# 56/56 [==============================] - 0s 4ms/step - loss: 77.0158 - mean_absolute_error: 77.0158 - val_loss: 83.2123 - val_mean_absolute_error: 83.2123
# Epoch 128/700
# 56/56 [==============================] - 0s 4ms/step - loss: 79.3334 - mean_absolute_error: 79.3334 - val_loss: 80.0141 - val_mean_absolute_error: 80.0141
# Epoch 129/700
# 56/56 [==============================] - 0s 4ms/step - loss: 82.6899 - mean_absolute_error: 82.6899 - val_loss: 90.6609 - val_mean_absolute_error: 90.6609
# Epoch 130/700
# 56/56 [==============================] - 0s 4ms/step - loss: 78.7529 - mean_absolute_error: 78.7529 - val_loss: 80.6271 - val_mean_absolute_error: 80.6271
# Epoch 131/700
# 56/56 [==============================] - 0s 4ms/step - loss: 75.5154 - mean_absolute_error: 75.5154 - val_loss: 84.7365 - val_mean_absolute_error: 84.7365
# Epoch 132/700
# 56/56 [==============================] - 0s 4ms/step - loss: 77.2409 - mean_absolute_error: 77.2409 - val_loss: 83.5642 - val_mean_absolute_error: 83.5642
# Epoch 133/700
# 56/56 [==============================] - 0s 4ms/step - loss: 79.4589 - mean_absolute_error: 79.4589 - val_loss: 81.8500 - val_mean_absolute_error: 81.8500
# Epoch 134/700
# 56/56 [==============================] - 0s 4ms/step - loss: 79.2501 - mean_absolute_error: 79.2501 - val_loss: 86.7662 - val_mean_absolute_error: 86.7662
# Epoch 135/700
# 56/56 [==============================] - 0s 4ms/step - loss: 76.8130 - mean_absolute_error: 76.8130 - val_loss: 80.0444 - val_mean_absolute_error: 80.0444
# Epoch 136/700
# 56/56 [==============================] - 0s 4ms/step - loss: 75.4089 - mean_absolute_error: 75.4089 - val_loss: 79.4926 - val_mean_absolute_error: 79.4926
# Epoch 137/700
# 56/56 [==============================] - 1s 23ms/step - loss: 75.2443 - mean_absolute_error: 75.2443 - val_loss: 77.2444 - val_mean_absolute_error: 77.2444
# Epoch 138/700
# 56/56 [==============================] - 1s 22ms/step - loss: 74.9850 - mean_absolute_error: 74.9850 - val_loss: 76.6764 - val_mean_absolute_error: 76.6764
# Epoch 139/700
# 56/56 [==============================] - 0s 4ms/step - loss: 76.2855 - mean_absolute_error: 76.2855 - val_loss: 100.8145 - val_mean_absolute_error: 100.8145
# Epoch 140/700
# 56/56 [==============================] - 0s 4ms/step - loss: 76.6408 - mean_absolute_error: 76.6408 - val_loss: 79.2582 - val_mean_absolute_error: 79.2582
# Epoch 141/700
# 56/56 [==============================] - 0s 4ms/step - loss: 73.4196 - mean_absolute_error: 73.4196 - val_loss: 81.4246 - val_mean_absolute_error: 81.4246
# Epoch 142/700
# 56/56 [==============================] - 0s 4ms/step - loss: 75.6603 - mean_absolute_error: 75.6603 - val_loss: 79.5024 - val_mean_absolute_error: 79.5024
# Epoch 143/700
# 56/56 [==============================] - 0s 4ms/step - loss: 74.1785 - mean_absolute_error: 74.1785 - val_loss: 83.4312 - val_mean_absolute_error: 83.4312
# Epoch 144/700
# 56/56 [==============================] - 1s 23ms/step - loss: 73.2898 - mean_absolute_error: 73.2898 - val_loss: 76.6084 - val_mean_absolute_error: 76.6084
# Epoch 145/700
# 56/56 [==============================] - 0s 4ms/step - loss: 73.6515 - mean_absolute_error: 73.6515 - val_loss: 80.4505 - val_mean_absolute_error: 80.4505
# Epoch 146/700
# 56/56 [==============================] - 1s 22ms/step - loss: 73.8877 - mean_absolute_error: 73.8877 - val_loss: 75.5919 - val_mean_absolute_error: 75.5919
# Epoch 147/700
# 56/56 [==============================] - 0s 4ms/step - loss: 74.1416 - mean_absolute_error: 74.1416 - val_loss: 88.2272 - val_mean_absolute_error: 88.2272
# Epoch 148/700
# 56/56 [==============================] - 1s 22ms/step - loss: 76.7896 - mean_absolute_error: 76.7896 - val_loss: 74.9732 - val_mean_absolute_error: 74.9732
# Epoch 149/700
# 56/56 [==============================] - 0s 4ms/step - loss: 73.8405 - mean_absolute_error: 73.8405 - val_loss: 79.7539 - val_mean_absolute_error: 79.7539
# Epoch 150/700
# 56/56 [==============================] - 0s 4ms/step - loss: 75.2582 - mean_absolute_error: 75.2582 - val_loss: 76.7427 - val_mean_absolute_error: 76.7427
# Epoch 151/700
# 56/56 [==============================] - 0s 4ms/step - loss: 72.5400 - mean_absolute_error: 72.5400 - val_loss: 83.0565 - val_mean_absolute_error: 83.0565
# Epoch 152/700
# 56/56 [==============================] - 0s 4ms/step - loss: 76.4668 - mean_absolute_error: 76.4668 - val_loss: 75.2951 - val_mean_absolute_error: 75.2951
# Epoch 153/700
# 56/56 [==============================] - 0s 4ms/step - loss: 74.5504 - mean_absolute_error: 74.5504 - val_loss: 80.0043 - val_mean_absolute_error: 80.0043
# Epoch 154/700
# 56/56 [==============================] - 0s 4ms/step - loss: 76.4960 - mean_absolute_error: 76.4960 - val_loss: 80.9403 - val_mean_absolute_error: 80.9403
# Epoch 155/700
# 56/56 [==============================] - 0s 4ms/step - loss: 77.0293 - mean_absolute_error: 77.0293 - val_loss: 81.7334 - val_mean_absolute_error: 81.7334
# Epoch 156/700
# 56/56 [==============================] - 2s 28ms/step - loss: 76.1005 - mean_absolute_error: 76.1005 - val_loss: 74.3247 - val_mean_absolute_error: 74.3247
# Epoch 157/700
# 56/56 [==============================] - 0s 4ms/step - loss: 72.1677 - mean_absolute_error: 72.1677 - val_loss: 75.2108 - val_mean_absolute_error: 75.2108
# Epoch 158/700
# 56/56 [==============================] - 0s 4ms/step - loss: 76.4695 - mean_absolute_error: 76.4695 - val_loss: 80.3388 - val_mean_absolute_error: 80.3388
# Epoch 159/700
# 56/56 [==============================] - 0s 4ms/step - loss: 72.7990 - mean_absolute_error: 72.7990 - val_loss: 78.7722 - val_mean_absolute_error: 78.7722
# Epoch 160/700
# 56/56 [==============================] - 0s 4ms/step - loss: 72.3105 - mean_absolute_error: 72.3105 - val_loss: 80.7942 - val_mean_absolute_error: 80.7942
# Epoch 161/700
# 56/56 [==============================] - 0s 4ms/step - loss: 72.1018 - mean_absolute_error: 72.1018 - val_loss: 85.2423 - val_mean_absolute_error: 85.2423
# Epoch 162/700
# 56/56 [==============================] - 1s 22ms/step - loss: 73.1845 - mean_absolute_error: 73.1845 - val_loss: 74.1424 - val_mean_absolute_error: 74.1424
# Epoch 163/700
# 56/56 [==============================] - 0s 4ms/step - loss: 71.0950 - mean_absolute_error: 71.0950 - val_loss: 75.7590 - val_mean_absolute_error: 75.7590
# Epoch 164/700
# 56/56 [==============================] - 0s 4ms/step - loss: 72.6543 - mean_absolute_error: 72.6543 - val_loss: 77.3931 - val_mean_absolute_error: 77.3931
# Epoch 165/700
# 56/56 [==============================] - 0s 4ms/step - loss: 71.1599 - mean_absolute_error: 71.1599 - val_loss: 77.0239 - val_mean_absolute_error: 77.0239
# Epoch 166/700
# 56/56 [==============================] - 0s 3ms/step - loss: 70.9411 - mean_absolute_error: 70.9411 - val_loss: 76.3802 - val_mean_absolute_error: 76.3802
# Epoch 167/700
# 56/56 [==============================] - 0s 4ms/step - loss: 71.0827 - mean_absolute_error: 71.0827 - val_loss: 78.0829 - val_mean_absolute_error: 78.0829
# Epoch 168/700
# 56/56 [==============================] - 0s 4ms/step - loss: 70.4644 - mean_absolute_error: 70.4644 - val_loss: 81.1633 - val_mean_absolute_error: 81.1633
# Epoch 169/700
# 56/56 [==============================] - 0s 4ms/step - loss: 70.8797 - mean_absolute_error: 70.8797 - val_loss: 75.8271 - val_mean_absolute_error: 75.8271
# Epoch 170/700
# 56/56 [==============================] - 1s 22ms/step - loss: 72.5841 - mean_absolute_error: 72.5841 - val_loss: 71.7497 - val_mean_absolute_error: 71.7497
# Epoch 171/700
# 56/56 [==============================] - 0s 4ms/step - loss: 73.6958 - mean_absolute_error: 73.6958 - val_loss: 81.5552 - val_mean_absolute_error: 81.5552
# Epoch 172/700
# 56/56 [==============================] - 0s 4ms/step - loss: 74.6118 - mean_absolute_error: 74.6118 - val_loss: 73.9836 - val_mean_absolute_error: 73.9836
# Epoch 173/700
# 56/56 [==============================] - 0s 4ms/step - loss: 71.8747 - mean_absolute_error: 71.8747 - val_loss: 72.5126 - val_mean_absolute_error: 72.5126
# Epoch 174/700
# 56/56 [==============================] - 1s 22ms/step - loss: 70.7037 - mean_absolute_error: 70.7037 - val_loss: 70.8505 - val_mean_absolute_error: 70.8505
# Epoch 175/700
# 56/56 [==============================] - 0s 4ms/step - loss: 71.6369 - mean_absolute_error: 71.6369 - val_loss: 130.5923 - val_mean_absolute_error: 130.5923
# Epoch 176/700
# 56/56 [==============================] - 0s 4ms/step - loss: 77.0791 - mean_absolute_error: 77.0791 - val_loss: 72.8463 - val_mean_absolute_error: 72.8463
# Epoch 177/700
# 56/56 [==============================] - 0s 4ms/step - loss: 72.2426 - mean_absolute_error: 72.2426 - val_loss: 77.7278 - val_mean_absolute_error: 77.7278
# Epoch 178/700
# 56/56 [==============================] - 1s 23ms/step - loss: 74.0572 - mean_absolute_error: 74.0572 - val_loss: 70.5883 - val_mean_absolute_error: 70.5883
# Epoch 179/700
# 56/56 [==============================] - 0s 4ms/step - loss: 72.3463 - mean_absolute_error: 72.3463 - val_loss: 72.5903 - val_mean_absolute_error: 72.5903
# Epoch 180/700
# 56/56 [==============================] - 0s 4ms/step - loss: 69.8428 - mean_absolute_error: 69.8428 - val_loss: 77.8988 - val_mean_absolute_error: 77.8988
# Epoch 181/700
# 56/56 [==============================] - 0s 4ms/step - loss: 73.1816 - mean_absolute_error: 73.1816 - val_loss: 76.1465 - val_mean_absolute_error: 76.1465
# Epoch 182/700
# 56/56 [==============================] - 0s 3ms/step - loss: 68.9577 - mean_absolute_error: 68.9577 - val_loss: 74.2913 - val_mean_absolute_error: 74.2913
# Epoch 183/700
# 56/56 [==============================] - 0s 4ms/step - loss: 69.7303 - mean_absolute_error: 69.7303 - val_loss: 75.1004 - val_mean_absolute_error: 75.1004
# Epoch 184/700
# 56/56 [==============================] - 0s 4ms/step - loss: 70.2722 - mean_absolute_error: 70.2722 - val_loss: 74.0660 - val_mean_absolute_error: 74.0660
# Epoch 185/700
# 56/56 [==============================] - 0s 4ms/step - loss: 70.4113 - mean_absolute_error: 70.4113 - val_loss: 75.3877 - val_mean_absolute_error: 75.3877
# Epoch 186/700
# 56/56 [==============================] - 0s 4ms/step - loss: 72.2119 - mean_absolute_error: 72.2119 - val_loss: 85.6032 - val_mean_absolute_error: 85.6032
# Epoch 187/700
# 56/56 [==============================] - 1s 23ms/step - loss: 67.7201 - mean_absolute_error: 67.7201 - val_loss: 69.3651 - val_mean_absolute_error: 69.3651
# Epoch 188/700
# 56/56 [==============================] - 0s 4ms/step - loss: 69.6258 - mean_absolute_error: 69.6258 - val_loss: 72.7738 - val_mean_absolute_error: 72.7738
# Epoch 189/700
# 56/56 [==============================] - 0s 4ms/step - loss: 70.2492 - mean_absolute_error: 70.2492 - val_loss: 70.3728 - val_mean_absolute_error: 70.3728
# Epoch 190/700
# 56/56 [==============================] - 0s 4ms/step - loss: 68.6803 - mean_absolute_error: 68.6803 - val_loss: 82.9603 - val_mean_absolute_error: 82.9603
# Epoch 191/700
# 56/56 [==============================] - 1s 23ms/step - loss: 69.5441 - mean_absolute_error: 69.5441 - val_loss: 68.2397 - val_mean_absolute_error: 68.2397
# Epoch 192/700
# 56/56 [==============================] - 0s 4ms/step - loss: 68.3709 - mean_absolute_error: 68.3709 - val_loss: 77.6885 - val_mean_absolute_error: 77.6885
# Epoch 193/700
# 56/56 [==============================] - 0s 4ms/step - loss: 71.2765 - mean_absolute_error: 71.2765 - val_loss: 69.4039 - val_mean_absolute_error: 69.4039
# Epoch 194/700
# 56/56 [==============================] - 0s 4ms/step - loss: 68.6613 - mean_absolute_error: 68.6613 - val_loss: 69.1735 - val_mean_absolute_error: 69.1735
# Epoch 195/700
# 56/56 [==============================] - 0s 4ms/step - loss: 67.4763 - mean_absolute_error: 67.4763 - val_loss: 84.6313 - val_mean_absolute_error: 84.6313
# Epoch 196/700
# 56/56 [==============================] - 0s 6ms/step - loss: 69.9052 - mean_absolute_error: 69.9052 - val_loss: 85.7582 - val_mean_absolute_error: 85.7582
# Epoch 197/700
# 56/56 [==============================] - 0s 6ms/step - loss: 68.9490 - mean_absolute_error: 68.9490 - val_loss: 87.2113 - val_mean_absolute_error: 87.2113
# Epoch 198/700
# 56/56 [==============================] - 0s 6ms/step - loss: 68.3100 - mean_absolute_error: 68.3100 - val_loss: 71.3492 - val_mean_absolute_error: 71.3492
# Epoch 199/700
# 56/56 [==============================] - 0s 6ms/step - loss: 67.8937 - mean_absolute_error: 67.8937 - val_loss: 69.7802 - val_mean_absolute_error: 69.7802
# Epoch 200/700
# 56/56 [==============================] - 0s 6ms/step - loss: 69.0521 - mean_absolute_error: 69.0521 - val_loss: 74.0797 - val_mean_absolute_error: 74.0797
# Epoch 201/700
# 56/56 [==============================] - 0s 7ms/step - loss: 68.0211 - mean_absolute_error: 68.0211 - val_loss: 71.2643 - val_mean_absolute_error: 71.2643
# Epoch 202/700
# 56/56 [==============================] - 0s 7ms/step - loss: 67.0758 - mean_absolute_error: 67.0758 - val_loss: 77.2640 - val_mean_absolute_error: 77.2640
# Epoch 203/700
# 56/56 [==============================] - 0s 7ms/step - loss: 66.9747 - mean_absolute_error: 66.9747 - val_loss: 78.4617 - val_mean_absolute_error: 78.4617
# Epoch 204/700
# 56/56 [==============================] - 2s 36ms/step - loss: 69.3991 - mean_absolute_error: 69.3991 - val_loss: 66.2729 - val_mean_absolute_error: 66.2729
# Epoch 205/700
# 56/56 [==============================] - 0s 4ms/step - loss: 66.4708 - mean_absolute_error: 66.4708 - val_loss: 73.6874 - val_mean_absolute_error: 73.6874
# Epoch 206/700
# 56/56 [==============================] - 0s 4ms/step - loss: 67.4446 - mean_absolute_error: 67.4446 - val_loss: 69.3547 - val_mean_absolute_error: 69.3547
# Epoch 207/700
# 56/56 [==============================] - 0s 4ms/step - loss: 66.3526 - mean_absolute_error: 66.3526 - val_loss: 70.5777 - val_mean_absolute_error: 70.5777
# Epoch 208/700
# 56/56 [==============================] - 1s 23ms/step - loss: 65.4928 - mean_absolute_error: 65.4928 - val_loss: 65.4266 - val_mean_absolute_error: 65.4266
# Epoch 209/700
# 56/56 [==============================] - 0s 5ms/step - loss: 65.3651 - mean_absolute_error: 65.3651 - val_loss: 72.2666 - val_mean_absolute_error: 72.2666
# Epoch 210/700
# 56/56 [==============================] - 0s 4ms/step - loss: 65.7223 - mean_absolute_error: 65.7223 - val_loss: 72.0862 - val_mean_absolute_error: 72.0862
# Epoch 211/700
# 56/56 [==============================] - 0s 5ms/step - loss: 66.3730 - mean_absolute_error: 66.3730 - val_loss: 69.8781 - val_mean_absolute_error: 69.8781
# Epoch 212/700
# 56/56 [==============================] - 0s 4ms/step - loss: 67.2841 - mean_absolute_error: 67.2841 - val_loss: 70.4432 - val_mean_absolute_error: 70.4432
# Epoch 213/700
# 56/56 [==============================] - 0s 4ms/step - loss: 66.7459 - mean_absolute_error: 66.7459 - val_loss: 67.8782 - val_mean_absolute_error: 67.8782
# Epoch 214/700
# 56/56 [==============================] - 0s 4ms/step - loss: 67.7823 - mean_absolute_error: 67.7823 - val_loss: 65.7070 - val_mean_absolute_error: 65.7070
# Epoch 215/700
# 56/56 [==============================] - 0s 4ms/step - loss: 67.8024 - mean_absolute_error: 67.8024 - val_loss: 74.9986 - val_mean_absolute_error: 74.9986
# Epoch 216/700
# 56/56 [==============================] - 0s 4ms/step - loss: 67.3248 - mean_absolute_error: 67.3248 - val_loss: 67.3544 - val_mean_absolute_error: 67.3544
# Epoch 217/700
# 56/56 [==============================] - 0s 4ms/step - loss: 64.4500 - mean_absolute_error: 64.4500 - val_loss: 66.1115 - val_mean_absolute_error: 66.1115
# Epoch 218/700
# 56/56 [==============================] - 0s 4ms/step - loss: 67.7589 - mean_absolute_error: 67.7589 - val_loss: 78.7444 - val_mean_absolute_error: 78.7444
# Epoch 219/700
# 56/56 [==============================] - 0s 4ms/step - loss: 67.8403 - mean_absolute_error: 67.8403 - val_loss: 67.2354 - val_mean_absolute_error: 67.2354
# Epoch 220/700
# 56/56 [==============================] - 0s 4ms/step - loss: 65.4632 - mean_absolute_error: 65.4632 - val_loss: 89.3372 - val_mean_absolute_error: 89.3372
# Epoch 221/700
# 56/56 [==============================] - 0s 4ms/step - loss: 67.4027 - mean_absolute_error: 67.4027 - val_loss: 70.5432 - val_mean_absolute_error: 70.5432
# Epoch 222/700
# 56/56 [==============================] - 0s 4ms/step - loss: 67.8584 - mean_absolute_error: 67.8584 - val_loss: 71.6856 - val_mean_absolute_error: 71.6856
# Epoch 223/700
# 56/56 [==============================] - 0s 4ms/step - loss: 64.5451 - mean_absolute_error: 64.5451 - val_loss: 69.5951 - val_mean_absolute_error: 69.5951
# Epoch 224/700
# 56/56 [==============================] - 0s 4ms/step - loss: 65.4773 - mean_absolute_error: 65.4773 - val_loss: 77.6652 - val_mean_absolute_error: 77.6652
# Epoch 225/700
# 56/56 [==============================] - 0s 4ms/step - loss: 65.4484 - mean_absolute_error: 65.4484 - val_loss: 77.4759 - val_mean_absolute_error: 77.4759
# Epoch 226/700
# 56/56 [==============================] - 0s 4ms/step - loss: 65.0063 - mean_absolute_error: 65.0063 - val_loss: 66.5604 - val_mean_absolute_error: 66.5604
# Epoch 227/700
# 56/56 [==============================] - 0s 4ms/step - loss: 64.5519 - mean_absolute_error: 64.5519 - val_loss: 68.3851 - val_mean_absolute_error: 68.3851
# Epoch 228/700
# 56/56 [==============================] - 0s 4ms/step - loss: 65.5252 - mean_absolute_error: 65.5252 - val_loss: 76.8699 - val_mean_absolute_error: 76.8699
# Epoch 229/700
# 56/56 [==============================] - 0s 4ms/step - loss: 65.4974 - mean_absolute_error: 65.4974 - val_loss: 65.4277 - val_mean_absolute_error: 65.4277
# Epoch 230/700
# 56/56 [==============================] - 0s 4ms/step - loss: 64.6243 - mean_absolute_error: 64.6243 - val_loss: 65.8541 - val_mean_absolute_error: 65.8541
# Epoch 231/700
# 56/56 [==============================] - 1s 23ms/step - loss: 63.1088 - mean_absolute_error: 63.1088 - val_loss: 64.6109 - val_mean_absolute_error: 64.6109
# Epoch 232/700
# 56/56 [==============================] - 0s 4ms/step - loss: 64.4071 - mean_absolute_error: 64.4071 - val_loss: 67.5954 - val_mean_absolute_error: 67.5954
# Epoch 233/700
# 56/56 [==============================] - 0s 4ms/step - loss: 68.1064 - mean_absolute_error: 68.1064 - val_loss: 68.5817 - val_mean_absolute_error: 68.5817
# Epoch 234/700
# 56/56 [==============================] - 0s 4ms/step - loss: 67.2539 - mean_absolute_error: 67.2539 - val_loss: 69.2478 - val_mean_absolute_error: 69.2478
# Epoch 235/700
# 56/56 [==============================] - 0s 4ms/step - loss: 63.7852 - mean_absolute_error: 63.7852 - val_loss: 70.3965 - val_mean_absolute_error: 70.3965
# Epoch 236/700
# 56/56 [==============================] - 0s 4ms/step - loss: 63.0799 - mean_absolute_error: 63.0799 - val_loss: 64.9507 - val_mean_absolute_error: 64.9507
# Epoch 237/700
# 56/56 [==============================] - 0s 4ms/step - loss: 66.9436 - mean_absolute_error: 66.9436 - val_loss: 67.1236 - val_mean_absolute_error: 67.1236
# Epoch 238/700
# 56/56 [==============================] - 0s 4ms/step - loss: 63.1018 - mean_absolute_error: 63.1018 - val_loss: 71.6776 - val_mean_absolute_error: 71.6776
# Epoch 239/700
# 56/56 [==============================] - 0s 4ms/step - loss: 63.0823 - mean_absolute_error: 63.0823 - val_loss: 66.3649 - val_mean_absolute_error: 66.3649
# Epoch 240/700
# 56/56 [==============================] - 0s 4ms/step - loss: 65.6465 - mean_absolute_error: 65.6465 - val_loss: 67.6846 - val_mean_absolute_error: 67.6846
# Epoch 241/700
# 56/56 [==============================] - 0s 4ms/step - loss: 63.3901 - mean_absolute_error: 63.3901 - val_loss: 76.7089 - val_mean_absolute_error: 76.7089
# Epoch 242/700
# 56/56 [==============================] - 0s 4ms/step - loss: 65.3311 - mean_absolute_error: 65.3311 - val_loss: 70.2952 - val_mean_absolute_error: 70.2952
# Epoch 243/700
# 56/56 [==============================] - 0s 4ms/step - loss: 63.2348 - mean_absolute_error: 63.2348 - val_loss: 80.2379 - val_mean_absolute_error: 80.2379
# Epoch 244/700
# 56/56 [==============================] - 0s 4ms/step - loss: 61.3433 - mean_absolute_error: 61.3433 - val_loss: 74.4810 - val_mean_absolute_error: 74.4810
# Epoch 245/700
# 56/56 [==============================] - 0s 4ms/step - loss: 65.6074 - mean_absolute_error: 65.6074 - val_loss: 66.2309 - val_mean_absolute_error: 66.2309
# Epoch 246/700
# 56/56 [==============================] - 1s 23ms/step - loss: 60.9983 - mean_absolute_error: 60.9983 - val_loss: 63.1902 - val_mean_absolute_error: 63.1902
# Epoch 247/700
# 56/56 [==============================] - 0s 4ms/step - loss: 64.3093 - mean_absolute_error: 64.3093 - val_loss: 67.2429 - val_mean_absolute_error: 67.2429
# Epoch 248/700
# 56/56 [==============================] - 0s 4ms/step - loss: 63.3301 - mean_absolute_error: 63.3301 - val_loss: 66.6543 - val_mean_absolute_error: 66.6543
# Epoch 249/700
# 56/56 [==============================] - 0s 4ms/step - loss: 61.6150 - mean_absolute_error: 61.6150 - val_loss: 70.6638 - val_mean_absolute_error: 70.6638
# Epoch 250/700
# 56/56 [==============================] - 0s 4ms/step - loss: 63.8579 - mean_absolute_error: 63.8579 - val_loss: 63.3981 - val_mean_absolute_error: 63.3981
# Epoch 251/700
# 56/56 [==============================] - 1s 23ms/step - loss: 62.9218 - mean_absolute_error: 62.9218 - val_loss: 63.0023 - val_mean_absolute_error: 63.0023
# Epoch 252/700
# 56/56 [==============================] - 0s 4ms/step - loss: 62.0492 - mean_absolute_error: 62.0492 - val_loss: 72.1475 - val_mean_absolute_error: 72.1475
# Epoch 253/700
# 56/56 [==============================] - 0s 4ms/step - loss: 62.5447 - mean_absolute_error: 62.5447 - val_loss: 63.1833 - val_mean_absolute_error: 63.1833
# Epoch 254/700
# 56/56 [==============================] - 1s 23ms/step - loss: 61.8562 - mean_absolute_error: 61.8562 - val_loss: 62.6375 - val_mean_absolute_error: 62.6375
# Epoch 255/700
# 56/56 [==============================] - 0s 4ms/step - loss: 59.0643 - mean_absolute_error: 59.0643 - val_loss: 62.9715 - val_mean_absolute_error: 62.9715
# Epoch 256/700
# 56/56 [==============================] - 0s 4ms/step - loss: 60.2740 - mean_absolute_error: 60.2740 - val_loss: 62.7778 - val_mean_absolute_error: 62.7778
# Epoch 257/700
# 56/56 [==============================] - 0s 4ms/step - loss: 63.6980 - mean_absolute_error: 63.6980 - val_loss: 62.9797 - val_mean_absolute_error: 62.9797
# Epoch 258/700
# 56/56 [==============================] - 2s 28ms/step - loss: 62.5535 - mean_absolute_error: 62.5535 - val_loss: 62.3469 - val_mean_absolute_error: 62.3469
# Epoch 259/700
# 56/56 [==============================] - 0s 4ms/step - loss: 60.8435 - mean_absolute_error: 60.8435 - val_loss: 64.0027 - val_mean_absolute_error: 64.0027
# Epoch 260/700
# 56/56 [==============================] - 0s 4ms/step - loss: 64.7554 - mean_absolute_error: 64.7554 - val_loss: 64.2296 - val_mean_absolute_error: 64.2296
# Epoch 261/700
# 56/56 [==============================] - 1s 23ms/step - loss: 61.8341 - mean_absolute_error: 61.8341 - val_loss: 60.2718 - val_mean_absolute_error: 60.2718
# Epoch 262/700
# 56/56 [==============================] - 0s 4ms/step - loss: 61.9116 - mean_absolute_error: 61.9116 - val_loss: 66.3728 - val_mean_absolute_error: 66.3728
# Epoch 263/700
# 56/56 [==============================] - 0s 4ms/step - loss: 59.9470 - mean_absolute_error: 59.9470 - val_loss: 72.3212 - val_mean_absolute_error: 72.3212
# Epoch 264/700
# 56/56 [==============================] - 0s 4ms/step - loss: 60.8096 - mean_absolute_error: 60.8096 - val_loss: 71.0873 - val_mean_absolute_error: 71.0873
# Epoch 265/700
# 56/56 [==============================] - 0s 4ms/step - loss: 61.7949 - mean_absolute_error: 61.7949 - val_loss: 62.3612 - val_mean_absolute_error: 62.3612
# Epoch 266/700
# 56/56 [==============================] - 0s 4ms/step - loss: 62.6940 - mean_absolute_error: 62.6940 - val_loss: 71.6493 - val_mean_absolute_error: 71.6493
# Epoch 267/700
# 56/56 [==============================] - 0s 4ms/step - loss: 62.1944 - mean_absolute_error: 62.1944 - val_loss: 60.7502 - val_mean_absolute_error: 60.7502
# Epoch 268/700
# 56/56 [==============================] - 0s 4ms/step - loss: 60.4105 - mean_absolute_error: 60.4105 - val_loss: 63.9523 - val_mean_absolute_error: 63.9523
# Epoch 269/700
# 56/56 [==============================] - 0s 4ms/step - loss: 59.9303 - mean_absolute_error: 59.9303 - val_loss: 61.9716 - val_mean_absolute_error: 61.9716
# Epoch 270/700
# 56/56 [==============================] - 0s 4ms/step - loss: 61.3871 - mean_absolute_error: 61.3871 - val_loss: 61.6040 - val_mean_absolute_error: 61.6040
# Epoch 271/700
# 56/56 [==============================] - 0s 4ms/step - loss: 60.6046 - mean_absolute_error: 60.6046 - val_loss: 67.4029 - val_mean_absolute_error: 67.4029
# Epoch 272/700
# 56/56 [==============================] - 1s 23ms/step - loss: 59.0129 - mean_absolute_error: 59.0129 - val_loss: 59.3587 - val_mean_absolute_error: 59.3587
# Epoch 273/700
# 56/56 [==============================] - 0s 4ms/step - loss: 58.7404 - mean_absolute_error: 58.7404 - val_loss: 61.2852 - val_mean_absolute_error: 61.2852
# Epoch 274/700
# 56/56 [==============================] - 0s 4ms/step - loss: 59.4352 - mean_absolute_error: 59.4352 - val_loss: 60.5794 - val_mean_absolute_error: 60.5794
# Epoch 275/700
# 56/56 [==============================] - 0s 4ms/step - loss: 58.1869 - mean_absolute_error: 58.1869 - val_loss: 69.1814 - val_mean_absolute_error: 69.1814
# Epoch 276/700
# 56/56 [==============================] - 0s 4ms/step - loss: 59.0752 - mean_absolute_error: 59.0752 - val_loss: 66.7839 - val_mean_absolute_error: 66.7839
# Epoch 277/700
# 56/56 [==============================] - 0s 4ms/step - loss: 62.3887 - mean_absolute_error: 62.3887 - val_loss: 67.6288 - val_mean_absolute_error: 67.6288
# Epoch 278/700
# 56/56 [==============================] - 0s 4ms/step - loss: 58.0352 - mean_absolute_error: 58.0352 - val_loss: 68.1073 - val_mean_absolute_error: 68.1073
# Epoch 279/700
# 56/56 [==============================] - 0s 4ms/step - loss: 60.4235 - mean_absolute_error: 60.4235 - val_loss: 64.2193 - val_mean_absolute_error: 64.2193
# Epoch 280/700
# 56/56 [==============================] - 0s 4ms/step - loss: 60.0907 - mean_absolute_error: 60.0907 - val_loss: 67.3452 - val_mean_absolute_error: 67.3452
# Epoch 281/700
# 56/56 [==============================] - 0s 4ms/step - loss: 60.1951 - mean_absolute_error: 60.1951 - val_loss: 63.9208 - val_mean_absolute_error: 63.9208
# Epoch 282/700
# 56/56 [==============================] - 0s 4ms/step - loss: 59.1222 - mean_absolute_error: 59.1222 - val_loss: 63.2179 - val_mean_absolute_error: 63.2179
# Epoch 283/700
# ...
# Epoch 607/700
# 56/56 [==============================] - 0s 4ms/step - loss: 44.6061 - mean_absolute_error: 44.6061 - val_loss: 48.2998 - val_mean_absolute_error: 48.2998
# Epoch 608/700
# 56/56 [==============================] - 0s 5ms/step - loss: 43.8653 - mean_absolute_error: 43.8653 - val_loss: 59.2066 - val_mean_absolute_error: 59.2066
# Epoch 609/700
# 56/56 [==============================] - 0s 4ms/step - loss: 43.0963 - mean_absolute_error: 43.0963 - val_loss: 47.2784 - val_mean_absolute_error: 47.2784
# Epoch 610/700
# 56/56 [==============================] - 0s 5ms/step - loss: 43.8496 - mean_absolute_error: 43.8496 - val_loss: 47.0787 - val_mean_absolute_error: 47.0787
# Epoch 611/700
# 56/56 [==============================] - 0s 4ms/step - loss: 43.2360 - mean_absolute_error: 43.2360 - val_loss: 46.4510 - val_mean_absolute_error: 46.4510
# Epoch 612/700
# 56/56 [==============================] - 0s 5ms/step - loss: 45.2726 - mean_absolute_error: 45.2726 - val_loss: 49.8318 - val_mean_absolute_error: 49.8318
# Epoch 613/700
# 56/56 [==============================] - 0s 5ms/step - loss: 44.8063 - mean_absolute_error: 44.8063 - val_loss: 51.9010 - val_mean_absolute_error: 51.9010
# Epoch 614/700
# 56/56 [==============================] - 0s 5ms/step - loss: 44.9939 - mean_absolute_error: 44.9939 - val_loss: 48.7285 - val_mean_absolute_error: 48.7285
# Epoch 615/700
# 56/56 [==============================] - 0s 4ms/step - loss: 41.2762 - mean_absolute_error: 41.2762 - val_loss: 53.2091 - val_mean_absolute_error: 53.2091
# Epoch 616/700
# 56/56 [==============================] - 0s 5ms/step - loss: 43.6414 - mean_absolute_error: 43.6414 - val_loss: 47.9218 - val_mean_absolute_error: 47.9218
# Epoch 617/700
# 56/56 [==============================] - 0s 5ms/step - loss: 42.6040 - mean_absolute_error: 42.6040 - val_loss: 51.4202 - val_mean_absolute_error: 51.4202
# Epoch 618/700
# 56/56 [==============================] - 0s 5ms/step - loss: 43.2088 - mean_absolute_error: 43.2088 - val_loss: 50.4914 - val_mean_absolute_error: 50.4914
# Epoch 619/700
# 56/56 [==============================] - 0s 5ms/step - loss: 43.3238 - mean_absolute_error: 43.3238 - val_loss: 47.4613 - val_mean_absolute_error: 47.4613
# Epoch 620/700
# 56/56 [==============================] - 0s 5ms/step - loss: 42.4863 - mean_absolute_error: 42.4863 - val_loss: 48.1153 - val_mean_absolute_error: 48.1153
# Epoch 621/700
# 56/56 [==============================] - 0s 5ms/step - loss: 42.6715 - mean_absolute_error: 42.6715 - val_loss: 50.9176 - val_mean_absolute_error: 50.9176
# Epoch 622/700
# 56/56 [==============================] - 0s 5ms/step - loss: 41.2861 - mean_absolute_error: 41.2861 - val_loss: 54.5080 - val_mean_absolute_error: 54.5080
# Epoch 623/700
# 56/56 [==============================] - 0s 5ms/step - loss: 43.3374 - mean_absolute_error: 43.3374 - val_loss: 47.6681 - val_mean_absolute_error: 47.6681
# Epoch 624/700
# 56/56 [==============================] - 0s 5ms/step - loss: 44.0046 - mean_absolute_error: 44.0046 - val_loss: 75.6652 - val_mean_absolute_error: 75.6652
# Epoch 625/700
# 56/56 [==============================] - 0s 5ms/step - loss: 47.1621 - mean_absolute_error: 47.1621 - val_loss: 56.9281 - val_mean_absolute_error: 56.9281
# Epoch 626/700
# 56/56 [==============================] - 0s 4ms/step - loss: 43.3150 - mean_absolute_error: 43.3150 - val_loss: 47.5290 - val_mean_absolute_error: 47.5290
# Epoch 627/700
# 56/56 [==============================] - 0s 5ms/step - loss: 41.9575 - mean_absolute_error: 41.9575 - val_loss: 48.7392 - val_mean_absolute_error: 48.7392
# Epoch 628/700
# 56/56 [==============================] - 0s 5ms/step - loss: 42.7842 - mean_absolute_error: 42.7842 - val_loss: 56.8253 - val_mean_absolute_error: 56.8253
# Epoch 629/700
# 56/56 [==============================] - 0s 5ms/step - loss: 41.6907 - mean_absolute_error: 41.6907 - val_loss: 53.0530 - val_mean_absolute_error: 53.0530
# Epoch 630/700
# 56/56 [==============================] - 0s 5ms/step - loss: 42.4759 - mean_absolute_error: 42.4759 - val_loss: 50.5784 - val_mean_absolute_error: 50.5784
# Epoch 631/700
# 56/56 [==============================] - 0s 5ms/step - loss: 42.2814 - mean_absolute_error: 42.2814 - val_loss: 50.7103 - val_mean_absolute_error: 50.7103
# Epoch 632/700
# 56/56 [==============================] - 0s 5ms/step - loss: 41.6246 - mean_absolute_error: 41.6246 - val_loss: 48.0756 - val_mean_absolute_error: 48.0756
# Epoch 633/700
# 56/56 [==============================] - 0s 4ms/step - loss: 41.6270 - mean_absolute_error: 41.6270 - val_loss: 48.2499 - val_mean_absolute_error: 48.2499
# Epoch 634/700
# 56/56 [==============================] - 0s 5ms/step - loss: 41.5567 - mean_absolute_error: 41.5567 - val_loss: 51.0093 - val_mean_absolute_error: 51.0093
# Epoch 635/700
# 56/56 [==============================] - 0s 4ms/step - loss: 40.6020 - mean_absolute_error: 40.6020 - val_loss: 46.3879 - val_mean_absolute_error: 46.3879
# Epoch 636/700
# 56/56 [==============================] - 0s 4ms/step - loss: 41.8499 - mean_absolute_error: 41.8499 - val_loss: 47.9139 - val_mean_absolute_error: 47.9139
# Epoch 637/700
# 56/56 [==============================] - 0s 4ms/step - loss: 40.7291 - mean_absolute_error: 40.7291 - val_loss: 54.0879 - val_mean_absolute_error: 54.0879
# Epoch 638/700
# 56/56 [==============================] - 0s 4ms/step - loss: 42.6997 - mean_absolute_error: 42.6997 - val_loss: 52.7675 - val_mean_absolute_error: 52.7675
# Epoch 639/700
# 56/56 [==============================] - 0s 4ms/step - loss: 41.9821 - mean_absolute_error: 41.9821 - val_loss: 53.4794 - val_mean_absolute_error: 53.4794
# Epoch 640/700
# 56/56 [==============================] - 0s 4ms/step - loss: 44.8076 - mean_absolute_error: 44.8076 - val_loss: 52.3412 - val_mean_absolute_error: 52.3412
# Epoch 641/700
# 56/56 [==============================] - 0s 5ms/step - loss: 41.9313 - mean_absolute_error: 41.9313 - val_loss: 52.4606 - val_mean_absolute_error: 52.4606
# Epoch 642/700
# 56/56 [==============================] - 0s 5ms/step - loss: 45.8179 - mean_absolute_error: 45.8179 - val_loss: 47.0843 - val_mean_absolute_error: 47.0843
# Epoch 643/700
# 56/56 [==============================] - 0s 5ms/step - loss: 40.8675 - mean_absolute_error: 40.8675 - val_loss: 46.7978 - val_mean_absolute_error: 46.7978
# Epoch 644/700
# 56/56 [==============================] - 0s 5ms/step - loss: 40.9238 - mean_absolute_error: 40.9238 - val_loss: 52.6095 - val_mean_absolute_error: 52.6095
# Epoch 645/700
# 56/56 [==============================] - 1s 23ms/step - loss: 44.1734 - mean_absolute_error: 44.1734 - val_loss: 45.8360 - val_mean_absolute_error: 45.8360
# Epoch 646/700
# 56/56 [==============================] - 0s 5ms/step - loss: 40.7047 - mean_absolute_error: 40.7047 - val_loss: 51.5330 - val_mean_absolute_error: 51.5330
# Epoch 647/700
# 56/56 [==============================] - 0s 6ms/step - loss: 41.0083 - mean_absolute_error: 41.0083 - val_loss: 48.3725 - val_mean_absolute_error: 48.3725
# Epoch 648/700
# 56/56 [==============================] - 0s 7ms/step - loss: 44.0124 - mean_absolute_error: 44.0124 - val_loss: 51.6287 - val_mean_absolute_error: 51.6287
# Epoch 649/700
# 56/56 [==============================] - 0s 7ms/step - loss: 43.4019 - mean_absolute_error: 43.4019 - val_loss: 56.7549 - val_mean_absolute_error: 56.7549
# Epoch 650/700
# 56/56 [==============================] - 0s 7ms/step - loss: 44.6233 - mean_absolute_error: 44.6233 - val_loss: 49.6299 - val_mean_absolute_error: 49.6299
# Epoch 651/700
# 56/56 [==============================] - 0s 7ms/step - loss: 43.6128 - mean_absolute_error: 43.6128 - val_loss: 52.1362 - val_mean_absolute_error: 52.1362
# Epoch 652/700
# 56/56 [==============================] - 0s 7ms/step - loss: 43.3685 - mean_absolute_error: 43.3685 - val_loss: 53.1825 - val_mean_absolute_error: 53.1825
# Epoch 653/700
# 56/56 [==============================] - 0s 6ms/step - loss: 42.2360 - mean_absolute_error: 42.2360 - val_loss: 48.0257 - val_mean_absolute_error: 48.0257
# Epoch 654/700
# 56/56 [==============================] - 0s 7ms/step - loss: 41.9252 - mean_absolute_error: 41.9252 - val_loss: 51.5811 - val_mean_absolute_error: 51.5811
# Epoch 655/700
# 56/56 [==============================] - 0s 7ms/step - loss: 44.3216 - mean_absolute_error: 44.3216 - val_loss: 51.9442 - val_mean_absolute_error: 51.9442
# Epoch 656/700
# 56/56 [==============================] - 0s 7ms/step - loss: 42.2613 - mean_absolute_error: 42.2613 - val_loss: 49.9561 - val_mean_absolute_error: 49.9561
# Epoch 657/700
# 56/56 [==============================] - 0s 7ms/step - loss: 42.5110 - mean_absolute_error: 42.5110 - val_loss: 48.5996 - val_mean_absolute_error: 48.5996
# Epoch 658/700
# 56/56 [==============================] - 0s 7ms/step - loss: 41.9769 - mean_absolute_error: 41.9769 - val_loss: 51.7875 - val_mean_absolute_error: 51.7875
# Epoch 659/700
# 56/56 [==============================] - 0s 6ms/step - loss: 44.1840 - mean_absolute_error: 44.1840 - val_loss: 51.3070 - val_mean_absolute_error: 51.3070
# Epoch 660/700
# 56/56 [==============================] - 0s 6ms/step - loss: 44.5789 - mean_absolute_error: 44.5789 - val_loss: 46.0044 - val_mean_absolute_error: 46.0044
# Epoch 661/700
# 56/56 [==============================] - 0s 7ms/step - loss: 41.7465 - mean_absolute_error: 41.7465 - val_loss: 47.4648 - val_mean_absolute_error: 47.4648
# Epoch 662/700
# 56/56 [==============================] - 2s 30ms/step - loss: 41.6866 - mean_absolute_error: 41.6866 - val_loss: 45.4760 - val_mean_absolute_error: 45.4760
# Epoch 663/700
# 56/56 [==============================] - 0s 4ms/step - loss: 40.7413 - mean_absolute_error: 40.7413 - val_loss: 55.8510 - val_mean_absolute_error: 55.8510
# Epoch 664/700
# 56/56 [==============================] - 0s 5ms/step - loss: 42.5316 - mean_absolute_error: 42.5316 - val_loss: 55.9790 - val_mean_absolute_error: 55.9790
# Epoch 665/700
# 56/56 [==============================] - 0s 4ms/step - loss: 41.3318 - mean_absolute_error: 41.3318 - val_loss: 48.0353 - val_mean_absolute_error: 48.0353
# Epoch 666/700
# 56/56 [==============================] - 0s 5ms/step - loss: 40.8963 - mean_absolute_error: 40.8963 - val_loss: 46.7671 - val_mean_absolute_error: 46.7671
# Epoch 667/700
# 56/56 [==============================] - 0s 4ms/step - loss: 41.5172 - mean_absolute_error: 41.5172 - val_loss: 45.9607 - val_mean_absolute_error: 45.9607
# Epoch 668/700
# 56/56 [==============================] - 0s 5ms/step - loss: 43.8792 - mean_absolute_error: 43.8792 - val_loss: 47.1036 - val_mean_absolute_error: 47.1036
# Epoch 669/700
# 56/56 [==============================] - 0s 4ms/step - loss: 43.6609 - mean_absolute_error: 43.6609 - val_loss: 49.1266 - val_mean_absolute_error: 49.1266
# Epoch 670/700
# 56/56 [==============================] - 0s 5ms/step - loss: 42.9843 - mean_absolute_error: 42.9843 - val_loss: 47.4996 - val_mean_absolute_error: 47.4996
# Epoch 671/700
# 56/56 [==============================] - 0s 5ms/step - loss: 42.1004 - mean_absolute_error: 42.1004 - val_loss: 47.9548 - val_mean_absolute_error: 47.9548
# Epoch 672/700
# 56/56 [==============================] - 0s 5ms/step - loss: 41.7361 - mean_absolute_error: 41.7361 - val_loss: 50.5945 - val_mean_absolute_error: 50.5945
# Epoch 673/700
# 56/56 [==============================] - 0s 4ms/step - loss: 41.6249 - mean_absolute_error: 41.6249 - val_loss: 47.7361 - val_mean_absolute_error: 47.7361
# Epoch 674/700
# 56/56 [==============================] - 0s 5ms/step - loss: 41.3388 - mean_absolute_error: 41.3388 - val_loss: 50.9700 - val_mean_absolute_error: 50.9700
# Epoch 675/700
# 56/56 [==============================] - 0s 5ms/step - loss: 42.4977 - mean_absolute_error: 42.4977 - val_loss: 46.7179 - val_mean_absolute_error: 46.7179
# Epoch 676/700
# 56/56 [==============================] - 0s 4ms/step - loss: 42.6926 - mean_absolute_error: 42.6926 - val_loss: 59.7041 - val_mean_absolute_error: 59.7041
# Epoch 677/700
# 56/56 [==============================] - 0s 5ms/step - loss: 42.3570 - mean_absolute_error: 42.3570 - val_loss: 50.9487 - val_mean_absolute_error: 50.9487
# Epoch 678/700
# 56/56 [==============================] - 0s 5ms/step - loss: 41.1658 - mean_absolute_error: 41.1658 - val_loss: 52.7601 - val_mean_absolute_error: 52.7601
# Epoch 679/700
# 56/56 [==============================] - 0s 5ms/step - loss: 43.0343 - mean_absolute_error: 43.0343 - val_loss: 54.6551 - val_mean_absolute_error: 54.6551
# Epoch 680/700
# 56/56 [==============================] - 0s 5ms/step - loss: 39.7223 - mean_absolute_error: 39.7223 - val_loss: 51.8974 - val_mean_absolute_error: 51.8974
# Epoch 681/700
# 56/56 [==============================] - 0s 4ms/step - loss: 43.7283 - mean_absolute_error: 43.7283 - val_loss: 46.7351 - val_mean_absolute_error: 46.7351
# Epoch 682/700
# 56/56 [==============================] - 1s 22ms/step - loss: 42.6032 - mean_absolute_error: 42.6032 - val_loss: 45.3588 - val_mean_absolute_error: 45.3588
# Epoch 683/700
# 56/56 [==============================] - 0s 5ms/step - loss: 40.5381 - mean_absolute_error: 40.5381 - val_loss: 47.8418 - val_mean_absolute_error: 47.8418
# Epoch 684/700
# 56/56 [==============================] - 0s 4ms/step - loss: 41.2003 - mean_absolute_error: 41.2003 - val_loss: 46.8452 - val_mean_absolute_error: 46.8452
# Epoch 685/700
# 56/56 [==============================] - 0s 5ms/step - loss: 47.6073 - mean_absolute_error: 47.6073 - val_loss: 54.4537 - val_mean_absolute_error: 54.4537
# Epoch 686/700
# 56/56 [==============================] - 0s 5ms/step - loss: 41.6954 - mean_absolute_error: 41.6954 - val_loss: 45.9332 - val_mean_absolute_error: 45.9332
# Epoch 687/700
# 56/56 [==============================] - 0s 5ms/step - loss: 41.2847 - mean_absolute_error: 41.2847 - val_loss: 49.5150 - val_mean_absolute_error: 49.5150
# Epoch 688/700
# 56/56 [==============================] - 0s 5ms/step - loss: 40.6762 - mean_absolute_error: 40.6762 - val_loss: 46.6501 - val_mean_absolute_error: 46.6501
# Epoch 689/700
# 56/56 [==============================] - 0s 5ms/step - loss: 40.5509 - mean_absolute_error: 40.5509 - val_loss: 46.7458 - val_mean_absolute_error: 46.7458
# Epoch 690/700
# 56/56 [==============================] - 0s 5ms/step - loss: 40.6718 - mean_absolute_error: 40.6718 - val_loss: 52.7046 - val_mean_absolute_error: 52.7046
# Epoch 691/700
# 56/56 [==============================] - 0s 4ms/step - loss: 43.0984 - mean_absolute_error: 43.0984 - val_loss: 51.5345 - val_mean_absolute_error: 51.5345
# Epoch 692/700
# 56/56 [==============================] - 0s 5ms/step - loss: 41.3507 - mean_absolute_error: 41.3507 - val_loss: 47.8240 - val_mean_absolute_error: 47.8240
# Epoch 693/700
# 56/56 [==============================] - 0s 5ms/step - loss: 42.2628 - mean_absolute_error: 42.2628 - val_loss: 50.2575 - val_mean_absolute_error: 50.2575
# Epoch 694/700
# 56/56 [==============================] - 0s 4ms/step - loss: 42.9866 - mean_absolute_error: 42.9866 - val_loss: 48.0922 - val_mean_absolute_error: 48.0922
# Epoch 695/700
# 56/56 [==============================] - 0s 5ms/step - loss: 41.8825 - mean_absolute_error: 41.8825 - val_loss: 55.3306 - val_mean_absolute_error: 55.3306
# Epoch 696/700
# 56/56 [==============================] - 0s 5ms/step - loss: 41.9484 - mean_absolute_error: 41.9484 - val_loss: 51.0229 - val_mean_absolute_error: 51.0229
# Epoch 697/700
# 56/56 [==============================] - 0s 5ms/step - loss: 42.8765 - mean_absolute_error: 42.8765 - val_loss: 46.5025 - val_mean_absolute_error: 46.5025
# Epoch 698/700
# 56/56 [==============================] - 0s 5ms/step - loss: 40.2003 - mean_absolute_error: 40.2003 - val_loss: 47.8941 - val_mean_absolute_error: 47.8941
# Epoch 699/700
# 56/56 [==============================] - 0s 5ms/step - loss: 44.1483 - mean_absolute_error: 44.1483 - val_loss: 47.1394 - val_mean_absolute_error: 47.1394
# Epoch 700/700
# 56/56 [==============================] - 1s 23ms/step - loss: 43.1273 - mean_absolute_error: 43.1273 - val_loss: 45.0101 - val_mean_absolute_error: 45.0101

# %%
# from tensorflow.keras.models import load_model   
# model = load_model('model_ann_all/')

# %%
#700
train_acc = model.evaluate(X_train, y_train, verbose=0)
print('MAE training : {:.3f}'.format(train_acc[1]))
scores = model.evaluate(X_validation, y_validation)
print('MAE validation : {:.3f}'.format(scores[1]))

test_acc = model.evaluate(X_test, y_test)
print('MAE test : {:.3f}'.format(test_acc[1]))
# Out:
# MAE training : 37.813
# 12/12 [==============================] - 0s 2ms/step - loss: 45.0101 - mean_absolute_error: 45.0101
# MAE validation : 45.010
# 10/10 [==============================] - 0s 2ms/step - loss: 44.5931 - mean_absolute_error: 44.5931
# MAE test : 44.593

# %%
#700
show_train_history(train_history,'loss','val_loss')

# %% [markdown]
# **Results for 700 epochs**

# %%
train_predictions = model.predict(X_train).flatten()

train_results = pd.DataFrame(data={'Train Predictions':train_predictions, 'Actuals':y_train.flatten()})
train_results

###train_results.to_csv(r'/content/gdrive/MyDrive/TRM/ENAAM/AllRanking/Predictions_Test_Top_Results_ANN.csv')
###train_results
# Out:
# 56/56 [==============================] - 0s 1ms/step
#       Train Predictions  Actuals
# 0           1585.712158   1672.0
# 1           1615.488281   1585.0
# 2           2448.437988   2432.0
# 3            439.839233    435.0
# 4           2115.276611   2088.0
# ...                 ...      ...
# 1780        1074.742432   1104.0
# 1781        2358.110352   2506.0
# 1782         166.147842    162.0
# 1783         530.019043    532.0
# 1784        1440.985596   1488.0
#
# [1785 rows x 2 columns]

# %%
res1 = train_results.head(50)
res1.plot(kind='bar',figsize=(16,10))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %%
test_predictions = model.predict(X_test).flatten()
test_results = pd.DataFrame(data={'Test Predictions':test_predictions, 'Actuals':y_test.flatten()})
test_results
# Out:
# 10/10 [==============================] - 0s 2ms/step
#      Test Predictions  Actuals
# 0         1519.442749   1517.0
# 1          586.871338    583.0
# 2          807.300659    812.0
# 3          491.491516    543.0
# 4         1780.991577   1809.0
# ..                ...      ...
# 286       2340.620361   2338.0
# 287        973.300903    978.0
# 288        510.232697    514.0
# 289        280.867798    269.0
# 290       1890.522339   1877.0
#
# [291 rows x 2 columns]

# %%
res2 = test_results.head(100)
res2.plot(kind='bar',figsize=(20,10))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %% [markdown]
# TOP 100

# %%
# Import dataset
df_2 = pd.read_csv('/content/gdrive/MyDrive/TRM/ENAAM/AllRanking/ground_truth.csv')
df_2
# Out:
#       Response Time  Availability  Throughput  Reliability  Latency  Rank
# 0             41.00            97        43.1           73     1.00      1
# 1             57.00            98        34.6           73     1.00      2
# 2             57.00            86        40.1           73     1.00      3
# 3             78.00           100        35.3           67     1.00      4
# 4             78.00            92        36.9           73     1.00      5
# ...             ...           ...         ...          ...      ...    ...
# 2502        1674.00            55         0.8           67  1005.40   2503
# 2503        2555.00            83         0.3           73  2035.00   2504
# 2504        2204.38            66         0.7           73  2050.13   2505
# 2505        4480.80            52         1.0           50  1652.40   2506
# 2506        4637.61            30         0.5           67  4140.35   2507
#
# [2507 rows x 6 columns]

# %%
# Create python dataframe
decisions_2 = pd.DataFrame()
decisions_2['Response Time'] = df_2['Response Time']
decisions_2['Availability'] = df_2['Availability']
decisions_2['Throughput'] = df_2['Throughput']
decisions_2['Reliability'] = df_2['Reliability']
decisions_2['Latency'] = df_2['Latency']
decisions_2['Rank'] = df_2['Rank ']
decisions_2.head(100)
# Out:
#     Response Time  Availability  Throughput  Reliability  Latency  Rank
# 0           41.00            97        43.1           73     1.00     1
# 1           57.00            98        34.6           73     1.00     2
# 2           57.00            86        40.1           73     1.00     3
# 3           78.00           100        35.3           67     1.00     4
# 4           78.00            92        36.9           73     1.00     5
# ..            ...           ...         ...          ...      ...   ...
# 95          53.00            83        14.5           73     2.00    96
# 96         116.00            98        16.7           67     1.33    97
# 97         126.67            94         9.5           73     0.67    98
# 98         119.00            83        10.7           73     1.00    99
# 99         111.00            87        27.4           58     2.00   100
#
# [100 rows x 6 columns]

# %%
test_data_top = decisions_2[0:100]

# %%
tmp_top = np.array(test_data_top)
X_test_top = tmp_top[:, :-1]
y_test_top = tmp_top[:, -1]

# %%
test_acc_top = model.evaluate(X_test_top, y_test_top)
print('MAE test top : {:.3f}'.format(test_acc_top[1]))
# Out:
# 4/4 [==============================] - 0s 3ms/step - loss: 5.7808 - mean_absolute_error: 5.7808
# MAE test top : 5.781

# %%
test_predictions_top = model.predict(X_test_top).flatten()
test_results_top = pd.DataFrame(data={'Test Predictions':test_predictions_top, 'Actuals':y_test_top.flatten()})
test_results_top.to_csv(r'/content/gdrive/MyDrive/TRM/ENAAM/AllRanking/Predictions_Test_Top_Results_ANN.csv')
test_results_top
# Out:
# 4/4 [==============================] - 0s 3ms/step
#     Test Predictions  Actuals
# 0           0.640377      1.0
# 1           1.420774      2.0
# 2           2.264885      3.0
# 3           3.907706      4.0
# 4           3.817825      5.0
# ..               ...      ...
# 95        103.236473     96.0
# 96         76.732498     97.0
# 97         93.350639     98.0
# 98        115.880295     99.0
# 99        118.117378    100.0
#
# [100 rows x 2 columns]

# %%
res3 = test_results_top.head(100)
res3.plot(kind='bar',figsize=(20,10))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()
