# %% [markdown]
# **1. Import Modules**

# %%
'''
  Import all necessary modules
'''

import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input , Dense, Dropout, SimpleRNN
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.losses import MeanSquaredError, MeanAbsoluteError
from tensorflow.keras.metrics import RootMeanSquaredError, MeanAbsoluteError
from tensorflow.keras.optimizers import Adam, Adadelta
from numpy.random import seed
from tensorflow.keras.utils import set_random_seed
from sklearn import preprocessing
import seaborn as sns

# %%
#mount the drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd /content/gdrive/MyDrive/TRM/ENAAM
# Out:
# /content/gdrive/MyDrive/TRM/ENAAM

# %% [markdown]
# **2. Dataset Preparation**

# %%
# Import dataset
df = pd.read_csv('/content/gdrive/MyDrive/TRM/ENAAM/AllRanking/ground_truth-shuffled.csv')
df
# Out:
#       Response Time  Availability  Throughput  Reliability  Latency  Rank
# 0            182.25            67         9.7           67    46.50   1672
# 1            175.50            90         7.6           80    39.00   1585
# 2            500.71            92         2.2           67   233.85   2432
# 3            175.00            86         9.4           73     3.00    435
# 4            996.00            83        14.0           83    59.00   2088
# ...             ...           ...         ...          ...      ...    ...
# 2502         432.00            86         8.8           80     1.29    577
# 2503         249.00            56         8.1           73     2.25    554
# 2504         219.20            94         1.1           73     8.40   1256
# 2505         171.00            83        18.6           80     5.00    474
# 2506         227.00            88        21.2           73    23.00   1321
#
# [2507 rows x 6 columns]

# %%
df.hist(figsize = (12,10))
plt.show()

# %%
f, ax = plt.subplots(figsize=(10, 8))
corr = df.corr()
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool),
            cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, ax=ax)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Correlation between different variables
#
corr = df.corr()
#
# Set up the matplotlib plot configuration
#
f, ax = plt.subplots(figsize=(12, 10))
#
# Generate a mask for upper traingle
#
mask = np.triu(np.ones_like(corr, dtype=bool))
#
# Configure a custom diverging colormap
#
cmap = sns.diverging_palette(230, 20, as_cmap=True)
#
# Draw the heatmap
#
sns.heatmap(corr, annot=True, mask = mask, cmap=cmap)

# %%
# Create python dataframe
decisions = pd.DataFrame()
decisions['Response Time'] = df['Response Time']
decisions['Availability'] = df['Availability']
decisions['Throughput'] = df['Throughput']
decisions['Reliability'] = df['Reliability']
decisions['Latency'] = df['Latency']
decisions['Rank'] = df['Rank ']
decisions
# Out:
#       Response Time  Availability  Throughput  Reliability  Latency  Rank
# 0            182.25            67         9.7           67    46.50  1672
# 1            175.50            90         7.6           80    39.00  1585
# 2            500.71            92         2.2           67   233.85  2432
# 3            175.00            86         9.4           73     3.00   435
# 4            996.00            83        14.0           83    59.00  2088
# ...             ...           ...         ...          ...      ...   ...
# 2502         432.00            86         8.8           80     1.29   577
# 2503         249.00            56         8.1           73     2.25   554
# 2504         219.20            94         1.1           73     8.40  1256
# 2505         171.00            83        18.6           80     5.00   474
# 2506         227.00            88        21.2           73    23.00  1321
#
# [2507 rows x 6 columns]

# %%
'''
 Split dataset to train (70%), test (15%) and validation(15%) sets. 
 The top 30 values were removed from the dataset to be split. 
      * Reason for removal - We have to check the MAE of the top 30. The data should be unknown to the model to get
        accurate figures. 
'''
training_data = decisions[0:1785]#361

test_data = decisions[1855:2146]

validation_data = decisions[2146:2507]

# %%
# Split into input and output values

tmp_train = np.array(training_data)
X_train = tmp_train[:, :-1]
y_train = tmp_train[:, -1]

tmp_test = np.array(test_data)
X_test = tmp_test[:, :-1]
y_test = tmp_test[:, -1]

tmp_val = np.array(validation_data)
X_validation = tmp_val[:, :-1]
y_validation = tmp_val[:, -1]

# %% [markdown]
# **3. Model Preparation**

# %%
seed(0)
set_random_seed(0)

# %%
'''
 This function is used to display the training history of the dataset.
'''
def show_train_history(train_history,train,validation):
    plt.plot(train_history.history[train])
    plt.plot(train_history.history[validation])
    plt.title('Train History')
    plt.ylabel(train)
    plt.xlabel('Epoch')
    plt.legend(['train', 'validation'], loc='best')
    plt.show()

# %%
# 5 hidden layer neural network

model = Sequential()

n_cols = training_data.shape[1]

model.add(Dense(256, kernel_initializer='normal', activation='relu', input_shape=(5,)))
# The Hidden Layers :
model.add(Dense(128, kernel_initializer='normal',activation='relu'))
model.add(Dense(96, kernel_initializer='normal',activation='relu'))
model.add(Dense(72, kernel_initializer='normal',activation='relu'))
model.add(Dense(64, kernel_initializer='normal',activation='relu'))
model.add(Dense(32, kernel_initializer='normal',activation='relu'))

model.add(Dense(1))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_14 (Dense)            (None, 256)               1536
#
#  dense_15 (Dense)            (None, 128)               32896
#
#  dense_16 (Dense)            (None, 96)                12384
#
#  dense_17 (Dense)            (None, 72)                6984
#
#  dense_18 (Dense)            (None, 64)                4672
#
#  dense_19 (Dense)            (None, 32)                2080
#
#  dense_20 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 60,585
# Trainable params: 60,585
# Non-trainable params: 0
# _________________________________________________________________

# %%
'''
Checkpoints are used to save the model at some interval, so the model can be loaded from the saved state to continue training
'''
cp = ModelCheckpoint('model_ann_all/', save_best_only=True)

# Compile model
model.compile(loss='mean_absolute_error',
                optimizer=tf.keras.optimizers.Adam(0.0001), metrics='mean_absolute_error')

# %%
#train model

train_history = model.fit(X_train, y_train, epochs=700, validation_data=(X_validation, y_validation), callbacks=[cp])
# Out:
# Epoch 1/700
# 56/56 [==============================] - 3s 36ms/step - loss: 1254.0957 - mean_absolute_error: 1254.0957 - val_loss: 1253.7839 - val_mean_absolute_error: 1253.7839
# Epoch 2/700
# 56/56 [==============================] - 1s 27ms/step - loss: 1218.0370 - mean_absolute_error: 1218.0370 - val_loss: 1121.2061 - val_mean_absolute_error: 1121.2061
# Epoch 3/700
# 56/56 [==============================] - 1s 26ms/step - loss: 913.0239 - mean_absolute_error: 913.0239 - val_loss: 760.8953 - val_mean_absolute_error: 760.8953
# Epoch 4/700
# 56/56 [==============================] - 1s 27ms/step - loss: 727.3682 - mean_absolute_error: 727.3682 - val_loss: 748.8724 - val_mean_absolute_error: 748.8724
# Epoch 5/700
# 56/56 [==============================] - 1s 26ms/step - loss: 693.5303 - mean_absolute_error: 693.5303 - val_loss: 723.6998 - val_mean_absolute_error: 723.6998
# Epoch 6/700
# 56/56 [==============================] - 2s 31ms/step - loss: 664.2856 - mean_absolute_error: 664.2856 - val_loss: 672.9695 - val_mean_absolute_error: 672.9695
# Epoch 7/700
# 56/56 [==============================] - 1s 25ms/step - loss: 635.4501 - mean_absolute_error: 635.4501 - val_loss: 649.8019 - val_mean_absolute_error: 649.8019
# Epoch 8/700
# 56/56 [==============================] - 1s 26ms/step - loss: 608.5070 - mean_absolute_error: 608.5070 - val_loss: 622.6158 - val_mean_absolute_error: 622.6158
# Epoch 9/700
# 56/56 [==============================] - 1s 27ms/step - loss: 583.7517 - mean_absolute_error: 583.7517 - val_loss: 601.0533 - val_mean_absolute_error: 601.0533
# Epoch 10/700
# 56/56 [==============================] - 1s 26ms/step - loss: 555.9774 - mean_absolute_error: 555.9774 - val_loss: 581.2953 - val_mean_absolute_error: 581.2953
# Epoch 11/700
# 56/56 [==============================] - 1s 26ms/step - loss: 531.8736 - mean_absolute_error: 531.8736 - val_loss: 559.3366 - val_mean_absolute_error: 559.3366
# Epoch 12/700
# 56/56 [==============================] - 2s 31ms/step - loss: 508.1509 - mean_absolute_error: 508.1509 - val_loss: 536.7566 - val_mean_absolute_error: 536.7566
# Epoch 13/700
# 56/56 [==============================] - 1s 26ms/step - loss: 483.9129 - mean_absolute_error: 483.9129 - val_loss: 514.5435 - val_mean_absolute_error: 514.5435
# Epoch 14/700
# 56/56 [==============================] - 2s 27ms/step - loss: 451.3170 - mean_absolute_error: 451.3170 - val_loss: 487.9990 - val_mean_absolute_error: 487.9990
# Epoch 15/700
# 56/56 [==============================] - 2s 28ms/step - loss: 410.1716 - mean_absolute_error: 410.1716 - val_loss: 428.9909 - val_mean_absolute_error: 428.9909
# Epoch 16/700
# 56/56 [==============================] - 2s 28ms/step - loss: 357.5910 - mean_absolute_error: 357.5910 - val_loss: 371.3985 - val_mean_absolute_error: 371.3985
# Epoch 17/700
# 56/56 [==============================] - 2s 32ms/step - loss: 303.2497 - mean_absolute_error: 303.2497 - val_loss: 309.4214 - val_mean_absolute_error: 309.4214
# Epoch 18/700
# 56/56 [==============================] - 2s 29ms/step - loss: 255.5509 - mean_absolute_error: 255.5509 - val_loss: 251.3761 - val_mean_absolute_error: 251.3761
# Epoch 19/700
# 56/56 [==============================] - 1s 27ms/step - loss: 228.5547 - mean_absolute_error: 228.5547 - val_loss: 230.9789 - val_mean_absolute_error: 230.9789
# Epoch 20/700
# 56/56 [==============================] - 1s 26ms/step - loss: 221.7471 - mean_absolute_error: 221.7471 - val_loss: 227.3392 - val_mean_absolute_error: 227.3392
# Epoch 21/700
# 56/56 [==============================] - 2s 27ms/step - loss: 210.3535 - mean_absolute_error: 210.3535 - val_loss: 212.6297 - val_mean_absolute_error: 212.6297
# Epoch 22/700
# 56/56 [==============================] - 1s 27ms/step - loss: 205.5829 - mean_absolute_error: 205.5829 - val_loss: 208.6875 - val_mean_absolute_error: 208.6875
# Epoch 23/700
# 56/56 [==============================] - 2s 32ms/step - loss: 200.0124 - mean_absolute_error: 200.0124 - val_loss: 204.2594 - val_mean_absolute_error: 204.2594
# Epoch 24/700
# 56/56 [==============================] - 1s 27ms/step - loss: 199.4630 - mean_absolute_error: 199.4630 - val_loss: 201.1845 - val_mean_absolute_error: 201.1845
# Epoch 25/700
# 56/56 [==============================] - 1s 27ms/step - loss: 192.0799 - mean_absolute_error: 192.0799 - val_loss: 197.3241 - val_mean_absolute_error: 197.3241
# Epoch 26/700
# 56/56 [==============================] - 1s 25ms/step - loss: 187.6320 - mean_absolute_error: 187.6320 - val_loss: 190.9956 - val_mean_absolute_error: 190.9956
# Epoch 27/700
# 56/56 [==============================] - 1s 26ms/step - loss: 183.8296 - mean_absolute_error: 183.8296 - val_loss: 185.3580 - val_mean_absolute_error: 185.3580
# Epoch 28/700
# 56/56 [==============================] - 2s 31ms/step - loss: 183.1465 - mean_absolute_error: 183.1465 - val_loss: 182.5119 - val_mean_absolute_error: 182.5119
# Epoch 29/700
# 56/56 [==============================] - 0s 4ms/step - loss: 177.6805 - mean_absolute_error: 177.6805 - val_loss: 183.0256 - val_mean_absolute_error: 183.0256
# Epoch 30/700
# 56/56 [==============================] - 1s 26ms/step - loss: 175.4072 - mean_absolute_error: 175.4072 - val_loss: 176.2558 - val_mean_absolute_error: 176.2558
# Epoch 31/700
# 56/56 [==============================] - 1s 25ms/step - loss: 175.1869 - mean_absolute_error: 175.1869 - val_loss: 172.1803 - val_mean_absolute_error: 172.1803
# Epoch 32/700
# 56/56 [==============================] - 1s 26ms/step - loss: 169.9442 - mean_absolute_error: 169.9442 - val_loss: 171.9355 - val_mean_absolute_error: 171.9355
# Epoch 33/700
# 56/56 [==============================] - 1s 25ms/step - loss: 167.4612 - mean_absolute_error: 167.4612 - val_loss: 168.7479 - val_mean_absolute_error: 168.7479
# Epoch 34/700
# 56/56 [==============================] - 1s 27ms/step - loss: 162.7512 - mean_absolute_error: 162.7512 - val_loss: 166.9056 - val_mean_absolute_error: 166.9056
# Epoch 35/700
# 56/56 [==============================] - 0s 5ms/step - loss: 161.2849 - mean_absolute_error: 161.2849 - val_loss: 167.6030 - val_mean_absolute_error: 167.6030
# Epoch 36/700
# 56/56 [==============================] - 0s 5ms/step - loss: 163.9308 - mean_absolute_error: 163.9308 - val_loss: 168.0719 - val_mean_absolute_error: 168.0719
# Epoch 37/700
# 56/56 [==============================] - 2s 33ms/step - loss: 155.9679 - mean_absolute_error: 155.9679 - val_loss: 159.9123 - val_mean_absolute_error: 159.9123
# Epoch 38/700
# 56/56 [==============================] - 2s 28ms/step - loss: 154.2123 - mean_absolute_error: 154.2123 - val_loss: 152.2251 - val_mean_absolute_error: 152.2251
# Epoch 39/700
# 56/56 [==============================] - 1s 26ms/step - loss: 154.3532 - mean_absolute_error: 154.3532 - val_loss: 151.1551 - val_mean_absolute_error: 151.1551
# Epoch 40/700
# 56/56 [==============================] - 1s 27ms/step - loss: 146.8836 - mean_absolute_error: 146.8836 - val_loss: 148.4954 - val_mean_absolute_error: 148.4954
# Epoch 41/700
# 56/56 [==============================] - 1s 27ms/step - loss: 144.6259 - mean_absolute_error: 144.6259 - val_loss: 148.4318 - val_mean_absolute_error: 148.4318
# Epoch 42/700
# 56/56 [==============================] - 2s 31ms/step - loss: 140.7537 - mean_absolute_error: 140.7537 - val_loss: 143.3352 - val_mean_absolute_error: 143.3352
# Epoch 43/700
# 56/56 [==============================] - 1s 26ms/step - loss: 141.1906 - mean_absolute_error: 141.1906 - val_loss: 142.2014 - val_mean_absolute_error: 142.2014
# Epoch 44/700
# 56/56 [==============================] - 1s 27ms/step - loss: 134.1574 - mean_absolute_error: 134.1574 - val_loss: 135.9285 - val_mean_absolute_error: 135.9285
# Epoch 45/700
# 56/56 [==============================] - 0s 5ms/step - loss: 134.2292 - mean_absolute_error: 134.2292 - val_loss: 138.2075 - val_mean_absolute_error: 138.2075
# Epoch 46/700
# 56/56 [==============================] - 1s 26ms/step - loss: 131.8000 - mean_absolute_error: 131.8000 - val_loss: 130.3589 - val_mean_absolute_error: 130.3589
# Epoch 47/700
# 56/56 [==============================] - 0s 5ms/step - loss: 127.4173 - mean_absolute_error: 127.4173 - val_loss: 144.4655 - val_mean_absolute_error: 144.4655
# Epoch 48/700
# 56/56 [==============================] - 1s 27ms/step - loss: 125.0484 - mean_absolute_error: 125.0484 - val_loss: 127.3195 - val_mean_absolute_error: 127.3195
# Epoch 49/700
# 56/56 [==============================] - 0s 4ms/step - loss: 126.4045 - mean_absolute_error: 126.4045 - val_loss: 132.2946 - val_mean_absolute_error: 132.2946
# Epoch 50/700
# 56/56 [==============================] - 2s 31ms/step - loss: 120.4318 - mean_absolute_error: 120.4318 - val_loss: 124.8406 - val_mean_absolute_error: 124.8406
# Epoch 51/700
# 56/56 [==============================] - 1s 25ms/step - loss: 119.6932 - mean_absolute_error: 119.6932 - val_loss: 118.8504 - val_mean_absolute_error: 118.8504
# Epoch 52/700
# 56/56 [==============================] - 0s 4ms/step - loss: 117.2359 - mean_absolute_error: 117.2359 - val_loss: 119.8641 - val_mean_absolute_error: 119.8641
# Epoch 53/700
# 56/56 [==============================] - 0s 4ms/step - loss: 113.3529 - mean_absolute_error: 113.3529 - val_loss: 119.4733 - val_mean_absolute_error: 119.4733
# Epoch 54/700
# 56/56 [==============================] - 0s 4ms/step - loss: 111.9542 - mean_absolute_error: 111.9542 - val_loss: 124.5731 - val_mean_absolute_error: 124.5731
# Epoch 55/700
# 56/56 [==============================] - 0s 4ms/step - loss: 113.3724 - mean_absolute_error: 113.3724 - val_loss: 146.5071 - val_mean_absolute_error: 146.5071
# Epoch 56/700
# 56/56 [==============================] - 1s 26ms/step - loss: 111.2190 - mean_absolute_error: 111.2190 - val_loss: 113.8961 - val_mean_absolute_error: 113.8961
# Epoch 57/700
# 56/56 [==============================] - 1s 26ms/step - loss: 110.6116 - mean_absolute_error: 110.6116 - val_loss: 106.9933 - val_mean_absolute_error: 106.9933
# Epoch 58/700
# 56/56 [==============================] - 1s 25ms/step - loss: 105.4025 - mean_absolute_error: 105.4025 - val_loss: 106.3094 - val_mean_absolute_error: 106.3094
# Epoch 59/700
# 56/56 [==============================] - 1s 26ms/step - loss: 105.4452 - mean_absolute_error: 105.4452 - val_loss: 105.8053 - val_mean_absolute_error: 105.8053
# Epoch 60/700
# 56/56 [==============================] - 2s 32ms/step - loss: 104.4620 - mean_absolute_error: 104.4620 - val_loss: 105.0236 - val_mean_absolute_error: 105.0236
# Epoch 61/700
# 56/56 [==============================] - 2s 29ms/step - loss: 102.3739 - mean_absolute_error: 102.3739 - val_loss: 105.0014 - val_mean_absolute_error: 105.0014
# Epoch 62/700
# 56/56 [==============================] - 2s 33ms/step - loss: 101.8281 - mean_absolute_error: 101.8281 - val_loss: 103.9339 - val_mean_absolute_error: 103.9339
# Epoch 63/700
# 56/56 [==============================] - 0s 5ms/step - loss: 101.6000 - mean_absolute_error: 101.6000 - val_loss: 106.1658 - val_mean_absolute_error: 106.1658
# Epoch 64/700
# 56/56 [==============================] - 2s 31ms/step - loss: 99.9436 - mean_absolute_error: 99.9436 - val_loss: 99.2072 - val_mean_absolute_error: 99.2072
# Epoch 65/700
# 56/56 [==============================] - 0s 5ms/step - loss: 98.1942 - mean_absolute_error: 98.1942 - val_loss: 100.7542 - val_mean_absolute_error: 100.7542
# Epoch 66/700
# 56/56 [==============================] - 0s 6ms/step - loss: 98.4654 - mean_absolute_error: 98.4654 - val_loss: 100.5438 - val_mean_absolute_error: 100.5438
# Epoch 67/700
# 56/56 [==============================] - 2s 28ms/step - loss: 95.2201 - mean_absolute_error: 95.2201 - val_loss: 97.5006 - val_mean_absolute_error: 97.5006
# Epoch 68/700
# 56/56 [==============================] - 2s 28ms/step - loss: 97.9953 - mean_absolute_error: 97.9953 - val_loss: 96.3812 - val_mean_absolute_error: 96.3812
# Epoch 69/700
# 56/56 [==============================] - 0s 5ms/step - loss: 93.8467 - mean_absolute_error: 93.8467 - val_loss: 101.4157 - val_mean_absolute_error: 101.4157
# Epoch 70/700
# 56/56 [==============================] - 0s 6ms/step - loss: 95.9986 - mean_absolute_error: 95.9986 - val_loss: 107.3604 - val_mean_absolute_error: 107.3604
# Epoch 71/700
# 56/56 [==============================] - 0s 4ms/step - loss: 93.6961 - mean_absolute_error: 93.6961 - val_loss: 104.9050 - val_mean_absolute_error: 104.9050
# Epoch 72/700
# 56/56 [==============================] - 0s 5ms/step - loss: 93.6546 - mean_absolute_error: 93.6546 - val_loss: 101.3772 - val_mean_absolute_error: 101.3772
# Epoch 73/700
# 56/56 [==============================] - 0s 5ms/step - loss: 97.2424 - mean_absolute_error: 97.2424 - val_loss: 113.8260 - val_mean_absolute_error: 113.8260
# Epoch 74/700
# 56/56 [==============================] - 0s 5ms/step - loss: 91.4946 - mean_absolute_error: 91.4946 - val_loss: 101.1631 - val_mean_absolute_error: 101.1631
# Epoch 75/700
# 56/56 [==============================] - 0s 4ms/step - loss: 95.8388 - mean_absolute_error: 95.8388 - val_loss: 106.3655 - val_mean_absolute_error: 106.3655
# Epoch 76/700
# 56/56 [==============================] - 2s 33ms/step - loss: 92.6350 - mean_absolute_error: 92.6350 - val_loss: 91.9341 - val_mean_absolute_error: 91.9341
# Epoch 77/700
# 56/56 [==============================] - 0s 5ms/step - loss: 90.9703 - mean_absolute_error: 90.9703 - val_loss: 97.1734 - val_mean_absolute_error: 97.1734
# Epoch 78/700
# 56/56 [==============================] - 0s 4ms/step - loss: 91.9609 - mean_absolute_error: 91.9609 - val_loss: 104.0437 - val_mean_absolute_error: 104.0437
# Epoch 79/700
# 56/56 [==============================] - 0s 5ms/step - loss: 92.6552 - mean_absolute_error: 92.6552 - val_loss: 99.8304 - val_mean_absolute_error: 99.8304
# Epoch 80/700
# 56/56 [==============================] - 0s 5ms/step - loss: 94.7694 - mean_absolute_error: 94.7694 - val_loss: 96.5560 - val_mean_absolute_error: 96.5560
# Epoch 81/700
# 56/56 [==============================] - 0s 5ms/step - loss: 90.9964 - mean_absolute_error: 90.9964 - val_loss: 101.8335 - val_mean_absolute_error: 101.8335
# Epoch 82/700
# 56/56 [==============================] - 0s 5ms/step - loss: 93.0992 - mean_absolute_error: 93.0992 - val_loss: 92.8511 - val_mean_absolute_error: 92.8511
# Epoch 83/700
# 56/56 [==============================] - 0s 4ms/step - loss: 89.0800 - mean_absolute_error: 89.0800 - val_loss: 93.5854 - val_mean_absolute_error: 93.5854
# Epoch 84/700
# 56/56 [==============================] - 0s 4ms/step - loss: 88.5086 - mean_absolute_error: 88.5086 - val_loss: 107.1916 - val_mean_absolute_error: 107.1916
# Epoch 85/700
# 56/56 [==============================] - 2s 28ms/step - loss: 88.8032 - mean_absolute_error: 88.8032 - val_loss: 89.1436 - val_mean_absolute_error: 89.1436
# Epoch 86/700
# 56/56 [==============================] - 0s 5ms/step - loss: 87.7298 - mean_absolute_error: 87.7298 - val_loss: 90.5767 - val_mean_absolute_error: 90.5767
# Epoch 87/700
# 56/56 [==============================] - 0s 4ms/step - loss: 87.2371 - mean_absolute_error: 87.2371 - val_loss: 100.8881 - val_mean_absolute_error: 100.8881
# Epoch 88/700
# 56/56 [==============================] - 2s 27ms/step - loss: 86.3369 - mean_absolute_error: 86.3369 - val_loss: 87.5210 - val_mean_absolute_error: 87.5210
# Epoch 89/700
# 56/56 [==============================] - 0s 5ms/step - loss: 89.7812 - mean_absolute_error: 89.7812 - val_loss: 98.3737 - val_mean_absolute_error: 98.3737
# Epoch 90/700
# 56/56 [==============================] - 0s 5ms/step - loss: 89.4050 - mean_absolute_error: 89.4050 - val_loss: 108.9028 - val_mean_absolute_error: 108.9028
# Epoch 91/700
# 56/56 [==============================] - 0s 4ms/step - loss: 86.7919 - mean_absolute_error: 86.7919 - val_loss: 108.3527 - val_mean_absolute_error: 108.3527
# Epoch 92/700
# 56/56 [==============================] - 0s 4ms/step - loss: 89.2357 - mean_absolute_error: 89.2357 - val_loss: 98.1003 - val_mean_absolute_error: 98.1003
# Epoch 93/700
# 56/56 [==============================] - 0s 4ms/step - loss: 86.5263 - mean_absolute_error: 86.5263 - val_loss: 92.6286 - val_mean_absolute_error: 92.6286
# Epoch 94/700
# 56/56 [==============================] - 0s 4ms/step - loss: 87.0597 - mean_absolute_error: 87.0597 - val_loss: 99.0503 - val_mean_absolute_error: 99.0503
# Epoch 95/700
# 56/56 [==============================] - 0s 4ms/step - loss: 86.7970 - mean_absolute_error: 86.7970 - val_loss: 92.2747 - val_mean_absolute_error: 92.2747
# Epoch 96/700
# 56/56 [==============================] - 0s 5ms/step - loss: 86.7975 - mean_absolute_error: 86.7975 - val_loss: 93.4515 - val_mean_absolute_error: 93.4515
# Epoch 97/700
# 56/56 [==============================] - 1s 26ms/step - loss: 87.8567 - mean_absolute_error: 87.8567 - val_loss: 86.8196 - val_mean_absolute_error: 86.8196
# Epoch 98/700
# 56/56 [==============================] - 0s 4ms/step - loss: 85.0343 - mean_absolute_error: 85.0343 - val_loss: 87.1698 - val_mean_absolute_error: 87.1698
# Epoch 99/700
# 56/56 [==============================] - 0s 4ms/step - loss: 85.6183 - mean_absolute_error: 85.6183 - val_loss: 97.6535 - val_mean_absolute_error: 97.6535
# Epoch 100/700
# 56/56 [==============================] - 0s 4ms/step - loss: 85.2903 - mean_absolute_error: 85.2903 - val_loss: 89.1884 - val_mean_absolute_error: 89.1884
# Epoch 101/700
# 56/56 [==============================] - 0s 4ms/step - loss: 84.3871 - mean_absolute_error: 84.3871 - val_loss: 89.4290 - val_mean_absolute_error: 89.4290
# Epoch 102/700
# 56/56 [==============================] - 0s 4ms/step - loss: 84.7351 - mean_absolute_error: 84.7351 - val_loss: 102.4986 - val_mean_absolute_error: 102.4986
# Epoch 103/700
# 56/56 [==============================] - 0s 5ms/step - loss: 84.2200 - mean_absolute_error: 84.2200 - val_loss: 90.0274 - val_mean_absolute_error: 90.0274
# Epoch 104/700
# 56/56 [==============================] - 0s 4ms/step - loss: 85.5870 - mean_absolute_error: 85.5870 - val_loss: 89.8118 - val_mean_absolute_error: 89.8118
# Epoch 105/700
# 56/56 [==============================] - 1s 25ms/step - loss: 84.4601 - mean_absolute_error: 84.4601 - val_loss: 86.3052 - val_mean_absolute_error: 86.3052
# Epoch 106/700
# 56/56 [==============================] - 0s 4ms/step - loss: 83.1771 - mean_absolute_error: 83.1771 - val_loss: 88.4222 - val_mean_absolute_error: 88.4222
# Epoch 107/700
# 56/56 [==============================] - 0s 4ms/step - loss: 82.0209 - mean_absolute_error: 82.0209 - val_loss: 89.5388 - val_mean_absolute_error: 89.5388
# Epoch 108/700
# 56/56 [==============================] - 1s 26ms/step - loss: 81.9090 - mean_absolute_error: 81.9090 - val_loss: 82.5228 - val_mean_absolute_error: 82.5228
# Epoch 109/700
# 56/56 [==============================] - 0s 4ms/step - loss: 83.1922 - mean_absolute_error: 83.1922 - val_loss: 89.0138 - val_mean_absolute_error: 89.0138
# Epoch 110/700
# 56/56 [==============================] - 0s 5ms/step - loss: 83.7244 - mean_absolute_error: 83.7244 - val_loss: 86.4200 - val_mean_absolute_error: 86.4200
# Epoch 111/700
# 56/56 [==============================] - 0s 4ms/step - loss: 83.2892 - mean_absolute_error: 83.2892 - val_loss: 100.2715 - val_mean_absolute_error: 100.2715
# Epoch 112/700
# 56/56 [==============================] - 0s 4ms/step - loss: 87.3836 - mean_absolute_error: 87.3836 - val_loss: 96.4595 - val_mean_absolute_error: 96.4595
# Epoch 113/700
# 56/56 [==============================] - 2s 31ms/step - loss: 86.1280 - mean_absolute_error: 86.1280 - val_loss: 82.2108 - val_mean_absolute_error: 82.2108
# Epoch 114/700
# 56/56 [==============================] - 0s 5ms/step - loss: 83.5110 - mean_absolute_error: 83.5110 - val_loss: 103.0001 - val_mean_absolute_error: 103.0001
# Epoch 115/700
# 56/56 [==============================] - 2s 28ms/step - loss: 83.0769 - mean_absolute_error: 83.0769 - val_loss: 81.3261 - val_mean_absolute_error: 81.3261
# Epoch 116/700
# 56/56 [==============================] - 0s 4ms/step - loss: 80.7742 - mean_absolute_error: 80.7742 - val_loss: 83.4656 - val_mean_absolute_error: 83.4656
# Epoch 117/700
# 56/56 [==============================] - 0s 4ms/step - loss: 82.2925 - mean_absolute_error: 82.2925 - val_loss: 84.0527 - val_mean_absolute_error: 84.0527
# Epoch 118/700
# 56/56 [==============================] - 0s 4ms/step - loss: 82.0322 - mean_absolute_error: 82.0322 - val_loss: 85.0964 - val_mean_absolute_error: 85.0964
# Epoch 119/700
# 56/56 [==============================] - 2s 28ms/step - loss: 83.1286 - mean_absolute_error: 83.1286 - val_loss: 80.0690 - val_mean_absolute_error: 80.0690
# Epoch 120/700
# 56/56 [==============================] - 0s 5ms/step - loss: 79.2056 - mean_absolute_error: 79.2056 - val_loss: 84.5324 - val_mean_absolute_error: 84.5324
# Epoch 121/700
# 56/56 [==============================] - 0s 5ms/step - loss: 81.2240 - mean_absolute_error: 81.2240 - val_loss: 85.3746 - val_mean_absolute_error: 85.3746
# Epoch 122/700
# 56/56 [==============================] - 0s 5ms/step - loss: 82.5692 - mean_absolute_error: 82.5692 - val_loss: 80.0873 - val_mean_absolute_error: 80.0873
# Epoch 123/700
# 56/56 [==============================] - 0s 4ms/step - loss: 78.8918 - mean_absolute_error: 78.8918 - val_loss: 84.1854 - val_mean_absolute_error: 84.1854
# Epoch 124/700
# 56/56 [==============================] - 0s 5ms/step - loss: 79.1049 - mean_absolute_error: 79.1049 - val_loss: 83.6147 - val_mean_absolute_error: 83.6147
# Epoch 125/700
# 56/56 [==============================] - 0s 5ms/step - loss: 80.0305 - mean_absolute_error: 80.0305 - val_loss: 85.0223 - val_mean_absolute_error: 85.0223
# Epoch 126/700
# 56/56 [==============================] - 0s 5ms/step - loss: 79.2325 - mean_absolute_error: 79.2325 - val_loss: 82.9759 - val_mean_absolute_error: 82.9759
# Epoch 127/700
# 56/56 [==============================] - 0s 5ms/step - loss: 80.9897 - mean_absolute_error: 80.9897 - val_loss: 82.5193 - val_mean_absolute_error: 82.5193
# Epoch 128/700
# 56/56 [==============================] - 1s 27ms/step - loss: 80.5557 - mean_absolute_error: 80.5557 - val_loss: 79.5111 - val_mean_absolute_error: 79.5111
# Epoch 129/700
# 56/56 [==============================] - 0s 5ms/step - loss: 81.2230 - mean_absolute_error: 81.2230 - val_loss: 87.4696 - val_mean_absolute_error: 87.4696
# Epoch 130/700
# 56/56 [==============================] - 0s 4ms/step - loss: 79.1376 - mean_absolute_error: 79.1376 - val_loss: 82.4202 - val_mean_absolute_error: 82.4202
# Epoch 131/700
# 56/56 [==============================] - 0s 4ms/step - loss: 79.2344 - mean_absolute_error: 79.2344 - val_loss: 91.8356 - val_mean_absolute_error: 91.8356
# Epoch 132/700
# 56/56 [==============================] - 0s 5ms/step - loss: 77.2852 - mean_absolute_error: 77.2852 - val_loss: 85.1994 - val_mean_absolute_error: 85.1994
# Epoch 133/700
# 56/56 [==============================] - 0s 5ms/step - loss: 81.0461 - mean_absolute_error: 81.0461 - val_loss: 85.0686 - val_mean_absolute_error: 85.0686
# Epoch 134/700
# 56/56 [==============================] - 0s 4ms/step - loss: 79.9585 - mean_absolute_error: 79.9585 - val_loss: 84.4358 - val_mean_absolute_error: 84.4358
# Epoch 135/700
# 56/56 [==============================] - 1s 26ms/step - loss: 77.5535 - mean_absolute_error: 77.5535 - val_loss: 78.5918 - val_mean_absolute_error: 78.5918
# Epoch 136/700
# 56/56 [==============================] - 2s 33ms/step - loss: 77.0144 - mean_absolute_error: 77.0144 - val_loss: 78.2730 - val_mean_absolute_error: 78.2730
# Epoch 137/700
# 56/56 [==============================] - 0s 4ms/step - loss: 79.5028 - mean_absolute_error: 79.5028 - val_loss: 82.9025 - val_mean_absolute_error: 82.9025
# Epoch 138/700
# 56/56 [==============================] - 2s 27ms/step - loss: 78.2606 - mean_absolute_error: 78.2606 - val_loss: 77.7485 - val_mean_absolute_error: 77.7485
# Epoch 139/700
# 56/56 [==============================] - 0s 4ms/step - loss: 79.0426 - mean_absolute_error: 79.0426 - val_loss: 88.0569 - val_mean_absolute_error: 88.0569
# Epoch 140/700
# 56/56 [==============================] - 0s 5ms/step - loss: 77.1878 - mean_absolute_error: 77.1878 - val_loss: 84.0541 - val_mean_absolute_error: 84.0541
# Epoch 141/700
# 56/56 [==============================] - 0s 5ms/step - loss: 76.6920 - mean_absolute_error: 76.6920 - val_loss: 85.0182 - val_mean_absolute_error: 85.0182
# Epoch 142/700
# 56/56 [==============================] - 2s 27ms/step - loss: 77.6842 - mean_absolute_error: 77.6842 - val_loss: 77.1811 - val_mean_absolute_error: 77.1811
# Epoch 143/700
# 56/56 [==============================] - 0s 4ms/step - loss: 76.5743 - mean_absolute_error: 76.5743 - val_loss: 91.6064 - val_mean_absolute_error: 91.6064
# Epoch 144/700
# 56/56 [==============================] - 1s 27ms/step - loss: 77.2352 - mean_absolute_error: 77.2352 - val_loss: 75.3466 - val_mean_absolute_error: 75.3466
# Epoch 145/700
# 56/56 [==============================] - 0s 5ms/step - loss: 74.9446 - mean_absolute_error: 74.9446 - val_loss: 77.5150 - val_mean_absolute_error: 77.5150
# Epoch 146/700
# 56/56 [==============================] - 0s 4ms/step - loss: 75.5823 - mean_absolute_error: 75.5823 - val_loss: 79.9722 - val_mean_absolute_error: 79.9722
# Epoch 147/700
# 56/56 [==============================] - 0s 5ms/step - loss: 79.3046 - mean_absolute_error: 79.3046 - val_loss: 77.3168 - val_mean_absolute_error: 77.3168
# Epoch 148/700
# 56/56 [==============================] - 0s 5ms/step - loss: 81.3172 - mean_absolute_error: 81.3172 - val_loss: 78.6460 - val_mean_absolute_error: 78.6460
# Epoch 149/700
# 56/56 [==============================] - 0s 4ms/step - loss: 77.1582 - mean_absolute_error: 77.1582 - val_loss: 86.4333 - val_mean_absolute_error: 86.4333
# Epoch 150/700
# 56/56 [==============================] - 0s 4ms/step - loss: 78.3945 - mean_absolute_error: 78.3945 - val_loss: 76.6863 - val_mean_absolute_error: 76.6863
# Epoch 151/700
# 56/56 [==============================] - 0s 5ms/step - loss: 75.1793 - mean_absolute_error: 75.1793 - val_loss: 88.3501 - val_mean_absolute_error: 88.3501
# Epoch 152/700
# 56/56 [==============================] - 0s 5ms/step - loss: 77.6226 - mean_absolute_error: 77.6226 - val_loss: 75.4969 - val_mean_absolute_error: 75.4969
# Epoch 153/700
# 56/56 [==============================] - 0s 4ms/step - loss: 76.7138 - mean_absolute_error: 76.7138 - val_loss: 79.2023 - val_mean_absolute_error: 79.2023
# Epoch 154/700
# 56/56 [==============================] - 0s 4ms/step - loss: 74.8560 - mean_absolute_error: 74.8560 - val_loss: 88.6689 - val_mean_absolute_error: 88.6689
# Epoch 155/700
# 56/56 [==============================] - 0s 4ms/step - loss: 78.5132 - mean_absolute_error: 78.5132 - val_loss: 85.8979 - val_mean_absolute_error: 85.8979
# Epoch 156/700
# 56/56 [==============================] - 0s 4ms/step - loss: 81.8359 - mean_absolute_error: 81.8359 - val_loss: 76.9917 - val_mean_absolute_error: 76.9917
# Epoch 157/700
# 56/56 [==============================] - 0s 4ms/step - loss: 74.1639 - mean_absolute_error: 74.1639 - val_loss: 77.2186 - val_mean_absolute_error: 77.2186
# Epoch 158/700
# 56/56 [==============================] - 0s 4ms/step - loss: 75.4118 - mean_absolute_error: 75.4118 - val_loss: 77.6947 - val_mean_absolute_error: 77.6947
# Epoch 159/700
# 56/56 [==============================] - 0s 4ms/step - loss: 74.0126 - mean_absolute_error: 74.0126 - val_loss: 79.4587 - val_mean_absolute_error: 79.4587
# Epoch 160/700
# 56/56 [==============================] - 0s 4ms/step - loss: 73.0690 - mean_absolute_error: 73.0690 - val_loss: 80.0942 - val_mean_absolute_error: 80.0942
# Epoch 161/700
# 56/56 [==============================] - 1s 27ms/step - loss: 74.6464 - mean_absolute_error: 74.6464 - val_loss: 75.0358 - val_mean_absolute_error: 75.0358
# Epoch 162/700
# 56/56 [==============================] - 0s 4ms/step - loss: 74.3332 - mean_absolute_error: 74.3332 - val_loss: 79.8678 - val_mean_absolute_error: 79.8678
# Epoch 163/700
# 56/56 [==============================] - 0s 5ms/step - loss: 74.0851 - mean_absolute_error: 74.0851 - val_loss: 85.1822 - val_mean_absolute_error: 85.1822
# Epoch 164/700
# 56/56 [==============================] - 0s 4ms/step - loss: 78.9459 - mean_absolute_error: 78.9459 - val_loss: 102.5646 - val_mean_absolute_error: 102.5646
# Epoch 165/700
# 56/56 [==============================] - 0s 4ms/step - loss: 77.4723 - mean_absolute_error: 77.4723 - val_loss: 77.1914 - val_mean_absolute_error: 77.1914
# Epoch 166/700
# 56/56 [==============================] - 0s 4ms/step - loss: 73.8421 - mean_absolute_error: 73.8421 - val_loss: 78.5073 - val_mean_absolute_error: 78.5073
# Epoch 167/700
# 56/56 [==============================] - 0s 4ms/step - loss: 74.9786 - mean_absolute_error: 74.9786 - val_loss: 78.5688 - val_mean_absolute_error: 78.5688
# Epoch 168/700
# 56/56 [==============================] - 0s 4ms/step - loss: 74.0383 - mean_absolute_error: 74.0383 - val_loss: 80.1291 - val_mean_absolute_error: 80.1291
# Epoch 169/700
# 56/56 [==============================] - 0s 4ms/step - loss: 72.7201 - mean_absolute_error: 72.7201 - val_loss: 81.3099 - val_mean_absolute_error: 81.3099
# Epoch 170/700
# 56/56 [==============================] - 0s 4ms/step - loss: 75.4116 - mean_absolute_error: 75.4116 - val_loss: 88.1017 - val_mean_absolute_error: 88.1017
# Epoch 171/700
# 56/56 [==============================] - 0s 5ms/step - loss: 77.1516 - mean_absolute_error: 77.1516 - val_loss: 80.5921 - val_mean_absolute_error: 80.5921
# Epoch 172/700
# 56/56 [==============================] - 0s 4ms/step - loss: 73.7060 - mean_absolute_error: 73.7060 - val_loss: 75.2128 - val_mean_absolute_error: 75.2128
# Epoch 173/700
# 56/56 [==============================] - 0s 5ms/step - loss: 74.1355 - mean_absolute_error: 74.1355 - val_loss: 75.5040 - val_mean_absolute_error: 75.5040
# Epoch 174/700
# 56/56 [==============================] - 0s 4ms/step - loss: 71.6567 - mean_absolute_error: 71.6567 - val_loss: 76.0464 - val_mean_absolute_error: 76.0464
# Epoch 175/700
# 56/56 [==============================] - 0s 5ms/step - loss: 75.3965 - mean_absolute_error: 75.3965 - val_loss: 121.1367 - val_mean_absolute_error: 121.1367
# Epoch 176/700
# 56/56 [==============================] - 1s 25ms/step - loss: 79.3300 - mean_absolute_error: 79.3300 - val_loss: 74.2201 - val_mean_absolute_error: 74.2201
# Epoch 177/700
# 56/56 [==============================] - 2s 32ms/step - loss: 73.8360 - mean_absolute_error: 73.8360 - val_loss: 74.1701 - val_mean_absolute_error: 74.1701
# Epoch 178/700
# 56/56 [==============================] - 0s 5ms/step - loss: 76.1447 - mean_absolute_error: 76.1447 - val_loss: 75.5188 - val_mean_absolute_error: 75.5188
# Epoch 179/700
# 56/56 [==============================] - 0s 5ms/step - loss: 76.0219 - mean_absolute_error: 76.0219 - val_loss: 81.5471 - val_mean_absolute_error: 81.5471
# Epoch 180/700
# 56/56 [==============================] - 0s 5ms/step - loss: 72.6728 - mean_absolute_error: 72.6728 - val_loss: 74.6293 - val_mean_absolute_error: 74.6293
# Epoch 181/700
# 56/56 [==============================] - 0s 5ms/step - loss: 71.1687 - mean_absolute_error: 71.1687 - val_loss: 74.1725 - val_mean_absolute_error: 74.1725
# Epoch 182/700
# 56/56 [==============================] - 2s 28ms/step - loss: 71.5686 - mean_absolute_error: 71.5686 - val_loss: 73.4154 - val_mean_absolute_error: 73.4154
# Epoch 183/700
# 56/56 [==============================] - 0s 5ms/step - loss: 71.7885 - mean_absolute_error: 71.7885 - val_loss: 83.0969 - val_mean_absolute_error: 83.0969
# Epoch 184/700
# 56/56 [==============================] - 0s 5ms/step - loss: 74.3182 - mean_absolute_error: 74.3182 - val_loss: 76.0568 - val_mean_absolute_error: 76.0568
# Epoch 185/700
# 56/56 [==============================] - 0s 6ms/step - loss: 71.6481 - mean_absolute_error: 71.6481 - val_loss: 75.1606 - val_mean_absolute_error: 75.1606
# Epoch 186/700
# 56/56 [==============================] - 0s 8ms/step - loss: 74.5173 - mean_absolute_error: 74.5173 - val_loss: 77.0690 - val_mean_absolute_error: 77.0690
# Epoch 187/700
# 56/56 [==============================] - 0s 7ms/step - loss: 71.1056 - mean_absolute_error: 71.1056 - val_loss: 76.3648 - val_mean_absolute_error: 76.3648
# Epoch 188/700
# 56/56 [==============================] - 0s 8ms/step - loss: 71.6685 - mean_absolute_error: 71.6685 - val_loss: 76.7717 - val_mean_absolute_error: 76.7717
# Epoch 189/700
# 56/56 [==============================] - 0s 8ms/step - loss: 70.8449 - mean_absolute_error: 70.8449 - val_loss: 80.5916 - val_mean_absolute_error: 80.5916
# Epoch 190/700
# 56/56 [==============================] - 0s 8ms/step - loss: 72.2139 - mean_absolute_error: 72.2139 - val_loss: 79.1611 - val_mean_absolute_error: 79.1611
# Epoch 191/700
# 56/56 [==============================] - 2s 40ms/step - loss: 74.9377 - mean_absolute_error: 74.9377 - val_loss: 71.2949 - val_mean_absolute_error: 71.2949
# Epoch 192/700
# 56/56 [==============================] - 0s 4ms/step - loss: 71.1272 - mean_absolute_error: 71.1272 - val_loss: 78.2441 - val_mean_absolute_error: 78.2441
# Epoch 193/700
# 56/56 [==============================] - 0s 5ms/step - loss: 75.6887 - mean_absolute_error: 75.6887 - val_loss: 72.6594 - val_mean_absolute_error: 72.6594
# Epoch 194/700
# 56/56 [==============================] - 0s 5ms/step - loss: 71.4754 - mean_absolute_error: 71.4754 - val_loss: 76.6327 - val_mean_absolute_error: 76.6327
# Epoch 195/700
# 56/56 [==============================] - 0s 5ms/step - loss: 70.8946 - mean_absolute_error: 70.8946 - val_loss: 82.7855 - val_mean_absolute_error: 82.7855
# Epoch 196/700
# 56/56 [==============================] - 0s 5ms/step - loss: 71.1216 - mean_absolute_error: 71.1216 - val_loss: 84.0002 - val_mean_absolute_error: 84.0002
# Epoch 197/700
# 56/56 [==============================] - 0s 5ms/step - loss: 70.0653 - mean_absolute_error: 70.0653 - val_loss: 77.1446 - val_mean_absolute_error: 77.1446
# Epoch 198/700
# 56/56 [==============================] - 0s 5ms/step - loss: 71.2725 - mean_absolute_error: 71.2725 - val_loss: 72.8949 - val_mean_absolute_error: 72.8949
# Epoch 199/700
# 56/56 [==============================] - 0s 5ms/step - loss: 73.8662 - mean_absolute_error: 73.8662 - val_loss: 76.4682 - val_mean_absolute_error: 76.4682
# Epoch 200/700
# 56/56 [==============================] - 0s 5ms/step - loss: 69.9175 - mean_absolute_error: 69.9175 - val_loss: 75.0955 - val_mean_absolute_error: 75.0955
# Epoch 201/700
# 56/56 [==============================] - 0s 5ms/step - loss: 72.3721 - mean_absolute_error: 72.3721 - val_loss: 75.0973 - val_mean_absolute_error: 75.0973
# Epoch 202/700
# 56/56 [==============================] - 0s 5ms/step - loss: 71.0829 - mean_absolute_error: 71.0829 - val_loss: 79.3261 - val_mean_absolute_error: 79.3261
# Epoch 203/700
# 56/56 [==============================] - 0s 5ms/step - loss: 70.3276 - mean_absolute_error: 70.3276 - val_loss: 83.3951 - val_mean_absolute_error: 83.3951
# Epoch 204/700
# 56/56 [==============================] - 0s 5ms/step - loss: 75.3572 - mean_absolute_error: 75.3572 - val_loss: 75.5536 - val_mean_absolute_error: 75.5536
# Epoch 205/700
# 56/56 [==============================] - 0s 5ms/step - loss: 71.2263 - mean_absolute_error: 71.2263 - val_loss: 73.1204 - val_mean_absolute_error: 73.1204
# Epoch 206/700
# 56/56 [==============================] - 0s 6ms/step - loss: 71.2199 - mean_absolute_error: 71.2199 - val_loss: 73.1666 - val_mean_absolute_error: 73.1666
# Epoch 207/700
# 56/56 [==============================] - 0s 5ms/step - loss: 71.4308 - mean_absolute_error: 71.4308 - val_loss: 74.5068 - val_mean_absolute_error: 74.5068
# Epoch 208/700
# 56/56 [==============================] - 2s 28ms/step - loss: 71.6351 - mean_absolute_error: 71.6351 - val_loss: 70.0299 - val_mean_absolute_error: 70.0299
# Epoch 209/700
# 56/56 [==============================] - 0s 5ms/step - loss: 71.5002 - mean_absolute_error: 71.5002 - val_loss: 72.6721 - val_mean_absolute_error: 72.6721
# Epoch 210/700
# 56/56 [==============================] - 0s 5ms/step - loss: 72.7173 - mean_absolute_error: 72.7173 - val_loss: 80.3918 - val_mean_absolute_error: 80.3918
# Epoch 211/700
# 56/56 [==============================] - 0s 5ms/step - loss: 69.8439 - mean_absolute_error: 69.8439 - val_loss: 70.6243 - val_mean_absolute_error: 70.6243
# Epoch 212/700
# 56/56 [==============================] - 0s 5ms/step - loss: 72.3734 - mean_absolute_error: 72.3734 - val_loss: 77.6311 - val_mean_absolute_error: 77.6311
# Epoch 213/700
# 56/56 [==============================] - 2s 28ms/step - loss: 72.0368 - mean_absolute_error: 72.0368 - val_loss: 68.8074 - val_mean_absolute_error: 68.8074
# Epoch 214/700
# 56/56 [==============================] - 0s 5ms/step - loss: 70.2935 - mean_absolute_error: 70.2935 - val_loss: 69.2338 - val_mean_absolute_error: 69.2338
# Epoch 215/700
# 56/56 [==============================] - 0s 5ms/step - loss: 68.6031 - mean_absolute_error: 68.6031 - val_loss: 76.9376 - val_mean_absolute_error: 76.9376
# Epoch 216/700
# 56/56 [==============================] - 0s 5ms/step - loss: 69.4269 - mean_absolute_error: 69.4269 - val_loss: 77.3862 - val_mean_absolute_error: 77.3862
# Epoch 217/700
# 56/56 [==============================] - 0s 5ms/step - loss: 71.0242 - mean_absolute_error: 71.0242 - val_loss: 75.7140 - val_mean_absolute_error: 75.7140
# Epoch 218/700
# 56/56 [==============================] - 0s 4ms/step - loss: 73.1876 - mean_absolute_error: 73.1876 - val_loss: 87.0845 - val_mean_absolute_error: 87.0845
# Epoch 219/700
# 56/56 [==============================] - 0s 5ms/step - loss: 70.8229 - mean_absolute_error: 70.8229 - val_loss: 70.5403 - val_mean_absolute_error: 70.5403
# Epoch 220/700
# 56/56 [==============================] - 1s 26ms/step - loss: 67.2401 - mean_absolute_error: 67.2401 - val_loss: 67.9378 - val_mean_absolute_error: 67.9378
# Epoch 221/700
# 56/56 [==============================] - 0s 4ms/step - loss: 70.5710 - mean_absolute_error: 70.5710 - val_loss: 73.6092 - val_mean_absolute_error: 73.6092
# Epoch 222/700
# 56/56 [==============================] - 0s 5ms/step - loss: 71.2105 - mean_absolute_error: 71.2105 - val_loss: 70.6909 - val_mean_absolute_error: 70.6909
# Epoch 223/700
# 56/56 [==============================] - 0s 5ms/step - loss: 67.2407 - mean_absolute_error: 67.2407 - val_loss: 69.5924 - val_mean_absolute_error: 69.5924
# Epoch 224/700
# 56/56 [==============================] - 0s 4ms/step - loss: 69.1208 - mean_absolute_error: 69.1208 - val_loss: 70.5091 - val_mean_absolute_error: 70.5091
# Epoch 225/700
# 56/56 [==============================] - 0s 5ms/step - loss: 66.7093 - mean_absolute_error: 66.7093 - val_loss: 73.8404 - val_mean_absolute_error: 73.8404
# Epoch 226/700
# 56/56 [==============================] - 0s 5ms/step - loss: 69.0725 - mean_absolute_error: 69.0725 - val_loss: 70.8479 - val_mean_absolute_error: 70.8479
# Epoch 227/700
# 56/56 [==============================] - 0s 5ms/step - loss: 69.4767 - mean_absolute_error: 69.4767 - val_loss: 73.6719 - val_mean_absolute_error: 73.6719
# Epoch 228/700
# 56/56 [==============================] - 0s 5ms/step - loss: 69.6128 - mean_absolute_error: 69.6128 - val_loss: 74.7203 - val_mean_absolute_error: 74.7203
# Epoch 229/700
# 56/56 [==============================] - 0s 5ms/step - loss: 69.4224 - mean_absolute_error: 69.4224 - val_loss: 86.4405 - val_mean_absolute_error: 86.4405
# Epoch 230/700
# 56/56 [==============================] - 0s 5ms/step - loss: 69.0540 - mean_absolute_error: 69.0540 - val_loss: 72.2853 - val_mean_absolute_error: 72.2853
# Epoch 231/700
# 56/56 [==============================] - 0s 5ms/step - loss: 66.7997 - mean_absolute_error: 66.7997 - val_loss: 69.4634 - val_mean_absolute_error: 69.4634
# Epoch 232/700
# 56/56 [==============================] - 0s 4ms/step - loss: 68.8770 - mean_absolute_error: 68.8770 - val_loss: 75.9052 - val_mean_absolute_error: 75.9052
# Epoch 233/700
# 56/56 [==============================] - 0s 5ms/step - loss: 73.5246 - mean_absolute_error: 73.5246 - val_loss: 87.0952 - val_mean_absolute_error: 87.0952
# Epoch 234/700
# 56/56 [==============================] - 0s 5ms/step - loss: 72.8432 - mean_absolute_error: 72.8432 - val_loss: 83.4636 - val_mean_absolute_error: 83.4636
# Epoch 235/700
# 56/56 [==============================] - 2s 31ms/step - loss: 69.9248 - mean_absolute_error: 69.9248 - val_loss: 67.5972 - val_mean_absolute_error: 67.5972
# Epoch 236/700
# 56/56 [==============================] - 0s 5ms/step - loss: 65.4849 - mean_absolute_error: 65.4849 - val_loss: 70.0679 - val_mean_absolute_error: 70.0679
# Epoch 237/700
# 56/56 [==============================] - 0s 5ms/step - loss: 69.3590 - mean_absolute_error: 69.3590 - val_loss: 71.9158 - val_mean_absolute_error: 71.9158
# Epoch 238/700
# 56/56 [==============================] - 0s 4ms/step - loss: 67.1660 - mean_absolute_error: 67.1660 - val_loss: 82.8424 - val_mean_absolute_error: 82.8424
# Epoch 239/700
# 56/56 [==============================] - 0s 5ms/step - loss: 65.8815 - mean_absolute_error: 65.8815 - val_loss: 69.5359 - val_mean_absolute_error: 69.5359
# Epoch 240/700
# 56/56 [==============================] - 0s 5ms/step - loss: 66.6209 - mean_absolute_error: 66.6209 - val_loss: 69.1387 - val_mean_absolute_error: 69.1387
# Epoch 241/700
# 56/56 [==============================] - 0s 4ms/step - loss: 66.0664 - mean_absolute_error: 66.0664 - val_loss: 79.0468 - val_mean_absolute_error: 79.0468
# Epoch 242/700
# 56/56 [==============================] - 0s 5ms/step - loss: 68.1845 - mean_absolute_error: 68.1845 - val_loss: 69.3988 - val_mean_absolute_error: 69.3988
# Epoch 243/700
# 56/56 [==============================] - 0s 5ms/step - loss: 68.7945 - mean_absolute_error: 68.7945 - val_loss: 69.8847 - val_mean_absolute_error: 69.8847
# Epoch 244/700
# 56/56 [==============================] - 0s 5ms/step - loss: 68.2117 - mean_absolute_error: 68.2117 - val_loss: 80.4274 - val_mean_absolute_error: 80.4274
# Epoch 245/700
# 56/56 [==============================] - 0s 5ms/step - loss: 67.4761 - mean_absolute_error: 67.4761 - val_loss: 78.3745 - val_mean_absolute_error: 78.3745
# Epoch 246/700
# 56/56 [==============================] - 0s 4ms/step - loss: 66.5758 - mean_absolute_error: 66.5758 - val_loss: 68.2524 - val_mean_absolute_error: 68.2524
# Epoch 247/700
# 56/56 [==============================] - 0s 5ms/step - loss: 70.7714 - mean_absolute_error: 70.7714 - val_loss: 76.7519 - val_mean_absolute_error: 76.7519
# Epoch 248/700
# 56/56 [==============================] - 0s 5ms/step - loss: 68.9266 - mean_absolute_error: 68.9266 - val_loss: 69.5760 - val_mean_absolute_error: 69.5760
# Epoch 249/700
# 56/56 [==============================] - 0s 5ms/step - loss: 66.4653 - mean_absolute_error: 66.4653 - val_loss: 79.7416 - val_mean_absolute_error: 79.7416
# Epoch 250/700
# 56/56 [==============================] - 0s 6ms/step - loss: 66.3820 - mean_absolute_error: 66.3820 - val_loss: 72.0310 - val_mean_absolute_error: 72.0310
# Epoch 251/700
# 56/56 [==============================] - 0s 5ms/step - loss: 71.2734 - mean_absolute_error: 71.2734 - val_loss: 72.1241 - val_mean_absolute_error: 72.1241
# Epoch 252/700
# 56/56 [==============================] - 0s 6ms/step - loss: 66.4190 - mean_absolute_error: 66.4190 - val_loss: 72.9482 - val_mean_absolute_error: 72.9482
# Epoch 253/700
# 56/56 [==============================] - 0s 5ms/step - loss: 67.0914 - mean_absolute_error: 67.0914 - val_loss: 70.1158 - val_mean_absolute_error: 70.1158
# Epoch 254/700
# 56/56 [==============================] - 2s 28ms/step - loss: 66.4033 - mean_absolute_error: 66.4033 - val_loss: 65.1824 - val_mean_absolute_error: 65.1824
# Epoch 255/700
# 56/56 [==============================] - 0s 5ms/step - loss: 64.0573 - mean_absolute_error: 64.0573 - val_loss: 75.7054 - val_mean_absolute_error: 75.7054
# Epoch 256/700
# 56/56 [==============================] - 0s 6ms/step - loss: 65.5939 - mean_absolute_error: 65.5939 - val_loss: 68.7182 - val_mean_absolute_error: 68.7182
# Epoch 257/700
# 56/56 [==============================] - 0s 5ms/step - loss: 68.7268 - mean_absolute_error: 68.7268 - val_loss: 76.4032 - val_mean_absolute_error: 76.4032
# Epoch 258/700
# 56/56 [==============================] - 0s 5ms/step - loss: 68.1398 - mean_absolute_error: 68.1398 - val_loss: 66.1075 - val_mean_absolute_error: 66.1075
# Epoch 259/700
# 56/56 [==============================] - 0s 5ms/step - loss: 66.5772 - mean_absolute_error: 66.5772 - val_loss: 68.8449 - val_mean_absolute_error: 68.8449
# Epoch 260/700
# 56/56 [==============================] - 0s 6ms/step - loss: 72.7640 - mean_absolute_error: 72.7640 - val_loss: 71.3706 - val_mean_absolute_error: 71.3706
# Epoch 261/700
# 56/56 [==============================] - 0s 5ms/step - loss: 74.2645 - mean_absolute_error: 74.2645 - val_loss: 76.7323 - val_mean_absolute_error: 76.7323
# Epoch 262/700
# 56/56 [==============================] - 0s 5ms/step - loss: 67.2493 - mean_absolute_error: 67.2493 - val_loss: 78.8304 - val_mean_absolute_error: 78.8304
# Epoch 263/700
# 56/56 [==============================] - 0s 5ms/step - loss: 65.2281 - mean_absolute_error: 65.2281 - val_loss: 76.5177 - val_mean_absolute_error: 76.5177
# Epoch 264/700
# 56/56 [==============================] - 0s 5ms/step - loss: 65.0347 - mean_absolute_error: 65.0347 - val_loss: 70.5458 - val_mean_absolute_error: 70.5458
# Epoch 265/700
# 56/56 [==============================] - 0s 5ms/step - loss: 65.2257 - mean_absolute_error: 65.2257 - val_loss: 65.5228 - val_mean_absolute_error: 65.5228
# Epoch 266/700
# 56/56 [==============================] - 0s 5ms/step - loss: 64.8492 - mean_absolute_error: 64.8492 - val_loss: 72.6407 - val_mean_absolute_error: 72.6407
# Epoch 267/700
# 56/56 [==============================] - 0s 5ms/step - loss: 64.4035 - mean_absolute_error: 64.4035 - val_loss: 66.7852 - val_mean_absolute_error: 66.7852
# Epoch 268/700
# 56/56 [==============================] - 0s 5ms/step - loss: 64.9205 - mean_absolute_error: 64.9205 - val_loss: 66.9624 - val_mean_absolute_error: 66.9624
# Epoch 269/700
# 56/56 [==============================] - 0s 5ms/step - loss: 67.7722 - mean_absolute_error: 67.7722 - val_loss: 68.1166 - val_mean_absolute_error: 68.1166
# Epoch 270/700
# 56/56 [==============================] - 0s 5ms/step - loss: 67.3219 - mean_absolute_error: 67.3219 - val_loss: 66.3263 - val_mean_absolute_error: 66.3263
# Epoch 271/700
# 56/56 [==============================] - 0s 5ms/step - loss: 63.1313 - mean_absolute_error: 63.1313 - val_loss: 75.9334 - val_mean_absolute_error: 75.9334
# Epoch 272/700
# 56/56 [==============================] - 0s 5ms/step - loss: 65.5401 - mean_absolute_error: 65.5401 - val_loss: 71.3002 - val_mean_absolute_error: 71.3002
# Epoch 273/700
# 56/56 [==============================] - 2s 27ms/step - loss: 63.2870 - mean_absolute_error: 63.2870 - val_loss: 63.5053 - val_mean_absolute_error: 63.5053
# Epoch 274/700
# 56/56 [==============================] - 0s 5ms/step - loss: 68.1809 - mean_absolute_error: 68.1809 - val_loss: 65.2838 - val_mean_absolute_error: 65.2838
# Epoch 275/700
# 56/56 [==============================] - 0s 5ms/step - loss: 63.4570 - mean_absolute_error: 63.4570 - val_loss: 65.3437 - val_mean_absolute_error: 65.3437
# Epoch 276/700
# 56/56 [==============================] - 0s 5ms/step - loss: 64.8911 - mean_absolute_error: 64.8911 - val_loss: 72.3637 - val_mean_absolute_error: 72.3637
# Epoch 277/700
# 56/56 [==============================] - 0s 5ms/step - loss: 63.1428 - mean_absolute_error: 63.1428 - val_loss: 68.7774 - val_mean_absolute_error: 68.7774
# Epoch 278/700
# 56/56 [==============================] - 0s 5ms/step - loss: 63.0703 - mean_absolute_error: 63.0703 - val_loss: 71.0873 - val_mean_absolute_error: 71.0873
# Epoch 279/700
# 56/56 [==============================] - 0s 5ms/step - loss: 63.8600 - mean_absolute_error: 63.8600 - val_loss: 66.2809 - val_mean_absolute_error: 66.2809
# Epoch 280/700
# 56/56 [==============================] - 0s 5ms/step - loss: 64.9728 - mean_absolute_error: 64.9728 - val_loss: 70.8516 - val_mean_absolute_error: 70.8516
# Epoch 281/700
# 56/56 [==============================] - 0s 5ms/step - loss: 65.4080 - mean_absolute_error: 65.4080 - val_loss: 65.9776 - val_mean_absolute_error: 65.9776
# Epoch 282/700
# 56/56 [==============================] - 0s 5ms/step - loss: 63.6098 - mean_absolute_error: 63.6098 - val_loss: 76.0463 - val_mean_absolute_error: 76.0463
# Epoch 283/700
# ...
# Epoch 607/700
# 56/56 [==============================] - 0s 6ms/step - loss: 48.2862 - mean_absolute_error: 48.2862 - val_loss: 56.1147 - val_mean_absolute_error: 56.1147
# Epoch 608/700
# 56/56 [==============================] - 0s 6ms/step - loss: 44.7512 - mean_absolute_error: 44.7512 - val_loss: 52.4023 - val_mean_absolute_error: 52.4023
# Epoch 609/700
# 56/56 [==============================] - 0s 6ms/step - loss: 47.2032 - mean_absolute_error: 47.2032 - val_loss: 48.5408 - val_mean_absolute_error: 48.5408
# Epoch 610/700
# 56/56 [==============================] - 0s 5ms/step - loss: 49.5436 - mean_absolute_error: 49.5436 - val_loss: 51.2951 - val_mean_absolute_error: 51.2951
# Epoch 611/700
# 56/56 [==============================] - 0s 6ms/step - loss: 45.6015 - mean_absolute_error: 45.6015 - val_loss: 48.0068 - val_mean_absolute_error: 48.0068
# Epoch 612/700
# 56/56 [==============================] - 0s 5ms/step - loss: 46.9755 - mean_absolute_error: 46.9755 - val_loss: 52.9755 - val_mean_absolute_error: 52.9755
# Epoch 613/700
# 56/56 [==============================] - 0s 5ms/step - loss: 47.0740 - mean_absolute_error: 47.0740 - val_loss: 53.5259 - val_mean_absolute_error: 53.5259
# Epoch 614/700
# 56/56 [==============================] - 0s 5ms/step - loss: 48.4135 - mean_absolute_error: 48.4135 - val_loss: 50.2391 - val_mean_absolute_error: 50.2391
# Epoch 615/700
# 56/56 [==============================] - 0s 5ms/step - loss: 48.4585 - mean_absolute_error: 48.4585 - val_loss: 57.2246 - val_mean_absolute_error: 57.2246
# Epoch 616/700
# 56/56 [==============================] - 0s 5ms/step - loss: 47.5649 - mean_absolute_error: 47.5649 - val_loss: 49.5358 - val_mean_absolute_error: 49.5358
# Epoch 617/700
# 56/56 [==============================] - 0s 5ms/step - loss: 49.5946 - mean_absolute_error: 49.5946 - val_loss: 50.8218 - val_mean_absolute_error: 50.8218
# Epoch 618/700
# 56/56 [==============================] - 0s 6ms/step - loss: 46.8312 - mean_absolute_error: 46.8312 - val_loss: 48.0664 - val_mean_absolute_error: 48.0664
# Epoch 619/700
# 56/56 [==============================] - 0s 5ms/step - loss: 45.6474 - mean_absolute_error: 45.6474 - val_loss: 49.3940 - val_mean_absolute_error: 49.3940
# Epoch 620/700
# 56/56 [==============================] - 0s 5ms/step - loss: 45.6300 - mean_absolute_error: 45.6300 - val_loss: 47.9227 - val_mean_absolute_error: 47.9227
# Epoch 621/700
# 56/56 [==============================] - 1s 27ms/step - loss: 46.6680 - mean_absolute_error: 46.6680 - val_loss: 47.1549 - val_mean_absolute_error: 47.1549
# Epoch 622/700
# 56/56 [==============================] - 0s 6ms/step - loss: 45.2230 - mean_absolute_error: 45.2230 - val_loss: 59.8048 - val_mean_absolute_error: 59.8048
# Epoch 623/700
# 56/56 [==============================] - 0s 6ms/step - loss: 46.1997 - mean_absolute_error: 46.1997 - val_loss: 53.6239 - val_mean_absolute_error: 53.6239
# Epoch 624/700
# 56/56 [==============================] - 0s 7ms/step - loss: 47.0504 - mean_absolute_error: 47.0504 - val_loss: 55.3761 - val_mean_absolute_error: 55.3761
# Epoch 625/700
# 56/56 [==============================] - 0s 6ms/step - loss: 49.9547 - mean_absolute_error: 49.9547 - val_loss: 62.7902 - val_mean_absolute_error: 62.7902
# Epoch 626/700
# 56/56 [==============================] - 0s 6ms/step - loss: 47.1980 - mean_absolute_error: 47.1980 - val_loss: 47.4224 - val_mean_absolute_error: 47.4224
# Epoch 627/700
# 56/56 [==============================] - 0s 6ms/step - loss: 47.6887 - mean_absolute_error: 47.6887 - val_loss: 49.6781 - val_mean_absolute_error: 49.6781
# Epoch 628/700
# 56/56 [==============================] - 0s 6ms/step - loss: 46.3847 - mean_absolute_error: 46.3847 - val_loss: 55.7401 - val_mean_absolute_error: 55.7401
# Epoch 629/700
# 56/56 [==============================] - 0s 7ms/step - loss: 46.1565 - mean_absolute_error: 46.1565 - val_loss: 51.8112 - val_mean_absolute_error: 51.8112
# Epoch 630/700
# 56/56 [==============================] - 0s 7ms/step - loss: 46.0703 - mean_absolute_error: 46.0703 - val_loss: 47.1974 - val_mean_absolute_error: 47.1974
# Epoch 631/700
# 56/56 [==============================] - 2s 30ms/step - loss: 45.0142 - mean_absolute_error: 45.0142 - val_loss: 46.7306 - val_mean_absolute_error: 46.7306
# Epoch 632/700
# 56/56 [==============================] - 0s 6ms/step - loss: 47.2046 - mean_absolute_error: 47.2046 - val_loss: 53.2985 - val_mean_absolute_error: 53.2985
# Epoch 633/700
# 56/56 [==============================] - 0s 6ms/step - loss: 46.3421 - mean_absolute_error: 46.3421 - val_loss: 48.1359 - val_mean_absolute_error: 48.1359
# Epoch 634/700
# 56/56 [==============================] - 0s 6ms/step - loss: 46.6264 - mean_absolute_error: 46.6264 - val_loss: 57.0023 - val_mean_absolute_error: 57.0023
# Epoch 635/700
# 56/56 [==============================] - 0s 6ms/step - loss: 44.9714 - mean_absolute_error: 44.9714 - val_loss: 48.1339 - val_mean_absolute_error: 48.1339
# Epoch 636/700
# 56/56 [==============================] - 0s 7ms/step - loss: 45.5675 - mean_absolute_error: 45.5675 - val_loss: 51.4756 - val_mean_absolute_error: 51.4756
# Epoch 637/700
# 56/56 [==============================] - 0s 5ms/step - loss: 45.8804 - mean_absolute_error: 45.8804 - val_loss: 54.9777 - val_mean_absolute_error: 54.9777
# Epoch 638/700
# 56/56 [==============================] - 0s 6ms/step - loss: 48.2688 - mean_absolute_error: 48.2688 - val_loss: 48.8137 - val_mean_absolute_error: 48.8137
# Epoch 639/700
# 56/56 [==============================] - 0s 5ms/step - loss: 46.6714 - mean_absolute_error: 46.6714 - val_loss: 47.1473 - val_mean_absolute_error: 47.1473
# Epoch 640/700
# 56/56 [==============================] - 0s 5ms/step - loss: 46.2021 - mean_absolute_error: 46.2021 - val_loss: 52.3310 - val_mean_absolute_error: 52.3310
# Epoch 641/700
# 56/56 [==============================] - 0s 6ms/step - loss: 45.0300 - mean_absolute_error: 45.0300 - val_loss: 50.6113 - val_mean_absolute_error: 50.6113
# Epoch 642/700
# 56/56 [==============================] - 0s 6ms/step - loss: 48.5762 - mean_absolute_error: 48.5762 - val_loss: 50.9654 - val_mean_absolute_error: 50.9654
# Epoch 643/700
# 56/56 [==============================] - 0s 6ms/step - loss: 45.9536 - mean_absolute_error: 45.9536 - val_loss: 51.4151 - val_mean_absolute_error: 51.4151
# Epoch 644/700
# 56/56 [==============================] - 0s 7ms/step - loss: 45.4275 - mean_absolute_error: 45.4275 - val_loss: 47.8532 - val_mean_absolute_error: 47.8532
# Epoch 645/700
# 56/56 [==============================] - 0s 6ms/step - loss: 47.1788 - mean_absolute_error: 47.1788 - val_loss: 49.6115 - val_mean_absolute_error: 49.6115
# Epoch 646/700
# 56/56 [==============================] - 0s 6ms/step - loss: 44.1656 - mean_absolute_error: 44.1656 - val_loss: 50.7400 - val_mean_absolute_error: 50.7400
# Epoch 647/700
# 56/56 [==============================] - 0s 6ms/step - loss: 44.0551 - mean_absolute_error: 44.0551 - val_loss: 50.4468 - val_mean_absolute_error: 50.4468
# Epoch 648/700
# 56/56 [==============================] - 0s 6ms/step - loss: 44.0204 - mean_absolute_error: 44.0204 - val_loss: 57.1912 - val_mean_absolute_error: 57.1912
# Epoch 649/700
# 56/56 [==============================] - 0s 6ms/step - loss: 46.0668 - mean_absolute_error: 46.0668 - val_loss: 54.6301 - val_mean_absolute_error: 54.6301
# Epoch 650/700
# 56/56 [==============================] - 0s 6ms/step - loss: 48.5955 - mean_absolute_error: 48.5955 - val_loss: 50.0706 - val_mean_absolute_error: 50.0706
# Epoch 651/700
# 56/56 [==============================] - 0s 5ms/step - loss: 48.5125 - mean_absolute_error: 48.5125 - val_loss: 62.2264 - val_mean_absolute_error: 62.2264
# Epoch 652/700
# 56/56 [==============================] - 0s 7ms/step - loss: 47.3221 - mean_absolute_error: 47.3221 - val_loss: 57.3407 - val_mean_absolute_error: 57.3407
# Epoch 653/700
# 56/56 [==============================] - 0s 6ms/step - loss: 47.1627 - mean_absolute_error: 47.1627 - val_loss: 47.9310 - val_mean_absolute_error: 47.9310
# Epoch 654/700
# 56/56 [==============================] - 0s 6ms/step - loss: 45.3894 - mean_absolute_error: 45.3894 - val_loss: 59.8603 - val_mean_absolute_error: 59.8603
# Epoch 655/700
# 56/56 [==============================] - 0s 6ms/step - loss: 47.4708 - mean_absolute_error: 47.4708 - val_loss: 48.6084 - val_mean_absolute_error: 48.6084
# Epoch 656/700
# 56/56 [==============================] - 0s 6ms/step - loss: 43.6925 - mean_absolute_error: 43.6925 - val_loss: 49.0778 - val_mean_absolute_error: 49.0778
# Epoch 657/700
# 56/56 [==============================] - 0s 5ms/step - loss: 45.9570 - mean_absolute_error: 45.9570 - val_loss: 47.5632 - val_mean_absolute_error: 47.5632
# Epoch 658/700
# 56/56 [==============================] - 0s 6ms/step - loss: 45.1472 - mean_absolute_error: 45.1472 - val_loss: 57.3003 - val_mean_absolute_error: 57.3003
# Epoch 659/700
# 56/56 [==============================] - 0s 6ms/step - loss: 48.6931 - mean_absolute_error: 48.6931 - val_loss: 48.3072 - val_mean_absolute_error: 48.3072
# Epoch 660/700
# 56/56 [==============================] - 0s 6ms/step - loss: 45.4029 - mean_absolute_error: 45.4029 - val_loss: 48.2235 - val_mean_absolute_error: 48.2235
# Epoch 661/700
# 56/56 [==============================] - 0s 6ms/step - loss: 45.2985 - mean_absolute_error: 45.2985 - val_loss: 48.6458 - val_mean_absolute_error: 48.6458
# Epoch 662/700
# 56/56 [==============================] - 0s 7ms/step - loss: 46.2156 - mean_absolute_error: 46.2156 - val_loss: 47.0318 - val_mean_absolute_error: 47.0318
# Epoch 663/700
# 56/56 [==============================] - 2s 28ms/step - loss: 45.9839 - mean_absolute_error: 45.9839 - val_loss: 46.1089 - val_mean_absolute_error: 46.1089
# Epoch 664/700
# 56/56 [==============================] - 0s 6ms/step - loss: 47.4439 - mean_absolute_error: 47.4439 - val_loss: 54.3031 - val_mean_absolute_error: 54.3031
# Epoch 665/700
# 56/56 [==============================] - 0s 6ms/step - loss: 45.9563 - mean_absolute_error: 45.9563 - val_loss: 53.2037 - val_mean_absolute_error: 53.2037
# Epoch 666/700
# 56/56 [==============================] - 0s 6ms/step - loss: 44.5789 - mean_absolute_error: 44.5789 - val_loss: 52.0683 - val_mean_absolute_error: 52.0683
# Epoch 667/700
# 56/56 [==============================] - 0s 6ms/step - loss: 45.1451 - mean_absolute_error: 45.1451 - val_loss: 47.9690 - val_mean_absolute_error: 47.9690
# Epoch 668/700
# 56/56 [==============================] - 0s 6ms/step - loss: 49.9839 - mean_absolute_error: 49.9839 - val_loss: 48.1130 - val_mean_absolute_error: 48.1130
# Epoch 669/700
# 56/56 [==============================] - 2s 29ms/step - loss: 44.0776 - mean_absolute_error: 44.0776 - val_loss: 45.8709 - val_mean_absolute_error: 45.8709
# Epoch 670/700
# 56/56 [==============================] - 0s 6ms/step - loss: 44.9198 - mean_absolute_error: 44.9198 - val_loss: 49.6286 - val_mean_absolute_error: 49.6286
# Epoch 671/700
# 56/56 [==============================] - 0s 6ms/step - loss: 44.7164 - mean_absolute_error: 44.7164 - val_loss: 52.2377 - val_mean_absolute_error: 52.2377
# Epoch 672/700
# 56/56 [==============================] - 0s 6ms/step - loss: 45.2220 - mean_absolute_error: 45.2220 - val_loss: 47.9630 - val_mean_absolute_error: 47.9630
# Epoch 673/700
# 56/56 [==============================] - 0s 6ms/step - loss: 43.3052 - mean_absolute_error: 43.3052 - val_loss: 46.9734 - val_mean_absolute_error: 46.9734
# Epoch 674/700
# 56/56 [==============================] - 0s 6ms/step - loss: 46.8532 - mean_absolute_error: 46.8532 - val_loss: 64.4674 - val_mean_absolute_error: 64.4674
# Epoch 675/700
# 56/56 [==============================] - 0s 6ms/step - loss: 46.2986 - mean_absolute_error: 46.2986 - val_loss: 46.7807 - val_mean_absolute_error: 46.7807
# Epoch 676/700
# 56/56 [==============================] - 0s 6ms/step - loss: 44.2393 - mean_absolute_error: 44.2393 - val_loss: 50.2924 - val_mean_absolute_error: 50.2924
# Epoch 677/700
# 56/56 [==============================] - 0s 6ms/step - loss: 44.8014 - mean_absolute_error: 44.8014 - val_loss: 53.0466 - val_mean_absolute_error: 53.0466
# Epoch 678/700
# 56/56 [==============================] - 0s 6ms/step - loss: 46.1424 - mean_absolute_error: 46.1424 - val_loss: 52.2239 - val_mean_absolute_error: 52.2239
# Epoch 679/700
# 56/56 [==============================] - 0s 6ms/step - loss: 47.4530 - mean_absolute_error: 47.4530 - val_loss: 73.1885 - val_mean_absolute_error: 73.1885
# Epoch 680/700
# 56/56 [==============================] - 0s 5ms/step - loss: 45.3523 - mean_absolute_error: 45.3523 - val_loss: 47.5838 - val_mean_absolute_error: 47.5838
# Epoch 681/700
# 56/56 [==============================] - 0s 6ms/step - loss: 44.2544 - mean_absolute_error: 44.2544 - val_loss: 54.7998 - val_mean_absolute_error: 54.7998
# Epoch 682/700
# 56/56 [==============================] - 0s 5ms/step - loss: 47.0786 - mean_absolute_error: 47.0786 - val_loss: 51.2618 - val_mean_absolute_error: 51.2618
# Epoch 683/700
# 56/56 [==============================] - 0s 6ms/step - loss: 46.1483 - mean_absolute_error: 46.1483 - val_loss: 48.9275 - val_mean_absolute_error: 48.9275
# Epoch 684/700
# 56/56 [==============================] - 0s 6ms/step - loss: 43.7081 - mean_absolute_error: 43.7081 - val_loss: 48.9029 - val_mean_absolute_error: 48.9029
# Epoch 685/700
# 56/56 [==============================] - 0s 5ms/step - loss: 43.5142 - mean_absolute_error: 43.5142 - val_loss: 53.0615 - val_mean_absolute_error: 53.0615
# Epoch 686/700
# 56/56 [==============================] - 0s 5ms/step - loss: 43.9514 - mean_absolute_error: 43.9514 - val_loss: 52.2067 - val_mean_absolute_error: 52.2067
# Epoch 687/700
# 56/56 [==============================] - 2s 31ms/step - loss: 43.3899 - mean_absolute_error: 43.3899 - val_loss: 45.2621 - val_mean_absolute_error: 45.2621
# Epoch 688/700
# 56/56 [==============================] - 0s 6ms/step - loss: 46.8475 - mean_absolute_error: 46.8475 - val_loss: 50.5587 - val_mean_absolute_error: 50.5587
# Epoch 689/700
# 56/56 [==============================] - 0s 6ms/step - loss: 44.5255 - mean_absolute_error: 44.5255 - val_loss: 50.6410 - val_mean_absolute_error: 50.6410
# Epoch 690/700
# 56/56 [==============================] - 0s 6ms/step - loss: 43.1420 - mean_absolute_error: 43.1420 - val_loss: 48.5890 - val_mean_absolute_error: 48.5890
# Epoch 691/700
# 56/56 [==============================] - 0s 6ms/step - loss: 46.2740 - mean_absolute_error: 46.2740 - val_loss: 55.7792 - val_mean_absolute_error: 55.7792
# Epoch 692/700
# 56/56 [==============================] - 0s 6ms/step - loss: 45.0894 - mean_absolute_error: 45.0894 - val_loss: 47.7105 - val_mean_absolute_error: 47.7105
# Epoch 693/700
# 56/56 [==============================] - 0s 6ms/step - loss: 45.5364 - mean_absolute_error: 45.5364 - val_loss: 45.6932 - val_mean_absolute_error: 45.6932
# Epoch 694/700
# 56/56 [==============================] - 0s 6ms/step - loss: 45.6706 - mean_absolute_error: 45.6706 - val_loss: 51.7987 - val_mean_absolute_error: 51.7987
# Epoch 695/700
# 56/56 [==============================] - 0s 5ms/step - loss: 45.3399 - mean_absolute_error: 45.3399 - val_loss: 59.5436 - val_mean_absolute_error: 59.5436
# Epoch 696/700
# 56/56 [==============================] - 0s 6ms/step - loss: 47.2585 - mean_absolute_error: 47.2585 - val_loss: 57.5443 - val_mean_absolute_error: 57.5443
# Epoch 697/700
# 56/56 [==============================] - 0s 6ms/step - loss: 47.9325 - mean_absolute_error: 47.9325 - val_loss: 51.6272 - val_mean_absolute_error: 51.6272
# Epoch 698/700
# 56/56 [==============================] - 0s 7ms/step - loss: 44.3081 - mean_absolute_error: 44.3081 - val_loss: 57.7271 - val_mean_absolute_error: 57.7271
# Epoch 699/700
# 56/56 [==============================] - 0s 7ms/step - loss: 48.6214 - mean_absolute_error: 48.6214 - val_loss: 55.3670 - val_mean_absolute_error: 55.3670
# Epoch 700/700
# 56/56 [==============================] - 0s 8ms/step - loss: 46.9941 - mean_absolute_error: 46.9941 - val_loss: 45.3055 - val_mean_absolute_error: 45.3055

# %%
# from tensorflow.keras.models import load_model   
# model = load_model('model_ann_all/')

# %%
#700
train_acc = model.evaluate(X_train, y_train, verbose=0)
print('MAE training : {:.3f}'.format(train_acc[1]))
scores = model.evaluate(X_validation, y_validation)
print('MAE validation : {:.3f}'.format(scores[1]))

test_acc = model.evaluate(X_test, y_test)
print('MAE test : {:.3f}'.format(test_acc[1]))
# Out:
# MAE training : 42.505
# 12/12 [==============================] - 0s 4ms/step - loss: 45.3055 - mean_absolute_error: 45.3055
# MAE validation : 45.305
# 10/10 [==============================] - 0s 4ms/step - loss: 47.2076 - mean_absolute_error: 47.2076
# MAE test : 47.208

# %%
#700
show_train_history(train_history,'loss','val_loss')

# %% [markdown]
# **Results for 700 epochs**

# %%
train_predictions = model.predict(X_train).flatten()
#train_predict_round = np.rint(train_predictions)
train_results = pd.DataFrame(data={'Train Predictions':train_predictions, 'Actuals':y_train.flatten()})
train_results

###train_results.to_csv(r'/content/gdrive/MyDrive/TRM/ENAAM/AllRanking/Predictions_Test_Top_Results_ANN.csv')
###train_results
# Out:
# 56/56 [==============================] - 0s 2ms/step
#       Train Predictions  Actuals
# 0           1583.524048   1672.0
# 1           1634.408936   1585.0
# 2           2511.376709   2432.0
# 3            435.352936    435.0
# 4           2140.947998   2088.0
# ...                 ...      ...
# 1780        1059.673584   1104.0
# 1781        2456.739502   2506.0
# 1782         168.007431    162.0
# 1783         520.330139    532.0
# 1784        1431.969238   1488.0
#
# [1785 rows x 2 columns]

# %%
res1 = train_results.head(50)
res1.plot(kind='bar',figsize=(16,10))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %%
test_predictions = model.predict(X_test).flatten()
test_results = pd.DataFrame(data={'Test Predictions':test_predictions, 'Actuals':y_test.flatten()})
test_results
# Out:
# 10/10 [==============================] - 0s 2ms/step
#      Test Predictions  Actuals
# 0         1519.178589   1517.0
# 1          558.050720    583.0
# 2          818.603333    812.0
# 3          492.979431    543.0
# 4         1780.903809   1809.0
# ..                ...      ...
# 286       2317.963867   2338.0
# 287        985.053162    978.0
# 288        529.327515    514.0
# 289        280.244232    269.0
# 290       1905.274902   1877.0
#
# [291 rows x 2 columns]

# %%
res2 = test_results.head(100)
res2.plot(kind='bar',figsize=(20,10))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %% [markdown]
# TOP 100

# %%
# Import dataset
df_2 = pd.read_csv('/content/gdrive/MyDrive/TRM/ENAAM/AllRanking/ground_truth.csv')
df_2
# Out:
#       Response Time  Availability  Throughput  Reliability  Latency  Rank
# 0             41.00            97        43.1           73     1.00      1
# 1             57.00            98        34.6           73     1.00      2
# 2             57.00            86        40.1           73     1.00      3
# 3             78.00           100        35.3           67     1.00      4
# 4             78.00            92        36.9           73     1.00      5
# ...             ...           ...         ...          ...      ...    ...
# 2502        1674.00            55         0.8           67  1005.40   2503
# 2503        2555.00            83         0.3           73  2035.00   2504
# 2504        2204.38            66         0.7           73  2050.13   2505
# 2505        4480.80            52         1.0           50  1652.40   2506
# 2506        4637.61            30         0.5           67  4140.35   2507
#
# [2507 rows x 6 columns]

# %%
# Create python dataframe
decisions_2 = pd.DataFrame()
decisions_2['Response Time'] = df_2['Response Time']
decisions_2['Availability'] = df_2['Availability']
decisions_2['Throughput'] = df_2['Throughput']
decisions_2['Reliability'] = df_2['Reliability']
decisions_2['Latency'] = df_2['Latency']
decisions_2['Rank'] = df_2['Rank ']
decisions_2.head(100)
# Out:
#     Response Time  Availability  Throughput  Reliability  Latency  Rank
# 0           41.00            97        43.1           73     1.00     1
# 1           57.00            98        34.6           73     1.00     2
# 2           57.00            86        40.1           73     1.00     3
# 3           78.00           100        35.3           67     1.00     4
# 4           78.00            92        36.9           73     1.00     5
# ..            ...           ...         ...          ...      ...   ...
# 95          53.00            83        14.5           73     2.00    96
# 96         116.00            98        16.7           67     1.33    97
# 97         126.67            94         9.5           73     0.67    98
# 98         119.00            83        10.7           73     1.00    99
# 99         111.00            87        27.4           58     2.00   100
#
# [100 rows x 6 columns]

# %%
test_data_top = decisions_2[0:100]

# %%
tmp_top = np.array(test_data_top)
X_test_top = tmp_top[:, :-1]
y_test_top = tmp_top[:, -1]

# %%
test_acc_top = model.evaluate(X_test_top, y_test_top)
print('MAE test top : {:.3f}'.format(test_acc_top[1]))
# Out:
# 4/4 [==============================] - 0s 4ms/step - loss: 6.6024 - mean_absolute_error: 6.6024
# MAE test top : 6.602

# %%
test_predictions_top = model.predict(X_test_top).flatten()
test_results_top = pd.DataFrame(data={'Test Predictions':test_predictions_top, 'Actuals':y_test_top.flatten()})
test_results_top.to_csv(r'/content/gdrive/MyDrive/TRM/ENAAM/AllRanking/Predictions_Test_Top_Results_ANN.csv')
test_results_top
# Out:
# 4/4 [==============================] - 0s 3ms/step
#     Test Predictions  Actuals
# 0           1.228461      1.0
# 1           2.569255      2.0
# 2           1.680126      3.0
# 3           5.703022      4.0
# 4           4.376498      5.0
# ..               ...      ...
# 95         98.096634     96.0
# 96         72.855362     97.0
# 97         89.859230     98.0
# 98        115.681664     99.0
# 99        109.814995    100.0
#
# [100 rows x 2 columns]

# %%
res3 = test_results_top.head(100)
res3.plot(kind='bar',figsize=(20,10))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()
