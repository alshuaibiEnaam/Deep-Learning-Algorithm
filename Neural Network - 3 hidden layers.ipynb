# %% [markdown]
# **1. Import Modules**

# %%
'''
  Import all necessary modules
'''

import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input , Dense, Dropout, SimpleRNN
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.losses import MeanSquaredError, MeanAbsoluteError
from tensorflow.keras.metrics import RootMeanSquaredError, MeanAbsoluteError
from tensorflow.keras.optimizers import Adam, Adadelta
from numpy.random import seed
from tensorflow.keras.utils import set_random_seed
from sklearn import preprocessing
import seaborn as sns

# %%
#mount the drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd /content/gdrive/MyDrive/TRM/ENAAM
# Out:
# /content/gdrive/MyDrive/TRM/ENAAM

# %% [markdown]
# **2. Dataset Preparation**

# %%
# Import dataset
df = pd.read_csv('/content/gdrive/MyDrive/TRM/ENAAM/AllRanking/ground_truth-shuffled.csv')
df
# Out:
#       Response Time  Availability  Throughput  Reliability  Latency  Rank
# 0            182.25            67         9.7           67    46.50   1672
# 1            175.50            90         7.6           80    39.00   1585
# 2            500.71            92         2.2           67   233.85   2432
# 3            175.00            86         9.4           73     3.00    435
# 4            996.00            83        14.0           83    59.00   2088
# ...             ...           ...         ...          ...      ...    ...
# 2502         432.00            86         8.8           80     1.29    577
# 2503         249.00            56         8.1           73     2.25    554
# 2504         219.20            94         1.1           73     8.40   1256
# 2505         171.00            83        18.6           80     5.00    474
# 2506         227.00            88        21.2           73    23.00   1321
#
# [2507 rows x 6 columns]

# %%
df.hist(figsize = (12,10))
plt.show()

# %%
f, ax = plt.subplots(figsize=(10, 8))
corr = df.corr()
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool),
            cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, ax=ax)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Correlation between different variables
#
corr = df.corr()
#
# Set up the matplotlib plot configuration
#
f, ax = plt.subplots(figsize=(12, 10))
#
# Generate a mask for upper traingle
#
mask = np.triu(np.ones_like(corr, dtype=bool))
#
# Configure a custom diverging colormap
#
cmap = sns.diverging_palette(230, 20, as_cmap=True)
#
# Draw the heatmap
#
sns.heatmap(corr, annot=True, mask = mask, cmap=cmap)

# %%
# Create python dataframe
decisions = pd.DataFrame()
decisions['Response Time'] = df['Response Time']
decisions['Availability'] = df['Availability']
decisions['Throughput'] = df['Throughput']
decisions['Reliability'] = df['Reliability']
decisions['Latency'] = df['Latency']
decisions['Rank'] = df['Rank ']
decisions
# Out:
#       Response Time  Availability  Throughput  Reliability  Latency  Rank
# 0            182.25            67         9.7           67    46.50  1672
# 1            175.50            90         7.6           80    39.00  1585
# 2            500.71            92         2.2           67   233.85  2432
# 3            175.00            86         9.4           73     3.00   435
# 4            996.00            83        14.0           83    59.00  2088
# ...             ...           ...         ...          ...      ...   ...
# 2502         432.00            86         8.8           80     1.29   577
# 2503         249.00            56         8.1           73     2.25   554
# 2504         219.20            94         1.1           73     8.40  1256
# 2505         171.00            83        18.6           80     5.00   474
# 2506         227.00            88        21.2           73    23.00  1321
#
# [2507 rows x 6 columns]

# %%
'''
 Split dataset to train (70%), test (15%) and validation(15%) sets. 
 The top 30 values were removed from the dataset to be split. 
      * Reason for removal - We have to check the MAE of the top 30. The data should be unknown to the model to get
        accurate figures. 
'''
training_data = decisions[0:1785]#361

test_data = decisions[1855:2146]

validation_data = decisions[2146:2507]

# %%
# Split into input and output values

tmp_train = np.array(training_data)
X_train = tmp_train[:, :-1]
y_train = tmp_train[:, -1]

tmp_test = np.array(test_data)
X_test = tmp_test[:, :-1]
y_test = tmp_test[:, -1]

tmp_val = np.array(validation_data)
X_validation = tmp_val[:, :-1]
y_validation = tmp_val[:, -1]

# %% [markdown]
# **3. Model Preparation**

# %%
seed(0)
set_random_seed(0)

# %%
'''
 This function is used to display the training history of the dataset.
'''
def show_train_history(train_history,train,validation):
    plt.plot(train_history.history[train])
    plt.plot(train_history.history[validation])
    plt.title('Train History')
    plt.ylabel(train)
    plt.xlabel('Epoch')
    plt.legend(['train', 'validation'], loc='best')
    plt.show()

# %%
# 3 hidden layer neural network 
model = Sequential()

n_cols = training_data.shape[1]

model.add(Dense(256, kernel_initializer='normal', activation='relu', input_shape=(5,)))
# The Hidden Layers :
model.add(Dense(128, kernel_initializer='normal',activation='relu'))
model.add(Dense(96, kernel_initializer='normal',activation='relu'))
model.add(Dense(72, kernel_initializer='normal',activation='relu'))

model.add(Dense(1))

# %%
model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_50 (Dense)            (None, 256)               1536
#
#  dense_51 (Dense)            (None, 128)               32896
#
#  dense_52 (Dense)            (None, 96)                12384
#
#  dense_53 (Dense)            (None, 72)                6984
#
#  dense_54 (Dense)            (None, 1)                 73
#
# =================================================================
# Total params: 53,873
# Trainable params: 53,873
# Non-trainable params: 0
# _________________________________________________________________

# %%
'''
Checkpoints are used to save the model at some interval, so the model can be loaded from the saved state to continue training
'''
cp = ModelCheckpoint('model_ann_all/', save_best_only=True)

# Compile model
model.compile(loss='mean_absolute_error',
                optimizer=tf.keras.optimizers.Adam(0.0001), metrics='mean_absolute_error')

# %%
#train model

train_history = model.fit(X_train, y_train, epochs=500, validation_data=(X_validation, y_validation), callbacks=[cp])
# Out:
# Epoch 1/500
# 56/56 [==============================] - 2s 22ms/step - loss: 1250.1040 - mean_absolute_error: 1250.1040 - val_loss: 1239.1077 - val_mean_absolute_error: 1239.1077
# Epoch 2/500
# 56/56 [==============================] - 1s 25ms/step - loss: 1179.2516 - mean_absolute_error: 1179.2516 - val_loss: 1045.9072 - val_mean_absolute_error: 1045.9072
# Epoch 3/500
# 56/56 [==============================] - 1s 20ms/step - loss: 892.1691 - mean_absolute_error: 892.1691 - val_loss: 761.7283 - val_mean_absolute_error: 761.7283
# Epoch 4/500
# 56/56 [==============================] - 1s 20ms/step - loss: 730.0883 - mean_absolute_error: 730.0883 - val_loss: 750.7408 - val_mean_absolute_error: 750.7408
# Epoch 5/500
# 56/56 [==============================] - 1s 19ms/step - loss: 692.3908 - mean_absolute_error: 692.3908 - val_loss: 715.1630 - val_mean_absolute_error: 715.1630
# Epoch 6/500
# 56/56 [==============================] - 1s 20ms/step - loss: 661.3474 - mean_absolute_error: 661.3474 - val_loss: 668.6380 - val_mean_absolute_error: 668.6380
# Epoch 7/500
# 56/56 [==============================] - 1s 19ms/step - loss: 627.3566 - mean_absolute_error: 627.3566 - val_loss: 638.1206 - val_mean_absolute_error: 638.1206
# Epoch 8/500
# 56/56 [==============================] - 1s 20ms/step - loss: 593.2134 - mean_absolute_error: 593.2134 - val_loss: 603.7635 - val_mean_absolute_error: 603.7635
# Epoch 9/500
# 56/56 [==============================] - 1s 20ms/step - loss: 560.0461 - mean_absolute_error: 560.0461 - val_loss: 574.5429 - val_mean_absolute_error: 574.5429
# Epoch 10/500
# 56/56 [==============================] - 1s 24ms/step - loss: 521.6069 - mean_absolute_error: 521.6069 - val_loss: 543.6777 - val_mean_absolute_error: 543.6777
# Epoch 11/500
# 56/56 [==============================] - 1s 21ms/step - loss: 484.1728 - mean_absolute_error: 484.1728 - val_loss: 505.5721 - val_mean_absolute_error: 505.5721
# Epoch 12/500
# 56/56 [==============================] - 1s 19ms/step - loss: 442.2469 - mean_absolute_error: 442.2469 - val_loss: 465.1706 - val_mean_absolute_error: 465.1706
# Epoch 13/500
# 56/56 [==============================] - 1s 20ms/step - loss: 396.7873 - mean_absolute_error: 396.7873 - val_loss: 418.5357 - val_mean_absolute_error: 418.5357
# Epoch 14/500
# 56/56 [==============================] - 1s 21ms/step - loss: 348.7457 - mean_absolute_error: 348.7457 - val_loss: 384.3486 - val_mean_absolute_error: 384.3486
# Epoch 15/500
# 56/56 [==============================] - 1s 21ms/step - loss: 305.5041 - mean_absolute_error: 305.5041 - val_loss: 317.9709 - val_mean_absolute_error: 317.9709
# Epoch 16/500
# 56/56 [==============================] - 1s 20ms/step - loss: 262.4694 - mean_absolute_error: 262.4694 - val_loss: 275.9898 - val_mean_absolute_error: 275.9898
# Epoch 17/500
# 56/56 [==============================] - 1s 19ms/step - loss: 234.1568 - mean_absolute_error: 234.1568 - val_loss: 234.6432 - val_mean_absolute_error: 234.6432
# Epoch 18/500
# 56/56 [==============================] - 1s 24ms/step - loss: 215.4644 - mean_absolute_error: 215.4644 - val_loss: 216.0619 - val_mean_absolute_error: 216.0619
# Epoch 19/500
# 56/56 [==============================] - 1s 21ms/step - loss: 209.0442 - mean_absolute_error: 209.0442 - val_loss: 208.3124 - val_mean_absolute_error: 208.3124
# Epoch 20/500
# 56/56 [==============================] - 1s 20ms/step - loss: 200.8596 - mean_absolute_error: 200.8596 - val_loss: 205.2565 - val_mean_absolute_error: 205.2565
# Epoch 21/500
# 56/56 [==============================] - 1s 20ms/step - loss: 194.2617 - mean_absolute_error: 194.2617 - val_loss: 195.8057 - val_mean_absolute_error: 195.8057
# Epoch 22/500
# 56/56 [==============================] - 1s 19ms/step - loss: 192.0041 - mean_absolute_error: 192.0041 - val_loss: 192.6418 - val_mean_absolute_error: 192.6418
# Epoch 23/500
# 56/56 [==============================] - 1s 20ms/step - loss: 186.4919 - mean_absolute_error: 186.4919 - val_loss: 188.1763 - val_mean_absolute_error: 188.1763
# Epoch 24/500
# 56/56 [==============================] - 1s 19ms/step - loss: 185.5685 - mean_absolute_error: 185.5685 - val_loss: 187.2831 - val_mean_absolute_error: 187.2831
# Epoch 25/500
# 56/56 [==============================] - 1s 20ms/step - loss: 180.4588 - mean_absolute_error: 180.4588 - val_loss: 181.8916 - val_mean_absolute_error: 181.8916
# Epoch 26/500
# 56/56 [==============================] - 1s 24ms/step - loss: 177.4807 - mean_absolute_error: 177.4807 - val_loss: 179.5376 - val_mean_absolute_error: 179.5376
# Epoch 27/500
# 56/56 [==============================] - 1s 20ms/step - loss: 173.2276 - mean_absolute_error: 173.2276 - val_loss: 174.4418 - val_mean_absolute_error: 174.4418
# Epoch 28/500
# 56/56 [==============================] - 0s 3ms/step - loss: 172.9313 - mean_absolute_error: 172.9313 - val_loss: 177.6279 - val_mean_absolute_error: 177.6279
# Epoch 29/500
# 56/56 [==============================] - 0s 3ms/step - loss: 168.4218 - mean_absolute_error: 168.4218 - val_loss: 178.0544 - val_mean_absolute_error: 178.0544
# Epoch 30/500
# 56/56 [==============================] - 1s 20ms/step - loss: 168.9734 - mean_absolute_error: 168.9734 - val_loss: 171.1846 - val_mean_absolute_error: 171.1846
# Epoch 31/500
# 56/56 [==============================] - 1s 20ms/step - loss: 164.8226 - mean_absolute_error: 164.8226 - val_loss: 163.4947 - val_mean_absolute_error: 163.4947
# Epoch 32/500
# 56/56 [==============================] - 0s 3ms/step - loss: 161.4757 - mean_absolute_error: 161.4757 - val_loss: 167.2822 - val_mean_absolute_error: 167.2822
# Epoch 33/500
# 56/56 [==============================] - 1s 20ms/step - loss: 157.4597 - mean_absolute_error: 157.4597 - val_loss: 157.9754 - val_mean_absolute_error: 157.9754
# Epoch 34/500
# 56/56 [==============================] - 0s 3ms/step - loss: 153.1363 - mean_absolute_error: 153.1363 - val_loss: 158.1324 - val_mean_absolute_error: 158.1324
# Epoch 35/500
# 56/56 [==============================] - 1s 20ms/step - loss: 153.5342 - mean_absolute_error: 153.5342 - val_loss: 156.1096 - val_mean_absolute_error: 156.1096
# Epoch 36/500
# 56/56 [==============================] - 0s 3ms/step - loss: 152.4089 - mean_absolute_error: 152.4089 - val_loss: 157.9928 - val_mean_absolute_error: 157.9928
# Epoch 37/500
# 56/56 [==============================] - 1s 20ms/step - loss: 147.2175 - mean_absolute_error: 147.2175 - val_loss: 148.9629 - val_mean_absolute_error: 148.9629
# Epoch 38/500
# 56/56 [==============================] - 1s 20ms/step - loss: 145.9355 - mean_absolute_error: 145.9355 - val_loss: 145.9703 - val_mean_absolute_error: 145.9703
# Epoch 39/500
# 56/56 [==============================] - 1s 24ms/step - loss: 141.6122 - mean_absolute_error: 141.6122 - val_loss: 144.8127 - val_mean_absolute_error: 144.8127
# Epoch 40/500
# 56/56 [==============================] - 1s 20ms/step - loss: 137.7262 - mean_absolute_error: 137.7262 - val_loss: 141.3125 - val_mean_absolute_error: 141.3125
# Epoch 41/500
# 56/56 [==============================] - 1s 20ms/step - loss: 137.0640 - mean_absolute_error: 137.0640 - val_loss: 138.1566 - val_mean_absolute_error: 138.1566
# Epoch 42/500
# 56/56 [==============================] - 1s 20ms/step - loss: 135.5393 - mean_absolute_error: 135.5393 - val_loss: 136.0302 - val_mean_absolute_error: 136.0302
# Epoch 43/500
# 56/56 [==============================] - 0s 3ms/step - loss: 133.3702 - mean_absolute_error: 133.3702 - val_loss: 140.7815 - val_mean_absolute_error: 140.7815
# Epoch 44/500
# 56/56 [==============================] - 1s 20ms/step - loss: 129.1716 - mean_absolute_error: 129.1716 - val_loss: 132.6186 - val_mean_absolute_error: 132.6186
# Epoch 45/500
# 56/56 [==============================] - 1s 20ms/step - loss: 127.6584 - mean_absolute_error: 127.6584 - val_loss: 132.0951 - val_mean_absolute_error: 132.0951
# Epoch 46/500
# 56/56 [==============================] - 1s 20ms/step - loss: 125.9716 - mean_absolute_error: 125.9716 - val_loss: 127.3580 - val_mean_absolute_error: 127.3580
# Epoch 47/500
# 56/56 [==============================] - 0s 3ms/step - loss: 122.8325 - mean_absolute_error: 122.8325 - val_loss: 137.4192 - val_mean_absolute_error: 137.4192
# Epoch 48/500
# 56/56 [==============================] - 1s 20ms/step - loss: 122.9233 - mean_absolute_error: 122.9233 - val_loss: 124.1926 - val_mean_absolute_error: 124.1926
# Epoch 49/500
# 56/56 [==============================] - 0s 3ms/step - loss: 119.8434 - mean_absolute_error: 119.8434 - val_loss: 130.4005 - val_mean_absolute_error: 130.4005
# Epoch 50/500
# 56/56 [==============================] - 1s 25ms/step - loss: 118.8550 - mean_absolute_error: 118.8550 - val_loss: 123.0748 - val_mean_absolute_error: 123.0748
# Epoch 51/500
# 56/56 [==============================] - 1s 19ms/step - loss: 117.0908 - mean_absolute_error: 117.0908 - val_loss: 116.9130 - val_mean_absolute_error: 116.9130
# Epoch 52/500
# 56/56 [==============================] - 0s 3ms/step - loss: 113.4151 - mean_absolute_error: 113.4151 - val_loss: 117.6741 - val_mean_absolute_error: 117.6741
# Epoch 53/500
# 56/56 [==============================] - 1s 20ms/step - loss: 112.4914 - mean_absolute_error: 112.4914 - val_loss: 113.6672 - val_mean_absolute_error: 113.6672
# Epoch 54/500
# 56/56 [==============================] - 0s 3ms/step - loss: 110.9462 - mean_absolute_error: 110.9462 - val_loss: 118.5249 - val_mean_absolute_error: 118.5249
# Epoch 55/500
# 56/56 [==============================] - 0s 3ms/step - loss: 112.6616 - mean_absolute_error: 112.6616 - val_loss: 146.4810 - val_mean_absolute_error: 146.4810
# Epoch 56/500
# 56/56 [==============================] - 1s 20ms/step - loss: 108.4694 - mean_absolute_error: 108.4694 - val_loss: 108.6426 - val_mean_absolute_error: 108.6426
# Epoch 57/500
# 56/56 [==============================] - 1s 20ms/step - loss: 108.7325 - mean_absolute_error: 108.7325 - val_loss: 107.4375 - val_mean_absolute_error: 107.4375
# Epoch 58/500
# 56/56 [==============================] - 0s 3ms/step - loss: 106.6125 - mean_absolute_error: 106.6125 - val_loss: 113.4896 - val_mean_absolute_error: 113.4896
# Epoch 59/500
# 56/56 [==============================] - 0s 3ms/step - loss: 104.9009 - mean_absolute_error: 104.9009 - val_loss: 108.0601 - val_mean_absolute_error: 108.0601
# Epoch 60/500
# 56/56 [==============================] - 1s 20ms/step - loss: 104.1753 - mean_absolute_error: 104.1753 - val_loss: 104.0234 - val_mean_absolute_error: 104.0234
# Epoch 61/500
# 56/56 [==============================] - 0s 3ms/step - loss: 101.2859 - mean_absolute_error: 101.2859 - val_loss: 105.7582 - val_mean_absolute_error: 105.7582
# Epoch 62/500
# 56/56 [==============================] - 0s 3ms/step - loss: 102.4282 - mean_absolute_error: 102.4282 - val_loss: 110.2596 - val_mean_absolute_error: 110.2596
# Epoch 63/500
# 56/56 [==============================] - 1s 20ms/step - loss: 100.9443 - mean_absolute_error: 100.9443 - val_loss: 102.8308 - val_mean_absolute_error: 102.8308
# Epoch 64/500
# 56/56 [==============================] - 1s 20ms/step - loss: 98.6817 - mean_absolute_error: 98.6817 - val_loss: 99.9404 - val_mean_absolute_error: 99.9404
# Epoch 65/500
# 56/56 [==============================] - 0s 3ms/step - loss: 98.9355 - mean_absolute_error: 98.9355 - val_loss: 101.1662 - val_mean_absolute_error: 101.1662
# Epoch 66/500
# 56/56 [==============================] - 1s 25ms/step - loss: 97.0496 - mean_absolute_error: 97.0496 - val_loss: 97.7126 - val_mean_absolute_error: 97.7126
# Epoch 67/500
# 56/56 [==============================] - 0s 3ms/step - loss: 96.9386 - mean_absolute_error: 96.9386 - val_loss: 99.9014 - val_mean_absolute_error: 99.9014
# Epoch 68/500
# 56/56 [==============================] - 0s 3ms/step - loss: 100.1833 - mean_absolute_error: 100.1833 - val_loss: 98.7576 - val_mean_absolute_error: 98.7576
# Epoch 69/500
# 56/56 [==============================] - 1s 20ms/step - loss: 93.5270 - mean_absolute_error: 93.5270 - val_loss: 96.5161 - val_mean_absolute_error: 96.5161
# Epoch 70/500
# 56/56 [==============================] - 0s 3ms/step - loss: 94.7339 - mean_absolute_error: 94.7339 - val_loss: 97.6660 - val_mean_absolute_error: 97.6660
# Epoch 71/500
# 56/56 [==============================] - 0s 3ms/step - loss: 92.8207 - mean_absolute_error: 92.8207 - val_loss: 109.3933 - val_mean_absolute_error: 109.3933
# Epoch 72/500
# 56/56 [==============================] - 1s 20ms/step - loss: 94.3107 - mean_absolute_error: 94.3107 - val_loss: 95.7024 - val_mean_absolute_error: 95.7024
# Epoch 73/500
# 56/56 [==============================] - 0s 3ms/step - loss: 95.4259 - mean_absolute_error: 95.4259 - val_loss: 107.5520 - val_mean_absolute_error: 107.5520
# Epoch 74/500
# 56/56 [==============================] - 1s 19ms/step - loss: 91.9664 - mean_absolute_error: 91.9664 - val_loss: 93.4817 - val_mean_absolute_error: 93.4817
# Epoch 75/500
# 56/56 [==============================] - 1s 20ms/step - loss: 90.7236 - mean_absolute_error: 90.7236 - val_loss: 92.7410 - val_mean_absolute_error: 92.7410
# Epoch 76/500
# 56/56 [==============================] - 0s 3ms/step - loss: 90.5946 - mean_absolute_error: 90.5946 - val_loss: 93.1325 - val_mean_absolute_error: 93.1325
# Epoch 77/500
# 56/56 [==============================] - 0s 4ms/step - loss: 91.2890 - mean_absolute_error: 91.2890 - val_loss: 98.9469 - val_mean_absolute_error: 98.9469
# Epoch 78/500
# 56/56 [==============================] - 0s 3ms/step - loss: 91.1242 - mean_absolute_error: 91.1242 - val_loss: 92.9527 - val_mean_absolute_error: 92.9527
# Epoch 79/500
# 56/56 [==============================] - 0s 3ms/step - loss: 89.7905 - mean_absolute_error: 89.7905 - val_loss: 96.0831 - val_mean_absolute_error: 96.0831
# Epoch 80/500
# 56/56 [==============================] - 1s 20ms/step - loss: 93.7831 - mean_absolute_error: 93.7831 - val_loss: 92.4105 - val_mean_absolute_error: 92.4105
# Epoch 81/500
# 56/56 [==============================] - 0s 3ms/step - loss: 90.0755 - mean_absolute_error: 90.0755 - val_loss: 98.7874 - val_mean_absolute_error: 98.7874
# Epoch 82/500
# 56/56 [==============================] - 0s 4ms/step - loss: 91.1172 - mean_absolute_error: 91.1172 - val_loss: 100.7619 - val_mean_absolute_error: 100.7619
# Epoch 83/500
# 56/56 [==============================] - 0s 3ms/step - loss: 89.4566 - mean_absolute_error: 89.4566 - val_loss: 93.4858 - val_mean_absolute_error: 93.4858
# Epoch 84/500
# 56/56 [==============================] - 0s 3ms/step - loss: 88.0741 - mean_absolute_error: 88.0741 - val_loss: 95.5192 - val_mean_absolute_error: 95.5192
# Epoch 85/500
# 56/56 [==============================] - 1s 19ms/step - loss: 87.5797 - mean_absolute_error: 87.5797 - val_loss: 87.0777 - val_mean_absolute_error: 87.0777
# Epoch 86/500
# 56/56 [==============================] - 0s 3ms/step - loss: 88.9213 - mean_absolute_error: 88.9213 - val_loss: 90.8898 - val_mean_absolute_error: 90.8898
# Epoch 87/500
# 56/56 [==============================] - 0s 3ms/step - loss: 87.1506 - mean_absolute_error: 87.1506 - val_loss: 95.4469 - val_mean_absolute_error: 95.4469
# Epoch 88/500
# 56/56 [==============================] - 1s 20ms/step - loss: 87.3121 - mean_absolute_error: 87.3121 - val_loss: 86.7912 - val_mean_absolute_error: 86.7912
# Epoch 89/500
# 56/56 [==============================] - 0s 3ms/step - loss: 86.4432 - mean_absolute_error: 86.4432 - val_loss: 93.0141 - val_mean_absolute_error: 93.0141
# Epoch 90/500
# 56/56 [==============================] - 0s 3ms/step - loss: 86.6064 - mean_absolute_error: 86.6064 - val_loss: 106.8948 - val_mean_absolute_error: 106.8948
# Epoch 91/500
# 56/56 [==============================] - 0s 3ms/step - loss: 86.3707 - mean_absolute_error: 86.3707 - val_loss: 97.7721 - val_mean_absolute_error: 97.7721
# Epoch 92/500
# 56/56 [==============================] - 0s 3ms/step - loss: 86.6971 - mean_absolute_error: 86.6971 - val_loss: 90.9094 - val_mean_absolute_error: 90.9094
# Epoch 93/500
# 56/56 [==============================] - 1s 25ms/step - loss: 85.0269 - mean_absolute_error: 85.0269 - val_loss: 86.2571 - val_mean_absolute_error: 86.2571
# Epoch 94/500
# 56/56 [==============================] - 0s 3ms/step - loss: 84.1989 - mean_absolute_error: 84.1989 - val_loss: 96.8473 - val_mean_absolute_error: 96.8473
# Epoch 95/500
# 56/56 [==============================] - 1s 19ms/step - loss: 86.0507 - mean_absolute_error: 86.0507 - val_loss: 84.9619 - val_mean_absolute_error: 84.9619
# Epoch 96/500
# 56/56 [==============================] - 0s 3ms/step - loss: 86.5525 - mean_absolute_error: 86.5525 - val_loss: 86.6874 - val_mean_absolute_error: 86.6874
# Epoch 97/500
# 56/56 [==============================] - 0s 3ms/step - loss: 84.3209 - mean_absolute_error: 84.3209 - val_loss: 86.6112 - val_mean_absolute_error: 86.6112
# Epoch 98/500
# 56/56 [==============================] - 0s 3ms/step - loss: 84.5137 - mean_absolute_error: 84.5137 - val_loss: 87.0552 - val_mean_absolute_error: 87.0552
# Epoch 99/500
# 56/56 [==============================] - 0s 3ms/step - loss: 84.6324 - mean_absolute_error: 84.6324 - val_loss: 86.5141 - val_mean_absolute_error: 86.5141
# Epoch 100/500
# 56/56 [==============================] - 0s 4ms/step - loss: 84.1883 - mean_absolute_error: 84.1883 - val_loss: 87.0422 - val_mean_absolute_error: 87.0422
# Epoch 101/500
# 56/56 [==============================] - 0s 3ms/step - loss: 83.0224 - mean_absolute_error: 83.0224 - val_loss: 90.1787 - val_mean_absolute_error: 90.1787
# Epoch 102/500
# 56/56 [==============================] - 0s 3ms/step - loss: 85.0327 - mean_absolute_error: 85.0327 - val_loss: 96.1620 - val_mean_absolute_error: 96.1620
# Epoch 103/500
# 56/56 [==============================] - 0s 3ms/step - loss: 84.5230 - mean_absolute_error: 84.5230 - val_loss: 86.4838 - val_mean_absolute_error: 86.4838
# Epoch 104/500
# 56/56 [==============================] - 1s 20ms/step - loss: 85.2574 - mean_absolute_error: 85.2574 - val_loss: 84.9597 - val_mean_absolute_error: 84.9597
# Epoch 105/500
# 56/56 [==============================] - 0s 3ms/step - loss: 82.2103 - mean_absolute_error: 82.2103 - val_loss: 88.6112 - val_mean_absolute_error: 88.6112
# Epoch 106/500
# 56/56 [==============================] - 0s 3ms/step - loss: 82.1952 - mean_absolute_error: 82.1952 - val_loss: 85.4204 - val_mean_absolute_error: 85.4204
# Epoch 107/500
# 56/56 [==============================] - 1s 21ms/step - loss: 81.0948 - mean_absolute_error: 81.0948 - val_loss: 83.4650 - val_mean_absolute_error: 83.4650
# Epoch 108/500
# 56/56 [==============================] - 0s 3ms/step - loss: 81.6962 - mean_absolute_error: 81.6962 - val_loss: 84.5399 - val_mean_absolute_error: 84.5399
# Epoch 109/500
# 56/56 [==============================] - 0s 3ms/step - loss: 83.1849 - mean_absolute_error: 83.1849 - val_loss: 89.0819 - val_mean_absolute_error: 89.0819
# Epoch 110/500
# 56/56 [==============================] - 0s 3ms/step - loss: 82.1626 - mean_absolute_error: 82.1626 - val_loss: 84.3780 - val_mean_absolute_error: 84.3780
# Epoch 111/500
# 56/56 [==============================] - 0s 3ms/step - loss: 82.8864 - mean_absolute_error: 82.8864 - val_loss: 91.5840 - val_mean_absolute_error: 91.5840
# Epoch 112/500
# 56/56 [==============================] - 0s 4ms/step - loss: 82.6086 - mean_absolute_error: 82.6086 - val_loss: 95.7436 - val_mean_absolute_error: 95.7436
# Epoch 113/500
# 56/56 [==============================] - 1s 20ms/step - loss: 84.7420 - mean_absolute_error: 84.7420 - val_loss: 82.5433 - val_mean_absolute_error: 82.5433
# Epoch 114/500
# 56/56 [==============================] - 0s 3ms/step - loss: 82.8293 - mean_absolute_error: 82.8293 - val_loss: 95.9338 - val_mean_absolute_error: 95.9338
# Epoch 115/500
# 56/56 [==============================] - 1s 21ms/step - loss: 83.1403 - mean_absolute_error: 83.1403 - val_loss: 81.1962 - val_mean_absolute_error: 81.1962
# Epoch 116/500
# 56/56 [==============================] - 0s 3ms/step - loss: 80.9936 - mean_absolute_error: 80.9936 - val_loss: 83.0609 - val_mean_absolute_error: 83.0609
# Epoch 117/500
# 56/56 [==============================] - 0s 4ms/step - loss: 80.9468 - mean_absolute_error: 80.9468 - val_loss: 82.6980 - val_mean_absolute_error: 82.6980
# Epoch 118/500
# 56/56 [==============================] - 0s 3ms/step - loss: 83.3942 - mean_absolute_error: 83.3942 - val_loss: 85.7741 - val_mean_absolute_error: 85.7741
# Epoch 119/500
# 56/56 [==============================] - 0s 3ms/step - loss: 81.4154 - mean_absolute_error: 81.4154 - val_loss: 82.5452 - val_mean_absolute_error: 82.5452
# Epoch 120/500
# 56/56 [==============================] - 1s 20ms/step - loss: 79.1883 - mean_absolute_error: 79.1883 - val_loss: 80.0446 - val_mean_absolute_error: 80.0446
# Epoch 121/500
# 56/56 [==============================] - 0s 3ms/step - loss: 79.8108 - mean_absolute_error: 79.8108 - val_loss: 83.4072 - val_mean_absolute_error: 83.4072
# Epoch 122/500
# 56/56 [==============================] - 0s 3ms/step - loss: 81.7182 - mean_absolute_error: 81.7182 - val_loss: 80.7196 - val_mean_absolute_error: 80.7196
# Epoch 123/500
# 56/56 [==============================] - 0s 3ms/step - loss: 79.2475 - mean_absolute_error: 79.2475 - val_loss: 90.6152 - val_mean_absolute_error: 90.6152
# Epoch 124/500
# 56/56 [==============================] - 0s 3ms/step - loss: 78.9138 - mean_absolute_error: 78.9138 - val_loss: 83.7427 - val_mean_absolute_error: 83.7427
# Epoch 125/500
# 56/56 [==============================] - 0s 3ms/step - loss: 80.1909 - mean_absolute_error: 80.1909 - val_loss: 82.9798 - val_mean_absolute_error: 82.9798
# Epoch 126/500
# 56/56 [==============================] - 0s 3ms/step - loss: 79.2725 - mean_absolute_error: 79.2725 - val_loss: 81.1517 - val_mean_absolute_error: 81.1517
# Epoch 127/500
# 56/56 [==============================] - 0s 3ms/step - loss: 79.7769 - mean_absolute_error: 79.7769 - val_loss: 83.6141 - val_mean_absolute_error: 83.6141
# Epoch 128/500
# 56/56 [==============================] - 0s 3ms/step - loss: 79.3822 - mean_absolute_error: 79.3822 - val_loss: 80.0635 - val_mean_absolute_error: 80.0635
# Epoch 129/500
# 56/56 [==============================] - 0s 3ms/step - loss: 81.6241 - mean_absolute_error: 81.6241 - val_loss: 83.1204 - val_mean_absolute_error: 83.1204
# Epoch 130/500
# 56/56 [==============================] - 0s 3ms/step - loss: 79.3247 - mean_absolute_error: 79.3247 - val_loss: 87.1913 - val_mean_absolute_error: 87.1913
# Epoch 131/500
# 56/56 [==============================] - 0s 3ms/step - loss: 80.8003 - mean_absolute_error: 80.8003 - val_loss: 85.1516 - val_mean_absolute_error: 85.1516
# Epoch 132/500
# 56/56 [==============================] - 0s 3ms/step - loss: 78.4240 - mean_absolute_error: 78.4240 - val_loss: 87.8913 - val_mean_absolute_error: 87.8913
# Epoch 133/500
# 56/56 [==============================] - 0s 3ms/step - loss: 79.7859 - mean_absolute_error: 79.7859 - val_loss: 87.5416 - val_mean_absolute_error: 87.5416
# Epoch 134/500
# 56/56 [==============================] - 1s 21ms/step - loss: 78.7261 - mean_absolute_error: 78.7261 - val_loss: 78.8757 - val_mean_absolute_error: 78.8757
# Epoch 135/500
# 56/56 [==============================] - 0s 3ms/step - loss: 80.5193 - mean_absolute_error: 80.5193 - val_loss: 80.4702 - val_mean_absolute_error: 80.4702
# Epoch 136/500
# 56/56 [==============================] - 0s 3ms/step - loss: 77.7215 - mean_absolute_error: 77.7215 - val_loss: 81.9684 - val_mean_absolute_error: 81.9684
# Epoch 137/500
# 56/56 [==============================] - 0s 3ms/step - loss: 77.3715 - mean_absolute_error: 77.3715 - val_loss: 79.5291 - val_mean_absolute_error: 79.5291
# Epoch 138/500
# 56/56 [==============================] - 0s 3ms/step - loss: 77.6910 - mean_absolute_error: 77.6910 - val_loss: 80.0065 - val_mean_absolute_error: 80.0065
# Epoch 139/500
# 56/56 [==============================] - 0s 3ms/step - loss: 77.1550 - mean_absolute_error: 77.1550 - val_loss: 92.3053 - val_mean_absolute_error: 92.3053
# Epoch 140/500
# 56/56 [==============================] - 0s 3ms/step - loss: 76.4723 - mean_absolute_error: 76.4723 - val_loss: 82.5419 - val_mean_absolute_error: 82.5419
# Epoch 141/500
# 56/56 [==============================] - 0s 3ms/step - loss: 76.3919 - mean_absolute_error: 76.3919 - val_loss: 83.9844 - val_mean_absolute_error: 83.9844
# Epoch 142/500
# 56/56 [==============================] - 0s 3ms/step - loss: 77.4294 - mean_absolute_error: 77.4294 - val_loss: 80.3792 - val_mean_absolute_error: 80.3792
# Epoch 143/500
# 56/56 [==============================] - 0s 3ms/step - loss: 76.7460 - mean_absolute_error: 76.7460 - val_loss: 81.7562 - val_mean_absolute_error: 81.7562
# Epoch 144/500
# 56/56 [==============================] - 1s 24ms/step - loss: 78.5640 - mean_absolute_error: 78.5640 - val_loss: 78.0776 - val_mean_absolute_error: 78.0776
# Epoch 145/500
# 56/56 [==============================] - 0s 3ms/step - loss: 75.3723 - mean_absolute_error: 75.3723 - val_loss: 80.5254 - val_mean_absolute_error: 80.5254
# Epoch 146/500
# 56/56 [==============================] - 0s 3ms/step - loss: 74.8826 - mean_absolute_error: 74.8826 - val_loss: 79.7927 - val_mean_absolute_error: 79.7927
# Epoch 147/500
# 56/56 [==============================] - 0s 3ms/step - loss: 77.3216 - mean_absolute_error: 77.3216 - val_loss: 78.7750 - val_mean_absolute_error: 78.7750
# Epoch 148/500
# 56/56 [==============================] - 0s 3ms/step - loss: 78.2823 - mean_absolute_error: 78.2823 - val_loss: 78.2566 - val_mean_absolute_error: 78.2566
# Epoch 149/500
# 56/56 [==============================] - 0s 3ms/step - loss: 76.6055 - mean_absolute_error: 76.6055 - val_loss: 83.2485 - val_mean_absolute_error: 83.2485
# Epoch 150/500
# 56/56 [==============================] - 0s 3ms/step - loss: 76.3095 - mean_absolute_error: 76.3095 - val_loss: 81.0604 - val_mean_absolute_error: 81.0604
# Epoch 151/500
# 56/56 [==============================] - 0s 4ms/step - loss: 74.2246 - mean_absolute_error: 74.2246 - val_loss: 79.7954 - val_mean_absolute_error: 79.7954
# Epoch 152/500
# 56/56 [==============================] - 1s 20ms/step - loss: 78.1334 - mean_absolute_error: 78.1334 - val_loss: 77.7058 - val_mean_absolute_error: 77.7058
# Epoch 153/500
# 56/56 [==============================] - 0s 3ms/step - loss: 75.7357 - mean_absolute_error: 75.7357 - val_loss: 78.9343 - val_mean_absolute_error: 78.9343
# Epoch 154/500
# 56/56 [==============================] - 0s 3ms/step - loss: 75.8094 - mean_absolute_error: 75.8094 - val_loss: 80.3542 - val_mean_absolute_error: 80.3542
# Epoch 155/500
# 56/56 [==============================] - 0s 3ms/step - loss: 75.2045 - mean_absolute_error: 75.2045 - val_loss: 78.7627 - val_mean_absolute_error: 78.7627
# Epoch 156/500
# 56/56 [==============================] - 1s 20ms/step - loss: 79.4957 - mean_absolute_error: 79.4957 - val_loss: 75.4334 - val_mean_absolute_error: 75.4334
# Epoch 157/500
# 56/56 [==============================] - 0s 3ms/step - loss: 73.6551 - mean_absolute_error: 73.6551 - val_loss: 78.0868 - val_mean_absolute_error: 78.0868
# Epoch 158/500
# 56/56 [==============================] - 0s 3ms/step - loss: 73.5141 - mean_absolute_error: 73.5141 - val_loss: 76.4965 - val_mean_absolute_error: 76.4965
# Epoch 159/500
# 56/56 [==============================] - 0s 3ms/step - loss: 74.2746 - mean_absolute_error: 74.2746 - val_loss: 86.2973 - val_mean_absolute_error: 86.2973
# Epoch 160/500
# 56/56 [==============================] - 0s 3ms/step - loss: 76.4334 - mean_absolute_error: 76.4334 - val_loss: 81.0145 - val_mean_absolute_error: 81.0145
# Epoch 161/500
# 56/56 [==============================] - 0s 3ms/step - loss: 74.6082 - mean_absolute_error: 74.6082 - val_loss: 80.8282 - val_mean_absolute_error: 80.8282
# Epoch 162/500
# 56/56 [==============================] - 0s 3ms/step - loss: 76.5922 - mean_absolute_error: 76.5922 - val_loss: 84.0755 - val_mean_absolute_error: 84.0755
# Epoch 163/500
# 56/56 [==============================] - 1s 20ms/step - loss: 73.5883 - mean_absolute_error: 73.5883 - val_loss: 74.6964 - val_mean_absolute_error: 74.6964
# Epoch 164/500
# 56/56 [==============================] - 0s 3ms/step - loss: 73.7848 - mean_absolute_error: 73.7848 - val_loss: 85.0162 - val_mean_absolute_error: 85.0162
# Epoch 165/500
# 56/56 [==============================] - 0s 3ms/step - loss: 74.8173 - mean_absolute_error: 74.8173 - val_loss: 80.8680 - val_mean_absolute_error: 80.8680
# Epoch 166/500
# 56/56 [==============================] - 0s 4ms/step - loss: 75.1337 - mean_absolute_error: 75.1337 - val_loss: 82.0687 - val_mean_absolute_error: 82.0687
# Epoch 167/500
# 56/56 [==============================] - 0s 3ms/step - loss: 73.0506 - mean_absolute_error: 73.0506 - val_loss: 76.9292 - val_mean_absolute_error: 76.9292
# Epoch 168/500
# 56/56 [==============================] - 0s 3ms/step - loss: 73.2612 - mean_absolute_error: 73.2612 - val_loss: 75.7975 - val_mean_absolute_error: 75.7975
# Epoch 169/500
# 56/56 [==============================] - 0s 3ms/step - loss: 72.3370 - mean_absolute_error: 72.3370 - val_loss: 79.4161 - val_mean_absolute_error: 79.4161
# Epoch 170/500
# 56/56 [==============================] - 0s 3ms/step - loss: 73.8089 - mean_absolute_error: 73.8089 - val_loss: 87.2991 - val_mean_absolute_error: 87.2991
# Epoch 171/500
# 56/56 [==============================] - 0s 3ms/step - loss: 76.7286 - mean_absolute_error: 76.7286 - val_loss: 80.3307 - val_mean_absolute_error: 80.3307
# Epoch 172/500
# 56/56 [==============================] - 0s 4ms/step - loss: 72.4129 - mean_absolute_error: 72.4129 - val_loss: 75.3918 - val_mean_absolute_error: 75.3918
# Epoch 173/500
# 56/56 [==============================] - 1s 21ms/step - loss: 71.9835 - mean_absolute_error: 71.9835 - val_loss: 72.8337 - val_mean_absolute_error: 72.8337
# Epoch 174/500
# 56/56 [==============================] - 0s 3ms/step - loss: 71.8756 - mean_absolute_error: 71.8756 - val_loss: 73.5075 - val_mean_absolute_error: 73.5075
# Epoch 175/500
# 56/56 [==============================] - 0s 3ms/step - loss: 73.5372 - mean_absolute_error: 73.5372 - val_loss: 97.7634 - val_mean_absolute_error: 97.7634
# Epoch 176/500
# 56/56 [==============================] - 1s 21ms/step - loss: 75.9056 - mean_absolute_error: 75.9056 - val_loss: 72.6638 - val_mean_absolute_error: 72.6638
# Epoch 177/500
# 56/56 [==============================] - 0s 3ms/step - loss: 71.7360 - mean_absolute_error: 71.7360 - val_loss: 72.8291 - val_mean_absolute_error: 72.8291
# Epoch 178/500
# 56/56 [==============================] - 1s 24ms/step - loss: 72.3758 - mean_absolute_error: 72.3758 - val_loss: 72.6636 - val_mean_absolute_error: 72.6636
# Epoch 179/500
# 56/56 [==============================] - 0s 3ms/step - loss: 74.1697 - mean_absolute_error: 74.1697 - val_loss: 80.8298 - val_mean_absolute_error: 80.8298
# Epoch 180/500
# 56/56 [==============================] - 0s 3ms/step - loss: 71.6360 - mean_absolute_error: 71.6360 - val_loss: 84.4636 - val_mean_absolute_error: 84.4636
# Epoch 181/500
# 56/56 [==============================] - 0s 3ms/step - loss: 72.7864 - mean_absolute_error: 72.7864 - val_loss: 74.2285 - val_mean_absolute_error: 74.2285
# Epoch 182/500
# 56/56 [==============================] - 0s 4ms/step - loss: 70.2811 - mean_absolute_error: 70.2811 - val_loss: 76.1511 - val_mean_absolute_error: 76.1511
# Epoch 183/500
# 56/56 [==============================] - 0s 3ms/step - loss: 71.0824 - mean_absolute_error: 71.0824 - val_loss: 80.5126 - val_mean_absolute_error: 80.5126
# Epoch 184/500
# 56/56 [==============================] - 0s 3ms/step - loss: 72.8448 - mean_absolute_error: 72.8448 - val_loss: 75.4042 - val_mean_absolute_error: 75.4042
# Epoch 185/500
# 56/56 [==============================] - 0s 3ms/step - loss: 71.4617 - mean_absolute_error: 71.4617 - val_loss: 78.8922 - val_mean_absolute_error: 78.8922
# Epoch 186/500
# 56/56 [==============================] - 0s 3ms/step - loss: 72.6466 - mean_absolute_error: 72.6466 - val_loss: 75.7071 - val_mean_absolute_error: 75.7071
# Epoch 187/500
# 56/56 [==============================] - 0s 3ms/step - loss: 70.6710 - mean_absolute_error: 70.6710 - val_loss: 72.9114 - val_mean_absolute_error: 72.9114
# Epoch 188/500
# 56/56 [==============================] - 1s 20ms/step - loss: 70.7597 - mean_absolute_error: 70.7597 - val_loss: 70.9898 - val_mean_absolute_error: 70.9898
# Epoch 189/500
# 56/56 [==============================] - 1s 20ms/step - loss: 68.9690 - mean_absolute_error: 68.9690 - val_loss: 70.6484 - val_mean_absolute_error: 70.6484
# Epoch 190/500
# 56/56 [==============================] - 0s 3ms/step - loss: 69.8166 - mean_absolute_error: 69.8166 - val_loss: 77.2767 - val_mean_absolute_error: 77.2767
# Epoch 191/500
# 56/56 [==============================] - 0s 3ms/step - loss: 71.4897 - mean_absolute_error: 71.4897 - val_loss: 73.7499 - val_mean_absolute_error: 73.7499
# Epoch 192/500
# 56/56 [==============================] - 0s 3ms/step - loss: 70.4845 - mean_absolute_error: 70.4845 - val_loss: 75.8419 - val_mean_absolute_error: 75.8419
# Epoch 193/500
# 56/56 [==============================] - 0s 3ms/step - loss: 71.2311 - mean_absolute_error: 71.2311 - val_loss: 71.6931 - val_mean_absolute_error: 71.6931
# Epoch 194/500
# 56/56 [==============================] - 0s 3ms/step - loss: 70.1760 - mean_absolute_error: 70.1760 - val_loss: 73.9696 - val_mean_absolute_error: 73.9696
# Epoch 195/500
# 56/56 [==============================] - 0s 3ms/step - loss: 70.8217 - mean_absolute_error: 70.8217 - val_loss: 74.9538 - val_mean_absolute_error: 74.9538
# Epoch 196/500
# 56/56 [==============================] - 0s 4ms/step - loss: 70.3774 - mean_absolute_error: 70.3774 - val_loss: 75.1256 - val_mean_absolute_error: 75.1256
# Epoch 197/500
# 56/56 [==============================] - 0s 3ms/step - loss: 70.1798 - mean_absolute_error: 70.1798 - val_loss: 87.6802 - val_mean_absolute_error: 87.6802
# Epoch 198/500
# 56/56 [==============================] - 0s 3ms/step - loss: 69.6540 - mean_absolute_error: 69.6540 - val_loss: 74.7822 - val_mean_absolute_error: 74.7822
# Epoch 199/500
# 56/56 [==============================] - 0s 3ms/step - loss: 68.8680 - mean_absolute_error: 68.8680 - val_loss: 76.2229 - val_mean_absolute_error: 76.2229
# Epoch 200/500
# 56/56 [==============================] - 0s 3ms/step - loss: 68.4542 - mean_absolute_error: 68.4542 - val_loss: 74.3199 - val_mean_absolute_error: 74.3199
# Epoch 201/500
# 56/56 [==============================] - 1s 21ms/step - loss: 68.6659 - mean_absolute_error: 68.6659 - val_loss: 69.7638 - val_mean_absolute_error: 69.7638
# Epoch 202/500
# 56/56 [==============================] - 0s 3ms/step - loss: 68.4764 - mean_absolute_error: 68.4764 - val_loss: 72.9253 - val_mean_absolute_error: 72.9253
# Epoch 203/500
# 56/56 [==============================] - 0s 3ms/step - loss: 68.9946 - mean_absolute_error: 68.9946 - val_loss: 75.8797 - val_mean_absolute_error: 75.8797
# Epoch 204/500
# 56/56 [==============================] - 0s 3ms/step - loss: 70.1903 - mean_absolute_error: 70.1903 - val_loss: 72.9445 - val_mean_absolute_error: 72.9445
# Epoch 205/500
# 56/56 [==============================] - 0s 3ms/step - loss: 71.1977 - mean_absolute_error: 71.1977 - val_loss: 72.4869 - val_mean_absolute_error: 72.4869
# Epoch 206/500
# 56/56 [==============================] - 0s 4ms/step - loss: 71.0827 - mean_absolute_error: 71.0827 - val_loss: 70.2290 - val_mean_absolute_error: 70.2290
# Epoch 207/500
# 56/56 [==============================] - 0s 3ms/step - loss: 66.9295 - mean_absolute_error: 66.9295 - val_loss: 71.4817 - val_mean_absolute_error: 71.4817
# Epoch 208/500
# 56/56 [==============================] - 1s 20ms/step - loss: 68.8744 - mean_absolute_error: 68.8744 - val_loss: 68.0458 - val_mean_absolute_error: 68.0458
# Epoch 209/500
# 56/56 [==============================] - 0s 3ms/step - loss: 65.8686 - mean_absolute_error: 65.8686 - val_loss: 75.0465 - val_mean_absolute_error: 75.0465
# Epoch 210/500
# 56/56 [==============================] - 0s 3ms/step - loss: 68.2325 - mean_absolute_error: 68.2325 - val_loss: 75.7369 - val_mean_absolute_error: 75.7369
# Epoch 211/500
# 56/56 [==============================] - 0s 3ms/step - loss: 67.8930 - mean_absolute_error: 67.8930 - val_loss: 68.7170 - val_mean_absolute_error: 68.7170
# Epoch 212/500
# 56/56 [==============================] - 0s 4ms/step - loss: 67.0361 - mean_absolute_error: 67.0361 - val_loss: 68.8694 - val_mean_absolute_error: 68.8694
# Epoch 213/500
# 56/56 [==============================] - 0s 4ms/step - loss: 68.5830 - mean_absolute_error: 68.5830 - val_loss: 68.3107 - val_mean_absolute_error: 68.3107
# Epoch 214/500
# 56/56 [==============================] - 1s 21ms/step - loss: 68.7044 - mean_absolute_error: 68.7044 - val_loss: 68.0371 - val_mean_absolute_error: 68.0371
# Epoch 215/500
# 56/56 [==============================] - 0s 3ms/step - loss: 67.7319 - mean_absolute_error: 67.7319 - val_loss: 71.6073 - val_mean_absolute_error: 71.6073
# Epoch 216/500
# 56/56 [==============================] - 0s 3ms/step - loss: 66.8256 - mean_absolute_error: 66.8256 - val_loss: 68.5428 - val_mean_absolute_error: 68.5428
# Epoch 217/500
# 56/56 [==============================] - 0s 3ms/step - loss: 67.8523 - mean_absolute_error: 67.8523 - val_loss: 71.7402 - val_mean_absolute_error: 71.7402
# Epoch 218/500
# 56/56 [==============================] - 0s 3ms/step - loss: 68.3949 - mean_absolute_error: 68.3949 - val_loss: 77.3985 - val_mean_absolute_error: 77.3985
# Epoch 219/500
# 56/56 [==============================] - 0s 3ms/step - loss: 66.7676 - mean_absolute_error: 66.7676 - val_loss: 72.0733 - val_mean_absolute_error: 72.0733
# Epoch 220/500
# 56/56 [==============================] - 0s 4ms/step - loss: 65.7416 - mean_absolute_error: 65.7416 - val_loss: 68.3385 - val_mean_absolute_error: 68.3385
# Epoch 221/500
# 56/56 [==============================] - 0s 3ms/step - loss: 66.7790 - mean_absolute_error: 66.7790 - val_loss: 71.6954 - val_mean_absolute_error: 71.6954
# Epoch 222/500
# 56/56 [==============================] - 0s 3ms/step - loss: 68.1513 - mean_absolute_error: 68.1513 - val_loss: 72.3060 - val_mean_absolute_error: 72.3060
# Epoch 223/500
# 56/56 [==============================] - 1s 20ms/step - loss: 65.8098 - mean_absolute_error: 65.8098 - val_loss: 66.7786 - val_mean_absolute_error: 66.7786
# Epoch 224/500
# 56/56 [==============================] - 0s 3ms/step - loss: 65.5909 - mean_absolute_error: 65.5909 - val_loss: 67.4584 - val_mean_absolute_error: 67.4584
# Epoch 225/500
# 56/56 [==============================] - 0s 3ms/step - loss: 65.0639 - mean_absolute_error: 65.0639 - val_loss: 77.5333 - val_mean_absolute_error: 77.5333
# Epoch 226/500
# 56/56 [==============================] - 1s 20ms/step - loss: 65.4447 - mean_absolute_error: 65.4447 - val_loss: 66.6622 - val_mean_absolute_error: 66.6622
# Epoch 227/500
# 56/56 [==============================] - 0s 3ms/step - loss: 68.2031 - mean_absolute_error: 68.2031 - val_loss: 73.4747 - val_mean_absolute_error: 73.4747
# Epoch 228/500
# 56/56 [==============================] - 0s 3ms/step - loss: 66.2546 - mean_absolute_error: 66.2546 - val_loss: 73.3361 - val_mean_absolute_error: 73.3361
# Epoch 229/500
# 56/56 [==============================] - 0s 4ms/step - loss: 68.0599 - mean_absolute_error: 68.0599 - val_loss: 77.5352 - val_mean_absolute_error: 77.5352
# Epoch 230/500
# 56/56 [==============================] - 0s 3ms/step - loss: 66.2774 - mean_absolute_error: 66.2774 - val_loss: 79.8134 - val_mean_absolute_error: 79.8134
# Epoch 231/500
# 56/56 [==============================] - 0s 3ms/step - loss: 66.7263 - mean_absolute_error: 66.7263 - val_loss: 66.8867 - val_mean_absolute_error: 66.8867
# Epoch 232/500
# 56/56 [==============================] - 0s 3ms/step - loss: 65.7429 - mean_absolute_error: 65.7429 - val_loss: 68.3805 - val_mean_absolute_error: 68.3805
# Epoch 233/500
# 56/56 [==============================] - 1s 26ms/step - loss: 66.3316 - mean_absolute_error: 66.3316 - val_loss: 65.5082 - val_mean_absolute_error: 65.5082
# Epoch 234/500
# 56/56 [==============================] - 0s 3ms/step - loss: 65.5505 - mean_absolute_error: 65.5505 - val_loss: 75.4522 - val_mean_absolute_error: 75.4522
# Epoch 235/500
# 56/56 [==============================] - 0s 3ms/step - loss: 65.2680 - mean_absolute_error: 65.2680 - val_loss: 68.6197 - val_mean_absolute_error: 68.6197
# Epoch 236/500
# 56/56 [==============================] - 0s 4ms/step - loss: 63.9005 - mean_absolute_error: 63.9005 - val_loss: 66.0785 - val_mean_absolute_error: 66.0785
# Epoch 237/500
# 56/56 [==============================] - 0s 3ms/step - loss: 65.8753 - mean_absolute_error: 65.8753 - val_loss: 69.9317 - val_mean_absolute_error: 69.9317
# Epoch 238/500
# 56/56 [==============================] - 0s 4ms/step - loss: 65.3467 - mean_absolute_error: 65.3467 - val_loss: 82.8811 - val_mean_absolute_error: 82.8811
# Epoch 239/500
# 56/56 [==============================] - 0s 4ms/step - loss: 66.5331 - mean_absolute_error: 66.5331 - val_loss: 68.2139 - val_mean_absolute_error: 68.2139
# Epoch 240/500
# 56/56 [==============================] - 0s 3ms/step - loss: 65.0066 - mean_absolute_error: 65.0066 - val_loss: 70.4213 - val_mean_absolute_error: 70.4213
# Epoch 241/500
# 56/56 [==============================] - 0s 3ms/step - loss: 64.0342 - mean_absolute_error: 64.0342 - val_loss: 72.1649 - val_mean_absolute_error: 72.1649
# Epoch 242/500
# 56/56 [==============================] - 0s 4ms/step - loss: 66.1183 - mean_absolute_error: 66.1183 - val_loss: 65.8854 - val_mean_absolute_error: 65.8854
# Epoch 243/500
# 56/56 [==============================] - 1s 21ms/step - loss: 64.7464 - mean_absolute_error: 64.7464 - val_loss: 65.2175 - val_mean_absolute_error: 65.2175
# Epoch 244/500
# 56/56 [==============================] - 0s 4ms/step - loss: 62.9198 - mean_absolute_error: 62.9198 - val_loss: 76.4132 - val_mean_absolute_error: 76.4132
# Epoch 245/500
# 56/56 [==============================] - 0s 3ms/step - loss: 65.6992 - mean_absolute_error: 65.6992 - val_loss: 67.6654 - val_mean_absolute_error: 67.6654
# Epoch 246/500
# 56/56 [==============================] - 0s 4ms/step - loss: 64.1787 - mean_absolute_error: 64.1787 - val_loss: 68.6928 - val_mean_absolute_error: 68.6928
# Epoch 247/500
# 56/56 [==============================] - 0s 4ms/step - loss: 66.3961 - mean_absolute_error: 66.3961 - val_loss: 67.4940 - val_mean_absolute_error: 67.4940
# Epoch 248/500
# 56/56 [==============================] - 0s 4ms/step - loss: 67.8753 - mean_absolute_error: 67.8753 - val_loss: 71.6340 - val_mean_absolute_error: 71.6340
# Epoch 249/500
# 56/56 [==============================] - 0s 3ms/step - loss: 63.5904 - mean_absolute_error: 63.5904 - val_loss: 68.5142 - val_mean_absolute_error: 68.5142
# Epoch 250/500
# 56/56 [==============================] - 1s 21ms/step - loss: 64.4790 - mean_absolute_error: 64.4790 - val_loss: 64.9911 - val_mean_absolute_error: 64.9911
# Epoch 251/500
# 56/56 [==============================] - 0s 3ms/step - loss: 64.6759 - mean_absolute_error: 64.6759 - val_loss: 72.4446 - val_mean_absolute_error: 72.4446
# Epoch 252/500
# 56/56 [==============================] - 0s 3ms/step - loss: 64.4583 - mean_absolute_error: 64.4583 - val_loss: 67.9723 - val_mean_absolute_error: 67.9723
# Epoch 253/500
# 56/56 [==============================] - 0s 4ms/step - loss: 66.4830 - mean_absolute_error: 66.4830 - val_loss: 67.1342 - val_mean_absolute_error: 67.1342
# Epoch 254/500
# 56/56 [==============================] - 0s 4ms/step - loss: 63.9122 - mean_absolute_error: 63.9122 - val_loss: 65.8028 - val_mean_absolute_error: 65.8028
# Epoch 255/500
# 56/56 [==============================] - 1s 21ms/step - loss: 63.7575 - mean_absolute_error: 63.7575 - val_loss: 64.8290 - val_mean_absolute_error: 64.8290
# Epoch 256/500
# 56/56 [==============================] - 0s 3ms/step - loss: 64.1986 - mean_absolute_error: 64.1986 - val_loss: 69.0650 - val_mean_absolute_error: 69.0650
# Epoch 257/500
# 56/56 [==============================] - 0s 3ms/step - loss: 65.0588 - mean_absolute_error: 65.0588 - val_loss: 74.0414 - val_mean_absolute_error: 74.0414
# Epoch 258/500
# 56/56 [==============================] - 0s 4ms/step - loss: 66.2835 - mean_absolute_error: 66.2835 - val_loss: 66.7886 - val_mean_absolute_error: 66.7886
# Epoch 259/500
# 56/56 [==============================] - 0s 4ms/step - loss: 64.1645 - mean_absolute_error: 64.1645 - val_loss: 75.1622 - val_mean_absolute_error: 75.1622
# Epoch 260/500
# 56/56 [==============================] - 0s 3ms/step - loss: 65.6300 - mean_absolute_error: 65.6300 - val_loss: 66.8524 - val_mean_absolute_error: 66.8524
# Epoch 261/500
# 56/56 [==============================] - 0s 3ms/step - loss: 69.3904 - mean_absolute_error: 69.3904 - val_loss: 78.1781 - val_mean_absolute_error: 78.1781
# Epoch 262/500
# 56/56 [==============================] - 0s 3ms/step - loss: 63.4942 - mean_absolute_error: 63.4942 - val_loss: 71.4239 - val_mean_absolute_error: 71.4239
# Epoch 263/500
# 56/56 [==============================] - 0s 3ms/step - loss: 63.0529 - mean_absolute_error: 63.0529 - val_loss: 71.2703 - val_mean_absolute_error: 71.2703
# Epoch 264/500
# 56/56 [==============================] - 0s 4ms/step - loss: 63.2397 - mean_absolute_error: 63.2397 - val_loss: 67.1153 - val_mean_absolute_error: 67.1153
# Epoch 265/500
# 56/56 [==============================] - 0s 3ms/step - loss: 62.4419 - mean_absolute_error: 62.4419 - val_loss: 66.3941 - val_mean_absolute_error: 66.3941
# Epoch 266/500
# 56/56 [==============================] - 0s 3ms/step - loss: 61.7476 - mean_absolute_error: 61.7476 - val_loss: 68.5064 - val_mean_absolute_error: 68.5064
# Epoch 267/500
# 56/56 [==============================] - 0s 3ms/step - loss: 61.8881 - mean_absolute_error: 61.8881 - val_loss: 67.0494 - val_mean_absolute_error: 67.0494
# Epoch 268/500
# 56/56 [==============================] - 0s 4ms/step - loss: 63.4442 - mean_absolute_error: 63.4442 - val_loss: 66.9964 - val_mean_absolute_error: 66.9964
# Epoch 269/500
# 56/56 [==============================] - 0s 4ms/step - loss: 63.9231 - mean_absolute_error: 63.9231 - val_loss: 72.3711 - val_mean_absolute_error: 72.3711
# Epoch 270/500
# 56/56 [==============================] - 0s 4ms/step - loss: 62.5327 - mean_absolute_error: 62.5327 - val_loss: 68.0242 - val_mean_absolute_error: 68.0242
# Epoch 271/500
# 56/56 [==============================] - 1s 20ms/step - loss: 61.4669 - mean_absolute_error: 61.4669 - val_loss: 62.8148 - val_mean_absolute_error: 62.8148
# Epoch 272/500
# 56/56 [==============================] - 0s 3ms/step - loss: 61.3781 - mean_absolute_error: 61.3781 - val_loss: 64.0185 - val_mean_absolute_error: 64.0185
# Epoch 273/500
# 56/56 [==============================] - 0s 3ms/step - loss: 61.4394 - mean_absolute_error: 61.4394 - val_loss: 63.8876 - val_mean_absolute_error: 63.8876
# Epoch 274/500
# 56/56 [==============================] - 0s 4ms/step - loss: 62.2077 - mean_absolute_error: 62.2077 - val_loss: 63.5501 - val_mean_absolute_error: 63.5501
# Epoch 275/500
# 56/56 [==============================] - 0s 3ms/step - loss: 62.8154 - mean_absolute_error: 62.8154 - val_loss: 71.2294 - val_mean_absolute_error: 71.2294
# Epoch 276/500
# 56/56 [==============================] - 0s 3ms/step - loss: 61.4879 - mean_absolute_error: 61.4879 - val_loss: 63.0295 - val_mean_absolute_error: 63.0295
# Epoch 277/500
# 56/56 [==============================] - 0s 3ms/step - loss: 60.8685 - mean_absolute_error: 60.8685 - val_loss: 63.9627 - val_mean_absolute_error: 63.9627
# Epoch 278/500
# 56/56 [==============================] - 0s 3ms/step - loss: 61.8304 - mean_absolute_error: 61.8304 - val_loss: 66.0788 - val_mean_absolute_error: 66.0788
# Epoch 279/500
# 56/56 [==============================] - 0s 4ms/step - loss: 61.5098 - mean_absolute_error: 61.5098 - val_loss: 65.6693 - val_mean_absolute_error: 65.6693
# Epoch 280/500
# 56/56 [==============================] - 0s 3ms/step - loss: 61.7182 - mean_absolute_error: 61.7182 - val_loss: 70.8226 - val_mean_absolute_error: 70.8226
# Epoch 281/500
# 56/56 [==============================] - 1s 21ms/step - loss: 61.7381 - mean_absolute_error: 61.7381 - val_loss: 62.7337 - val_mean_absolute_error: 62.7337
# Epoch 282/500
# 56/56 [==============================] - 1s 21ms/step - loss: 60.7788 - mean_absolute_error: 60.7788 - val_loss: 61.5556 - val_mean_absolute_error: 61.5556
# Epoch 283/500
# ...
# Epoch 407/500
# 56/56 [==============================] - 0s 4ms/step - loss: 53.4021 - mean_absolute_error: 53.4021 - val_loss: 56.8715 - val_mean_absolute_error: 56.8715
# Epoch 408/500
# 56/56 [==============================] - 0s 3ms/step - loss: 53.3106 - mean_absolute_error: 53.3106 - val_loss: 67.3281 - val_mean_absolute_error: 67.3281
# Epoch 409/500
# 56/56 [==============================] - 0s 3ms/step - loss: 53.8827 - mean_absolute_error: 53.8827 - val_loss: 59.0776 - val_mean_absolute_error: 59.0776
# Epoch 410/500
# 56/56 [==============================] - 1s 20ms/step - loss: 55.4253 - mean_absolute_error: 55.4253 - val_loss: 54.9934 - val_mean_absolute_error: 54.9934
# Epoch 411/500
# 56/56 [==============================] - 0s 4ms/step - loss: 59.7047 - mean_absolute_error: 59.7047 - val_loss: 60.3107 - val_mean_absolute_error: 60.3107
# Epoch 412/500
# 56/56 [==============================] - 0s 4ms/step - loss: 54.5814 - mean_absolute_error: 54.5814 - val_loss: 55.4818 - val_mean_absolute_error: 55.4818
# Epoch 413/500
# 56/56 [==============================] - 1s 20ms/step - loss: 54.1376 - mean_absolute_error: 54.1376 - val_loss: 54.3899 - val_mean_absolute_error: 54.3899
# Epoch 414/500
# 56/56 [==============================] - 0s 4ms/step - loss: 54.1798 - mean_absolute_error: 54.1798 - val_loss: 55.3893 - val_mean_absolute_error: 55.3893
# Epoch 415/500
# 56/56 [==============================] - 0s 4ms/step - loss: 53.2391 - mean_absolute_error: 53.2391 - val_loss: 56.0336 - val_mean_absolute_error: 56.0336
# Epoch 416/500
# 56/56 [==============================] - 1s 22ms/step - loss: 52.0803 - mean_absolute_error: 52.0803 - val_loss: 53.9295 - val_mean_absolute_error: 53.9295
# Epoch 417/500
# 56/56 [==============================] - 0s 4ms/step - loss: 54.4542 - mean_absolute_error: 54.4542 - val_loss: 65.8493 - val_mean_absolute_error: 65.8493
# Epoch 418/500
# 56/56 [==============================] - 0s 4ms/step - loss: 54.1806 - mean_absolute_error: 54.1806 - val_loss: 60.8266 - val_mean_absolute_error: 60.8266
# Epoch 419/500
# 56/56 [==============================] - 0s 4ms/step - loss: 54.1733 - mean_absolute_error: 54.1733 - val_loss: 66.3428 - val_mean_absolute_error: 66.3428
# Epoch 420/500
# 56/56 [==============================] - 0s 4ms/step - loss: 56.1476 - mean_absolute_error: 56.1476 - val_loss: 54.3164 - val_mean_absolute_error: 54.3164
# Epoch 421/500
# 56/56 [==============================] - 0s 4ms/step - loss: 52.7987 - mean_absolute_error: 52.7987 - val_loss: 56.7254 - val_mean_absolute_error: 56.7254
# Epoch 422/500
# 56/56 [==============================] - 0s 4ms/step - loss: 52.4160 - mean_absolute_error: 52.4160 - val_loss: 57.5920 - val_mean_absolute_error: 57.5920
# Epoch 423/500
# 56/56 [==============================] - 0s 4ms/step - loss: 52.4078 - mean_absolute_error: 52.4078 - val_loss: 60.5261 - val_mean_absolute_error: 60.5261
# Epoch 424/500
# 56/56 [==============================] - 0s 4ms/step - loss: 54.7322 - mean_absolute_error: 54.7322 - val_loss: 54.5607 - val_mean_absolute_error: 54.5607
# Epoch 425/500
# 56/56 [==============================] - 0s 4ms/step - loss: 55.7168 - mean_absolute_error: 55.7168 - val_loss: 59.7075 - val_mean_absolute_error: 59.7075
# Epoch 426/500
# 56/56 [==============================] - 0s 4ms/step - loss: 53.3500 - mean_absolute_error: 53.3500 - val_loss: 55.5296 - val_mean_absolute_error: 55.5296
# Epoch 427/500
# 56/56 [==============================] - 0s 4ms/step - loss: 53.1590 - mean_absolute_error: 53.1590 - val_loss: 58.0151 - val_mean_absolute_error: 58.0151
# Epoch 428/500
# 56/56 [==============================] - 0s 4ms/step - loss: 53.4790 - mean_absolute_error: 53.4790 - val_loss: 56.0658 - val_mean_absolute_error: 56.0658
# Epoch 429/500
# 56/56 [==============================] - 1s 21ms/step - loss: 55.2263 - mean_absolute_error: 55.2263 - val_loss: 53.2335 - val_mean_absolute_error: 53.2335
# Epoch 430/500
# 56/56 [==============================] - 0s 4ms/step - loss: 51.3319 - mean_absolute_error: 51.3319 - val_loss: 53.4752 - val_mean_absolute_error: 53.4752
# Epoch 431/500
# 56/56 [==============================] - 0s 4ms/step - loss: 54.7520 - mean_absolute_error: 54.7520 - val_loss: 54.2300 - val_mean_absolute_error: 54.2300
# Epoch 432/500
# 56/56 [==============================] - 0s 4ms/step - loss: 53.3555 - mean_absolute_error: 53.3555 - val_loss: 54.9914 - val_mean_absolute_error: 54.9914
# Epoch 433/500
# 56/56 [==============================] - 0s 4ms/step - loss: 53.4001 - mean_absolute_error: 53.4001 - val_loss: 60.4722 - val_mean_absolute_error: 60.4722
# Epoch 434/500
# 56/56 [==============================] - 0s 4ms/step - loss: 52.0032 - mean_absolute_error: 52.0032 - val_loss: 56.6101 - val_mean_absolute_error: 56.6101
# Epoch 435/500
# 56/56 [==============================] - 0s 4ms/step - loss: 51.9098 - mean_absolute_error: 51.9098 - val_loss: 60.8736 - val_mean_absolute_error: 60.8736
# Epoch 436/500
# 56/56 [==============================] - 0s 4ms/step - loss: 51.6091 - mean_absolute_error: 51.6091 - val_loss: 62.5459 - val_mean_absolute_error: 62.5459
# Epoch 437/500
# 56/56 [==============================] - 0s 4ms/step - loss: 53.6014 - mean_absolute_error: 53.6014 - val_loss: 57.8020 - val_mean_absolute_error: 57.8020
# Epoch 438/500
# 56/56 [==============================] - 0s 4ms/step - loss: 52.4528 - mean_absolute_error: 52.4528 - val_loss: 56.9838 - val_mean_absolute_error: 56.9838
# Epoch 439/500
# 56/56 [==============================] - 0s 4ms/step - loss: 52.3766 - mean_absolute_error: 52.3766 - val_loss: 53.3966 - val_mean_absolute_error: 53.3966
# Epoch 440/500
# 56/56 [==============================] - 0s 4ms/step - loss: 52.5973 - mean_absolute_error: 52.5973 - val_loss: 56.3513 - val_mean_absolute_error: 56.3513
# Epoch 441/500
# 56/56 [==============================] - 0s 4ms/step - loss: 54.1061 - mean_absolute_error: 54.1061 - val_loss: 54.3898 - val_mean_absolute_error: 54.3898
# Epoch 442/500
# 56/56 [==============================] - 0s 4ms/step - loss: 51.3622 - mean_absolute_error: 51.3622 - val_loss: 55.3773 - val_mean_absolute_error: 55.3773
# Epoch 443/500
# 56/56 [==============================] - 1s 21ms/step - loss: 53.1216 - mean_absolute_error: 53.1216 - val_loss: 52.5418 - val_mean_absolute_error: 52.5418
# Epoch 444/500
# 56/56 [==============================] - 0s 4ms/step - loss: 51.0721 - mean_absolute_error: 51.0721 - val_loss: 54.3440 - val_mean_absolute_error: 54.3440
# Epoch 445/500
# 56/56 [==============================] - 0s 4ms/step - loss: 52.3861 - mean_absolute_error: 52.3861 - val_loss: 60.2527 - val_mean_absolute_error: 60.2527
# Epoch 446/500
# 56/56 [==============================] - 0s 4ms/step - loss: 52.3860 - mean_absolute_error: 52.3860 - val_loss: 57.6823 - val_mean_absolute_error: 57.6823
# Epoch 447/500
# 56/56 [==============================] - 0s 4ms/step - loss: 50.5126 - mean_absolute_error: 50.5126 - val_loss: 52.8859 - val_mean_absolute_error: 52.8859
# Epoch 448/500
# 56/56 [==============================] - 0s 4ms/step - loss: 51.6785 - mean_absolute_error: 51.6785 - val_loss: 54.9594 - val_mean_absolute_error: 54.9594
# Epoch 449/500
# 56/56 [==============================] - 0s 3ms/step - loss: 52.4551 - mean_absolute_error: 52.4551 - val_loss: 59.3750 - val_mean_absolute_error: 59.3750
# Epoch 450/500
# 56/56 [==============================] - 0s 4ms/step - loss: 52.8601 - mean_absolute_error: 52.8601 - val_loss: 73.6013 - val_mean_absolute_error: 73.6013
# Epoch 451/500
# 56/56 [==============================] - 0s 4ms/step - loss: 54.2715 - mean_absolute_error: 54.2715 - val_loss: 57.1143 - val_mean_absolute_error: 57.1143
# Epoch 452/500
# 56/56 [==============================] - 0s 4ms/step - loss: 52.0254 - mean_absolute_error: 52.0254 - val_loss: 62.6343 - val_mean_absolute_error: 62.6343
# Epoch 453/500
# 56/56 [==============================] - 0s 4ms/step - loss: 51.6610 - mean_absolute_error: 51.6610 - val_loss: 52.8418 - val_mean_absolute_error: 52.8418
# Epoch 454/500
# 56/56 [==============================] - 0s 4ms/step - loss: 58.3855 - mean_absolute_error: 58.3855 - val_loss: 69.1519 - val_mean_absolute_error: 69.1519
# Epoch 455/500
# 56/56 [==============================] - 0s 4ms/step - loss: 58.2551 - mean_absolute_error: 58.2551 - val_loss: 56.2707 - val_mean_absolute_error: 56.2707
# Epoch 456/500
# 56/56 [==============================] - 0s 4ms/step - loss: 53.1684 - mean_absolute_error: 53.1684 - val_loss: 54.0850 - val_mean_absolute_error: 54.0850
# Epoch 457/500
# 56/56 [==============================] - 0s 4ms/step - loss: 51.9713 - mean_absolute_error: 51.9713 - val_loss: 55.6990 - val_mean_absolute_error: 55.6990
# Epoch 458/500
# 56/56 [==============================] - 0s 4ms/step - loss: 49.3614 - mean_absolute_error: 49.3614 - val_loss: 54.5300 - val_mean_absolute_error: 54.5300
# Epoch 459/500
# 56/56 [==============================] - 0s 4ms/step - loss: 51.5912 - mean_absolute_error: 51.5912 - val_loss: 53.3379 - val_mean_absolute_error: 53.3379
# Epoch 460/500
# 56/56 [==============================] - 0s 4ms/step - loss: 50.4149 - mean_absolute_error: 50.4149 - val_loss: 53.9216 - val_mean_absolute_error: 53.9216
# Epoch 461/500
# 56/56 [==============================] - 0s 4ms/step - loss: 50.3503 - mean_absolute_error: 50.3503 - val_loss: 54.5742 - val_mean_absolute_error: 54.5742
# Epoch 462/500
# 56/56 [==============================] - 0s 4ms/step - loss: 50.8677 - mean_absolute_error: 50.8677 - val_loss: 55.9647 - val_mean_absolute_error: 55.9647
# Epoch 463/500
# 56/56 [==============================] - 0s 4ms/step - loss: 50.7388 - mean_absolute_error: 50.7388 - val_loss: 59.5048 - val_mean_absolute_error: 59.5048
# Epoch 464/500
# 56/56 [==============================] - 0s 4ms/step - loss: 51.3115 - mean_absolute_error: 51.3115 - val_loss: 52.7767 - val_mean_absolute_error: 52.7767
# Epoch 465/500
# 56/56 [==============================] - 0s 4ms/step - loss: 53.1883 - mean_absolute_error: 53.1883 - val_loss: 55.8656 - val_mean_absolute_error: 55.8656
# Epoch 466/500
# 56/56 [==============================] - 0s 4ms/step - loss: 51.5770 - mean_absolute_error: 51.5770 - val_loss: 54.0903 - val_mean_absolute_error: 54.0903
# Epoch 467/500
# 56/56 [==============================] - 0s 4ms/step - loss: 50.5367 - mean_absolute_error: 50.5367 - val_loss: 53.8550 - val_mean_absolute_error: 53.8550
# Epoch 468/500
# 56/56 [==============================] - 0s 4ms/step - loss: 52.9785 - mean_absolute_error: 52.9785 - val_loss: 54.6436 - val_mean_absolute_error: 54.6436
# Epoch 469/500
# 56/56 [==============================] - 0s 4ms/step - loss: 51.6375 - mean_absolute_error: 51.6375 - val_loss: 52.8410 - val_mean_absolute_error: 52.8410
# Epoch 470/500
# 56/56 [==============================] - 0s 4ms/step - loss: 52.3150 - mean_absolute_error: 52.3150 - val_loss: 60.1265 - val_mean_absolute_error: 60.1265
# Epoch 471/500
# 56/56 [==============================] - 0s 5ms/step - loss: 50.3558 - mean_absolute_error: 50.3558 - val_loss: 57.7716 - val_mean_absolute_error: 57.7716
# Epoch 472/500
# 56/56 [==============================] - 0s 4ms/step - loss: 50.2360 - mean_absolute_error: 50.2360 - val_loss: 59.5914 - val_mean_absolute_error: 59.5914
# Epoch 473/500
# 56/56 [==============================] - 0s 4ms/step - loss: 49.7149 - mean_absolute_error: 49.7149 - val_loss: 56.6281 - val_mean_absolute_error: 56.6281
# Epoch 474/500
# 56/56 [==============================] - 1s 25ms/step - loss: 50.0611 - mean_absolute_error: 50.0611 - val_loss: 52.0583 - val_mean_absolute_error: 52.0583
# Epoch 475/500
# 56/56 [==============================] - 0s 3ms/step - loss: 53.6946 - mean_absolute_error: 53.6946 - val_loss: 62.1045 - val_mean_absolute_error: 62.1045
# Epoch 476/500
# 56/56 [==============================] - 0s 4ms/step - loss: 53.6092 - mean_absolute_error: 53.6092 - val_loss: 52.8345 - val_mean_absolute_error: 52.8345
# Epoch 477/500
# 56/56 [==============================] - 0s 4ms/step - loss: 52.2118 - mean_absolute_error: 52.2118 - val_loss: 57.8055 - val_mean_absolute_error: 57.8055
# Epoch 478/500
# 56/56 [==============================] - 0s 4ms/step - loss: 51.0772 - mean_absolute_error: 51.0772 - val_loss: 59.1720 - val_mean_absolute_error: 59.1720
# Epoch 479/500
# 56/56 [==============================] - 0s 4ms/step - loss: 50.0095 - mean_absolute_error: 50.0095 - val_loss: 53.7494 - val_mean_absolute_error: 53.7494
# Epoch 480/500
# 56/56 [==============================] - 0s 4ms/step - loss: 51.3917 - mean_absolute_error: 51.3917 - val_loss: 53.4821 - val_mean_absolute_error: 53.4821
# Epoch 481/500
# 56/56 [==============================] - 0s 4ms/step - loss: 53.4469 - mean_absolute_error: 53.4469 - val_loss: 57.0492 - val_mean_absolute_error: 57.0492
# Epoch 482/500
# 56/56 [==============================] - 0s 4ms/step - loss: 50.7850 - mean_absolute_error: 50.7850 - val_loss: 58.5955 - val_mean_absolute_error: 58.5955
# Epoch 483/500
# 56/56 [==============================] - 0s 4ms/step - loss: 52.1150 - mean_absolute_error: 52.1150 - val_loss: 54.6467 - val_mean_absolute_error: 54.6467
# Epoch 484/500
# 56/56 [==============================] - 0s 4ms/step - loss: 49.6717 - mean_absolute_error: 49.6717 - val_loss: 55.4283 - val_mean_absolute_error: 55.4283
# Epoch 485/500
# 56/56 [==============================] - 0s 4ms/step - loss: 52.1377 - mean_absolute_error: 52.1377 - val_loss: 53.9339 - val_mean_absolute_error: 53.9339
# Epoch 486/500
# 56/56 [==============================] - 0s 4ms/step - loss: 50.6357 - mean_absolute_error: 50.6357 - val_loss: 56.5171 - val_mean_absolute_error: 56.5171
# Epoch 487/500
# 56/56 [==============================] - 0s 4ms/step - loss: 49.5387 - mean_absolute_error: 49.5387 - val_loss: 53.1152 - val_mean_absolute_error: 53.1152
# Epoch 488/500
# 56/56 [==============================] - 1s 21ms/step - loss: 49.4930 - mean_absolute_error: 49.4930 - val_loss: 51.0989 - val_mean_absolute_error: 51.0989
# Epoch 489/500
# 56/56 [==============================] - 0s 4ms/step - loss: 50.3657 - mean_absolute_error: 50.3657 - val_loss: 56.2167 - val_mean_absolute_error: 56.2167
# Epoch 490/500
# 56/56 [==============================] - 0s 4ms/step - loss: 50.6490 - mean_absolute_error: 50.6490 - val_loss: 51.8286 - val_mean_absolute_error: 51.8286
# Epoch 491/500
# 56/56 [==============================] - 0s 4ms/step - loss: 49.8085 - mean_absolute_error: 49.8085 - val_loss: 53.6266 - val_mean_absolute_error: 53.6266
# Epoch 492/500
# 56/56 [==============================] - 0s 4ms/step - loss: 49.4927 - mean_absolute_error: 49.4927 - val_loss: 52.8901 - val_mean_absolute_error: 52.8901
# Epoch 493/500
# 56/56 [==============================] - 0s 4ms/step - loss: 50.1303 - mean_absolute_error: 50.1303 - val_loss: 52.5809 - val_mean_absolute_error: 52.5809
# Epoch 494/500
# 56/56 [==============================] - 0s 4ms/step - loss: 51.4032 - mean_absolute_error: 51.4032 - val_loss: 59.9238 - val_mean_absolute_error: 59.9238
# Epoch 495/500
# 56/56 [==============================] - 0s 4ms/step - loss: 49.1865 - mean_absolute_error: 49.1865 - val_loss: 54.1536 - val_mean_absolute_error: 54.1536
# Epoch 496/500
# 56/56 [==============================] - 0s 4ms/step - loss: 48.9977 - mean_absolute_error: 48.9977 - val_loss: 52.1887 - val_mean_absolute_error: 52.1887
# Epoch 497/500
# 56/56 [==============================] - 0s 4ms/step - loss: 49.1923 - mean_absolute_error: 49.1923 - val_loss: 52.9514 - val_mean_absolute_error: 52.9514
# Epoch 498/500
# 56/56 [==============================] - 0s 4ms/step - loss: 50.0169 - mean_absolute_error: 50.0169 - val_loss: 54.2917 - val_mean_absolute_error: 54.2917
# Epoch 499/500
# 56/56 [==============================] - 1s 21ms/step - loss: 51.5514 - mean_absolute_error: 51.5514 - val_loss: 50.7707 - val_mean_absolute_error: 50.7707
# Epoch 500/500
# 56/56 [==============================] - 0s 4ms/step - loss: 51.6562 - mean_absolute_error: 51.6562 - val_loss: 56.2526 - val_mean_absolute_error: 56.2526

# %%
# from tensorflow.keras.models import load_model   
# model = load_model('model_ann_all/')

# %%
#500
train_acc = model.evaluate(X_train, y_train, verbose=0)
print('MAE training : {:.3f}'.format(train_acc[1]))
scores = model.evaluate(X_validation, y_validation)
print('MAE validation : {:.3f}'.format(scores[1]))

test_acc = model.evaluate(X_test, y_test)
print('MAE test : {:.3f}'.format(test_acc[1]))
# Out:
# MAE training : 48.678
# 12/12 [==============================] - 0s 2ms/step - loss: 56.2526 - mean_absolute_error: 56.2526
# MAE validation : 56.253
# 10/10 [==============================] - 0s 2ms/step - loss: 52.9920 - mean_absolute_error: 52.9920
# MAE test : 52.992

# %%
#500
show_train_history(train_history,'loss','val_loss')

# %% [markdown]
# **Results for 700 epochs**

# %%
train_predictions = model.predict(X_train).flatten()
#train_predict_round = np.rint(train_predictions)
train_results = pd.DataFrame(data={'Train Predictions':train_predictions, 'Actuals':y_train.flatten()})
train_results

###train_results.to_csv(r'/content/gdrive/MyDrive/TRM/ENAAM/AllRanking/Predictions_Test_Top_Results_ANN.csv')
###train_results
# Out:
# 56/56 [==============================] - 0s 1ms/step
#       Train Predictions  Actuals
# 0           1558.797974   1672.0
# 1           1654.884644   1585.0
# 2           2536.983398   2432.0
# 3            437.166321    435.0
# 4           2182.268311   2088.0
# ...                 ...      ...
# 1780        1096.386841   1104.0
# 1781        2356.502441   2506.0
# 1782         154.021698    162.0
# 1783         525.446838    532.0
# 1784        1463.830200   1488.0
#
# [1785 rows x 2 columns]

# %%
res1 = train_results.head(50)
res1.plot(kind='bar',figsize=(16,10))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %%
test_predictions = model.predict(X_test).flatten()
test_results = pd.DataFrame(data={'Test Predictions':test_predictions, 'Actuals':y_test.flatten()})
test_results
# Out:
# 10/10 [==============================] - 0s 2ms/step
#      Test Predictions  Actuals
# 0         1521.840210   1517.0
# 1          562.586609    583.0
# 2          822.618530    812.0
# 3          484.921814    543.0
# 4         1838.764771   1809.0
# ..                ...      ...
# 286       2403.320801   2338.0
# 287       1007.237732    978.0
# 288        522.607971    514.0
# 289        281.693237    269.0
# 290       1947.795532   1877.0
#
# [291 rows x 2 columns]

# %%
res2 = test_results.head(100)
res2.plot(kind='bar',figsize=(20,10))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %% [markdown]
# TOP 100

# %%
# Import dataset
df_2 = pd.read_csv('/content/gdrive/MyDrive/TRM/ENAAM/AllRanking/ground_truth.csv')
df_2
# Out:
#       Response Time  Availability  Throughput  Reliability  Latency  Rank
# 0             41.00            97        43.1           73     1.00      1
# 1             57.00            98        34.6           73     1.00      2
# 2             57.00            86        40.1           73     1.00      3
# 3             78.00           100        35.3           67     1.00      4
# 4             78.00            92        36.9           73     1.00      5
# ...             ...           ...         ...          ...      ...    ...
# 2502        1674.00            55         0.8           67  1005.40   2503
# 2503        2555.00            83         0.3           73  2035.00   2504
# 2504        2204.38            66         0.7           73  2050.13   2505
# 2505        4480.80            52         1.0           50  1652.40   2506
# 2506        4637.61            30         0.5           67  4140.35   2507
#
# [2507 rows x 6 columns]

# %%
# Create python dataframe
decisions_2 = pd.DataFrame()
decisions_2['Response Time'] = df_2['Response Time']
decisions_2['Availability'] = df_2['Availability']
decisions_2['Throughput'] = df_2['Throughput']
decisions_2['Reliability'] = df_2['Reliability']
decisions_2['Latency'] = df_2['Latency']
decisions_2['Rank'] = df_2['Rank ']
decisions_2.head(100)
# Out:
#     Response Time  Availability  Throughput  Reliability  Latency  Rank
# 0           41.00            97        43.1           73     1.00     1
# 1           57.00            98        34.6           73     1.00     2
# 2           57.00            86        40.1           73     1.00     3
# 3           78.00           100        35.3           67     1.00     4
# 4           78.00            92        36.9           73     1.00     5
# ..            ...           ...         ...          ...      ...   ...
# 95          53.00            83        14.5           73     2.00    96
# 96         116.00            98        16.7           67     1.33    97
# 97         126.67            94         9.5           73     0.67    98
# 98         119.00            83        10.7           73     1.00    99
# 99         111.00            87        27.4           58     2.00   100
#
# [100 rows x 6 columns]

# %%
test_data_top = decisions_2[0:100]

# %%
tmp_top = np.array(test_data_top)
X_test_top = tmp_top[:, :-1]
y_test_top = tmp_top[:, -1]

# %%
test_acc_top = model.evaluate(X_test_top, y_test_top)
print('MAE test top : {:.3f}'.format(test_acc_top[1]))
# Out:
# 4/4 [==============================] - 0s 3ms/step - loss: 7.0500 - mean_absolute_error: 7.0500
# MAE test top : 7.050

# %%
test_predictions_top = model.predict(X_test_top).flatten()
test_results_top = pd.DataFrame(data={'Test Predictions':test_predictions_top, 'Actuals':y_test_top.flatten()})
test_results_top.to_csv(r'/content/gdrive/MyDrive/TRM/ENAAM/AllRanking/Predictions_Test_Top_Results_ANN.csv')
test_results_top
# Out:
# 4/4 [==============================] - 0s 3ms/step
#     Test Predictions  Actuals
# 0           0.574440      1.0
# 1          -1.068486      2.0
# 2           4.985174      3.0
# 3           1.447594      4.0
# 4           6.912106      5.0
# ..               ...      ...
# 95        101.953537     96.0
# 96         72.762810     97.0
# 97         85.883667     98.0
# 98        118.695068     99.0
# 99        121.400986    100.0
#
# [100 rows x 2 columns]

# %%
res3 = test_results_top.head(100)
res3.plot(kind='bar',figsize=(20,10))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()
